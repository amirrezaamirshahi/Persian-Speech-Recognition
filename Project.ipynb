# %% [markdown]
# ### preprocess_audio

# %%
import os
import librosa
import soundfile as sf
import scipy.signal as signal
import numpy as np

# مسیرها
input_dir = 'data/raw_recordings'
output_dir = 'data/preprocessed_recordings'
os.makedirs(output_dir, exist_ok=True)

# تنظیمات
target_sr = 16000
subtype = 'PCM_16'
low_cut = 300
high_cut = 3400
order = 5

# توابع پردازش
def normalize_audio(y):
    return y / np.max(np.abs(y))

def trim_silence(y, top_db=30):
    return librosa.effects.trim(y, top_db=top_db)[0]

def bandpass_filter(y, sr, low_cut, high_cut, order=5):
    nyquist = 0.5 * sr
    low = low_cut / nyquist
    high = high_cut / nyquist
    b, a = signal.butter(order, [low, high], btype='band')
    return signal.lfilter(b, a, y)

# پردازش فایل‌ها
for filename in os.listdir(input_dir):
    if filename.endswith('.wav'):
        input_path = os.path.join(input_dir, filename)
        output_path = os.path.join(output_dir, filename)

        # 1. بارگذاری و تبدیل به نرخ ۱۶kHz
        y, sr = librosa.load(input_path, sr=target_sr)

        # 2. نرمال‌سازی دامنه
        y = normalize_audio(y)

        # 3. حذف سکوت از ابتدا و انتها
        y = trim_silence(y)

        # 4. فیلتر باندپَس (حذف نویز خارج از بازه گفتار)
        y = bandpass_filter(y, sr, low_cut, high_cut, order)

        # 5. ذخیره با فرمت ۱۶ بیت
        sf.write(output_path, y, sr, subtype=subtype)

        print(f'✅ Processed and saved: {filename}')
# Out:
# ✅ Processed and saved: Bale_000001.wav
# ✅ Processed and saved: Bale_000002.wav
# ✅ Processed and saved: Bale_000003.wav
# ✅ Processed and saved: Bale_000004.wav
# ✅ Processed and saved: Bale_000005.wav
# ✅ Processed and saved: Bale_001.wav
# ✅ Processed and saved: Bale_002.wav
# ✅ Processed and saved: Bale_003.wav
# ✅ Processed and saved: Bale_004.wav
# ✅ Processed and saved: Bale_005.wav
# ✅ Processed and saved: Bale_01.wav
# ✅ Processed and saved: Bale_02.wav
# ✅ Processed and saved: Bale_03.wav
# ✅ Processed and saved: Bale_04.wav
# ✅ Processed and saved: Bale_05.wav
# ✅ Processed and saved: BesiarAali_000001.wav
# ✅ Processed and saved: BesiarAali_000002.wav
# ✅ Processed and saved: BesiarAali_000003.wav
# ✅ Processed and saved: BesiarAali_000004.wav
# ✅ Processed and saved: BesiarAali_000005.wav
# ✅ Processed and saved: BesiarAali_001.wav
# ✅ Processed and saved: BesiarAali_002.wav
# ✅ Processed and saved: BesiarAali_003.wav
# ✅ Processed and saved: BesiarAali_004.wav
# ✅ Processed and saved: BesiarAali_005.wav
# ✅ Processed and saved: BesiarAali_01.wav
# ✅ Processed and saved: BesiarAali_02.wav
# ✅ Processed and saved: BesiarAali_03.wav
# ✅ Processed and saved: BesiarAali_04.wav
# ✅ Processed and saved: BesiarAali_05.wav
# ✅ Processed and saved: Kheir_000001.wav
# ✅ Processed and saved: Kheir_000002.wav
# ✅ Processed and saved: Kheir_000003.wav
# ✅ Processed and saved: Kheir_000004.wav
# ✅ Processed and saved: Kheir_000005.wav
# ✅ Processed and saved: Kheir_001.wav
# ✅ Processed and saved: Kheir_002.wav
# ✅ Processed and saved: Kheir_003.wav
# ✅ Processed and saved: Kheir_004.wav
# ✅ Processed and saved: Kheir_005.wav
# ✅ Processed and saved: kheir_01.wav
# ✅ Processed and saved: kheir_02.wav
# ✅ Processed and saved: kheir_03.wav
# ✅ Processed and saved: kheir_04.wav
# ✅ Processed and saved: kheir_05.wav
# ✅ Processed and saved: Khodahafez_000001.wav
# ✅ Processed and saved: Khodahafez_000002.wav
# ✅ Processed and saved: Khodahafez_000003.wav
# ✅ Processed and saved: Khodahafez_000004.wav
# ✅ Processed and saved: Khodahafez_000005.wav
# ✅ Processed and saved: Khodahafez_001.wav
# ✅ Processed and saved: Khodahafez_002.wav
# ✅ Processed and saved: Khodahafez_003.wav
# ✅ Processed and saved: Khodahafez_004.wav
# ✅ Processed and saved: Khodahafez_005.wav
# ✅ Processed and saved: Motshakeram_000001.wav
# ✅ Processed and saved: Motshakeram_000002.wav
# ✅ Processed and saved: Motshakeram_000003.wav
# ✅ Processed and saved: Motshakeram_000004.wav
# ✅ Processed and saved: Motshakeram_000005.wav
# ✅ Processed and saved: Motshakeram_001.wav
# ✅ Processed and saved: Motshakeram_002.wav
# ✅ Processed and saved: Motshakeram_003.wav
# ✅ Processed and saved: Motshakeram_004.wav
# ✅ Processed and saved: Motshakeram_005.wav
# ✅ Processed and saved: Motshakeram_01.wav
# ✅ Processed and saved: Motshakeram_02.wav
# ✅ Processed and saved: Motshakeram_03.wav
# ✅ Processed and saved: Motshakeram_04.wav
# ✅ Processed and saved: Motshakeram_05.wav
# ✅ Processed and saved: Salam_000001.wav
# ✅ Processed and saved: Salam_000002.wav
# ✅ Processed and saved: Salam_000003.wav
# ✅ Processed and saved: Salam_000004.wav
# ✅ Processed and saved: Salam_000005.wav
# ✅ Processed and saved: Salam_001.wav
# ✅ Processed and saved: Salam_002.wav
# ✅ Processed and saved: Salam_003.wav
# ✅ Processed and saved: Salam_004.wav
# ✅ Processed and saved: Salam_005.wav
# ✅ Processed and saved: Salam_01.wav
# ✅ Processed and saved: Salam_02.wav
# ✅ Processed and saved: Salam_03.wav
# ✅ Processed and saved: Salam_04.wav
# ✅ Processed and saved: Salam_05.wav

# %% [markdown]
# ### plot_waveform

# %%
import os
import librosa
import soundfile as sf
import scipy.signal as signal
import numpy as np
import matplotlib.pyplot as plt
import librosa.display

# Path to preprocessed audio files and output directory
input_dir = 'data/preprocessed_recordings'
output_dir = 'plot_waveform'
target_sr = 16000

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Feature extraction functions
def compute_rms(y):
    return np.sqrt(np.mean(y**2))

def compute_zcr(y):
    return np.mean(librosa.zero_crossings(y, pad=False))

def compute_energy(y):
    return np.sum(y**2)

def save_waveform_plot(y, sr, title, rms, zcr, energy):
    plt.figure(figsize=(10, 2.5))
    librosa.display.waveshow(y, sr=sr)
    plt.title(f'Waveform: {title}')
    plt.xlabel("Time (seconds)")
    plt.ylabel("Amplitude")
    
    # Add feature text to the plot
    text_str = f'RMS: {rms:.4f}\nZCR: {zcr:.4f}\nEnergy: {energy:.2f}'
    plt.text(0.02, 0.98, text_str, transform=plt.gca().transAxes, 
             verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
    
    plt.tight_layout()
    output_path = os.path.join(output_dir, f'waveform_{title}.png')
    plt.savefig(output_path)
    plt.close()

def save_fft_plot(y, sr, title, rms, zcr, energy):
    Y = np.fft.rfft(y)
    freqs = np.fft.rfftfreq(len(y), 1/sr)
    plt.figure(figsize=(10, 2.5))
    plt.plot(freqs, np.abs(Y))
    plt.title(f'Frequency Spectrum (FFT): {title}')
    plt.xlabel("Frequency (Hz)")
    plt.ylabel("Magnitude")
    plt.xlim(0, 8000)
    
    # Add feature text to the plot
    text_str = f'RMS: {rms:.4f}\nZCR: {zcr:.4f}\nEnergy: {energy:.2f}'
    plt.text(0.02, 0.98, text_str, transform=plt.gca().transAxes, 
             verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
    
    plt.tight_layout()
    output_path = os.path.join(output_dir, f'fft_{title}.png')
    plt.savefig(output_path)
    plt.close()

def save_features_to_text(filename, rms, zcr, energy):
    output_path = os.path.join(output_dir, f'features_{filename}.txt')
    with open(output_path, 'w') as f:
        f.write(f'File: {filename}\n')
        f.write(f'RMS: {rms:.4f}\n')
        f.write(f'Zero-Crossing Rate: {zcr:.4f}\n')
        f.write(f'Energy: {energy:.2f}\n')

# Analyze each audio file
for filename in os.listdir(input_dir):
    if filename.endswith('.wav'):
        path = os.path.join(input_dir, filename)
        y, sr = librosa.load(path, sr=target_sr)

        # Compute features
        rms = compute_rms(y)
        zcr = compute_zcr(y)
        energy = compute_energy(y)

        # Save features to text file
        save_features_to_text(filename, rms, zcr, energy)

        # Save visualizations with features annotated
        save_waveform_plot(y, sr, filename, rms, zcr, energy)
        save_fft_plot(y, sr, filename, rms, zcr, energy)

# %% [markdown]
# ### MFCC

# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

class FeatureExtractor:
    def __init__(self, sample_rate=16000, n_mfcc=13, n_fft=2048,
                 hop_length=512, n_mels=128):
        self.sample_rate = sample_rate
        self.n_mfcc = n_mfcc
        self.n_fft = n_fft
        self.hop_length = hop_length
        self.n_mels = n_mels

    def pre_emphasis(self, signal, pre_emph_coef=0.97):
        return np.append(signal[0], signal[1:] - pre_emph_coef * signal[:-1])

    def remove_silence(self, y, threshold=0.01):
        energy = librosa.feature.rms(y=y)[0]
        frames = np.nonzero(energy > threshold)
        if frames[0].size:
            y = y[librosa.frames_to_samples(frames[0][0]):librosa.frames_to_samples(frames[0][-1])]
        return y

    def extract_mfcc(self, y):
        y = self.pre_emphasis(y)
        mfcc = librosa.feature.mfcc(y=y, sr=self.sample_rate, n_mfcc=self.n_mfcc,
                                    n_fft=self.n_fft, hop_length=self.hop_length,
                                    n_mels=self.n_mels)
        mfcc = (mfcc - np.mean(mfcc)) / np.std(mfcc)
        return mfcc

    def extract_delta_features(self, mfcc):
        delta = librosa.feature.delta(mfcc)
        delta_delta = librosa.feature.delta(mfcc, order=2)
        combined = np.vstack([mfcc, delta, delta_delta])
        return combined

    def normalize_feature_length(self, features, target_length=50):
        n_features, original_length = features.shape
        x_old = np.linspace(0, 1, original_length)
        x_new = np.linspace(0, 1, target_length)
        interpolated = np.zeros((n_features, target_length))
        for i in range(n_features):
            f = interp1d(x_old, features[i], kind='linear')
            interpolated[i] = f(x_new)
        return interpolated

    def extract_energy(self, y):
        return np.sum(y ** 2)

    def save_mfcc_spectrogram(self, mfcc, title, energy):
        plt.figure(figsize=(8, 3))
        librosa.display.specshow(mfcc, x_axis='time')
        plt.colorbar()
        plt.title(f'MFCC: {title}')
        # Add energy text to the plot
        text_str = f'Energy: {energy:.2f}'
        plt.text(0.02, 0.98, text_str, transform=plt.gca().transAxes, 
                 verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
        plt.tight_layout()
        output_path = os.path.join('mfcc_plot', f'mfcc_{title}.png')
        plt.savefig(output_path)
        plt.close()

# Paths for input and output
input_dir = 'data/preprocessed_recordings'
output_dir = 'data/mfcc_features'
plot_dir = 'mfcc_plot'
os.makedirs(output_dir, exist_ok=True)
os.makedirs(plot_dir, exist_ok=True)

# Extract unique words from filenames
words = set()
for filename in os.listdir(input_dir):
    if filename.endswith('.wav'):
        word = filename.split('_')[0]
        words.add(word)
words = sorted(list(words))

extractor = FeatureExtractor()
word_features = {}

for word in words:
    mfccs = []
    energies = []
    lengths = []
    print(f'\n🔍 Word: {word}')
    
    # Process all files for the current word
    for filename in os.listdir(input_dir):
        if filename.startswith(word + '_') and filename.endswith('.wav'):
            wav_path = os.path.join(input_dir, filename)
            y, sr = librosa.load(wav_path, sr=16000)

            y = extractor.remove_silence(y)
            energy = extractor.extract_energy(y)
            mfcc = extractor.extract_mfcc(y)
            mfcc = extractor.extract_delta_features(mfcc)
            mfcc = extractor.normalize_feature_length(mfcc)

            # Save features to npy file
            npy_filename = filename.replace('.wav', '.npy')
            np.save(os.path.join(output_dir, npy_filename), mfcc)

            # Save MFCC spectrogram
            extractor.save_mfcc_spectrogram(mfcc, filename, energy)

            # Collect statistics
            mfccs.append(mfcc)
            energies.append(energy)
            lengths.append(len(y) / sr)

    # Store for final analysis
    word_features[word] = {
        'mfccs': mfccs,
        'energies': energies,
        'lengths': lengths
    }

    print(f"📏 Avg length: {np.mean(lengths):.2f}s")
    print(f"⚡ Avg energy: {np.mean(energies):.2f}")
# Out:
# 🔍 Word: Bale
# 📏 Avg length: 0.51s
# ⚡ Avg energy: 214.98
#
# 🔍 Word: BesiarAali
# 📏 Avg length: 1.03s
# ⚡ Avg energy: 315.66
#
# 🔍 Word: Kheir
# 📏 Avg length: 0.59s
# ⚡ Avg energy: 202.99
#
# 🔍 Word: Khodahafez
# 📏 Avg length: 0.88s
# ⚡ Avg energy: 262.23
#
# 🔍 Word: Motshakeram
# 📏 Avg length: 0.90s
# ⚡ Avg energy: 245.67
#
# 🔍 Word: Salam
# 📏 Avg length: 0.58s
# ⚡ Avg energy: 167.00
#
# 🔍 Word: kheir
# 📏 Avg length: 0.55s
# ⚡ Avg energy: 175.90

# %% [markdown]
# ### DTW

# %%
import numpy as np
from scipy.spatial.distance import euclidean, cityblock, cosine, correlation
import os
import pandas as pd
import matplotlib.pyplot as plt

class DTWAnalyzer:
    def __init__(self, feature_dir='data/mfcc_features', target_length=50, window_size=0.2, plot_dir='dtw_plots'):
        self.feature_dir = feature_dir
        self.target_length = target_length
        self.window_size = window_size
        self.plot_dir = plot_dir
        # Create plot directory if it doesn't exist
        os.makedirs(self.plot_dir, exist_ok=True)

    def normalize_zscore(self, features):
        """Apply z-score normalization to features."""
        return (features - np.mean(features)) / np.std(features)

    def compute_dtw_distance(self, seq1, seq2, distance_metric='euclidean'):
        """Compute DTW distance and warping path between two sequences with fixed window size."""
        n, m = seq1.shape[1], seq2.shape[1]
        w = int(self.window_size * max(n, m))

        # Initialize cost matrix
        cost_matrix = np.full((n + 1, m + 1), np.inf)
        cost_matrix[0, 0] = 0

        # Initialize path tracking
        path = []

        # Compute cost matrix
        for i in range(1, n + 1):
            for j in range(max(1, i - w), min(m + 1, i + w)):
                if distance_metric == 'euclidean':
                    cost = euclidean(seq1[:, i-1], seq2[:, j-1])
                elif distance_metric == 'manhattan':
                    cost = cityblock(seq1[:, i-1], seq2[:, j-1])
                elif distance_metric == 'cosine':
                    cost = cosine(seq1[:, i-1], seq2[:, j-1])
                elif distance_metric == 'correlation':
                    cost = correlation(seq1[:, i-1], seq2[:, j-1])
                else:
                    raise ValueError("Unsupported distance metric")

                cost_matrix[i, j] = cost + min(
                    cost_matrix[i-1, j],    # Insertion
                    cost_matrix[i, j-1],    # Deletion
                    cost_matrix[i-1, j-1]   # Match
                )

        # Backtrack to find the warping path
        i, j = n, m
        while i > 0 and j > 0:
            path.append((i-1, j-1))
            min_cost = min(cost_matrix[i-1, j], cost_matrix[i, j-1], cost_matrix[i-1, j-1])
            if min_cost == cost_matrix[i-1, j-1]:
                i, j = i-1, j-1
            elif min_cost == cost_matrix[i-1, j]:
                i -= 1
            else:
                j -= 1

        path.reverse()
        return cost_matrix[n, m], path, cost_matrix[1:, 1:]

    def analyze_warping_path(self, path, n, m):
        """Analyze the warping path for statistics and critical points."""
        path = np.array(path)
        lengths = np.sqrt(np.sum(np.diff(path, axis=0)**2, axis=1))
        total_length = np.sum(lengths) if len(lengths) > 0 else 0
        std_dev = np.std(lengths) if len(lengths) > 0 else 0
        diagonal_dev = np.mean(np.abs(path[:, 0] - path[:, 1])) if len(path) > 0 else 0
        turning_points = np.sum(np.abs(np.diff(np.sign(np.diff(path[:, 0] - path[:, 1]))))) / 2 if len(path) > 1 else 0

        # Identify compression and expansion points
        compression_points = []
        expansion_points = []
        for i in range(1, len(path)):
            di, dj = path[i][0] - path[i-1][0], path[i][1] - path[i-1][1]
            if di == 0 and dj > 0:  # Horizontal move (compression)
                compression_points.append(path[i])
            elif dj == 0 and di > 0:  # Vertical move (expansion)
                expansion_points.append(path[i])

        return {
            'total_length': total_length,
            'std_dev': std_dev,
            'diagonal_deviation': diagonal_dev,
            'turning_points': turning_points,
            'compression_points': compression_points,
            'expansion_points': expansion_points,
            'num_compression': len(compression_points),
            'num_expansion': len(expansion_points)
        }

    def plot_cost_matrix(self, cost_matrix, path, word1, word2, idx1, idx2):
        """Plot the cost matrix with DTW path, diagonal line, and critical points."""
        plt.figure(figsize=(8, 6))
        plt.imshow(cost_matrix, origin='lower', cmap='viridis', interpolation='nearest')
        plt.colorbar(label='Cost')
        plt.title(f'DTW Cost Matrix: {word1}_{idx1:02d} vs {word2}_{idx2:02d}')
        plt.xlabel(f'{word2}_{idx2:02d} Frames')
        plt.ylabel(f'{word1}_{idx1:02d} Frames')

        # Plot DTW path
        path = np.array(path)
        plt.plot(path[:, 1], path[:, 0], 'r-', label='DTW Path')

        # Plot diagonal line
        min_len = min(cost_matrix.shape)
        plt.plot(range(min_len), range(min_len), 'k--', label='Diagonal', alpha=0.5)

        # Plot compression and expansion points
        path_stats = self.analyze_warping_path(path, cost_matrix.shape[0], cost_matrix.shape[1])
        if path_stats['compression_points']:
            comp_points = np.array(path_stats['compression_points'])
            plt.scatter(comp_points[:, 1], comp_points[:, 0], c='red', marker='o', s=50, label='Compression Points')
        if path_stats['expansion_points']:
            exp_points = np.array(path_stats['expansion_points'])
            plt.scatter(exp_points[:, 1], exp_points[:, 0], c='blue', marker='^', s=50, label='Expansion Points')

        plt.legend()
        plt.grid(True)
        plt.savefig(os.path.join(self.plot_dir, f'dtw_path_{word1}_{idx1:02d}_vs_{word2}_{idx2:02d}.png'))
        plt.close()

    def compare_features(self, word1, word2, idx1=1, idx2=1):
        """Compare two audio features using multiple metrics and fixed window size."""
        file1 = f"{word1}_{idx1:02d}.npy"
        file2 = f"{word2}_{idx2:02d}.npy"

        try:
            mfcc1 = np.load(os.path.join(self.feature_dir, file1))
            mfcc2 = np.load(os.path.join(self.feature_dir, file2))
        except FileNotFoundError as e:
            print(f"Error: File not found - {e}")
            return None, None

        # Verify shape for 13 MFCC features
        expected_shape = (39, self.target_length)
        if mfcc1.shape != expected_shape or mfcc2.shape != expected_shape:
            print(f"Error: Unexpected shape for {file1}: {mfcc1.shape} or {file2}: {mfcc2.shape}. Expected {expected_shape}.")
            return None, None

        # Apply z-score normalization
        mfcc1 = self.normalize_zscore(mfcc1)
        mfcc2 = self.normalize_zscore(mfcc2)

        # Compute different distance metrics on normalized features
        results = {
            'Euclidean': euclidean(mfcc1.flatten(), mfcc2.flatten()),
            'Manhattan': cityblock(mfcc1.flatten(), mfcc2.flatten()),
            'Cosine': cosine(mfcc1.flatten(), mfcc2.flatten()),
            'Correlation': correlation(mfcc1.flatten(), mfcc2.flatten())
        }

        # Compute DTW with fixed window size
        distance, path, cost_matrix = self.compute_dtw_distance(mfcc1, mfcc2)
        path_stats = self.analyze_warping_path(path, mfcc1.shape[1], mfcc2.shape[1])
        dtw_results = {
            'distance': distance,
            'path': path,
            'cost_matrix': cost_matrix,
            'path_stats': path_stats
        }

        # Plot cost matrix with DTW path
        self.plot_cost_matrix(cost_matrix, path, word1, word2, idx1, idx2)

        return results, dtw_results


# Initialize analyzer with fixed window size
analyzer = DTWAnalyzer(window_size=0.2)

# Define comparisons
comparisons = [
    ('Salam', 'Salam', 1, 2),  # Same word comparison
    ('Salam', 'Bale', 1, 1),   # Different word comparison
    ('Bale', 'Kheir', 1, 1),   # Different word comparison
    ('Bale', 'Motshakeram', 1, 1),      # Additional comparison
    ('BesiarAali', 'BesiarAali', 3, 2),  # Same word comparison
    ('Motshakeram', 'Motshakeram', 1, 2),  # Same word comparison
    ('Salam', 'Motshakeram', 1, 2),  # Same word comparison
    ('BesiarAali', 'BesiarAali', 5, 3),  # Same word comparison
    ('BesiarAali', 'BesiarAali', 3, 2),  # Same word comparison
    ('BesiarAali', 'BesiarAali', 4, 5),  # Same word comparison
    ('BesiarAali', 'BesiarAali', 2, 5),  # Same word comparison
    ('BesiarAali', 'Salam', 3, 2),  # Same word comparison
    ('BesiarAali', 'Motshakeram', 2, 4),  # Same word comparison
    ('Salam', 'Motshakeram', 2, 3),  # Same word comparison
    ('Salam', 'Motshakeram', 1, 3),  # Same word comparison
    ('Salam', 'Motshakeram', 1, 4),  # Same word comparison
    ('Salam', 'Motshakeram', 3, 5),  # Same word comparison
]

# Perform comparisons and collect results
table_data = []
dtw_table_data = []
combined_table_data = []
for word1, word2, idx1, idx2 in comparisons:
    print(f"\n🔍 Comparing {word1}_{idx1:02d} vs {word2}_{idx2:02d}")
    metrics, dtw_results = analyzer.compare_features(word1, word2, idx1, idx2)
    
    if metrics is None or dtw_results is None:
        print(f"Skipping comparison due to missing files or incorrect shape.")
        continue

    # Print standard metrics
    print(f"📏 Standard Metrics: {metrics}")
    
    # Print DTW results
    print(f"📐 DTW (window_size=0.2):")
    print(f"  Distance: {dtw_results['distance']:.2f}")
    print(f"  Path Stats: {dtw_results['path_stats']}")
    print(f"  Diagonal Deviation Analysis: Mean deviation from diagonal is {dtw_results['path_stats']['diagonal_deviation']:.2f}")
    print(f"  Critical Points: {dtw_results['path_stats']['num_compression']} compression points, {dtw_results['path_stats']['num_expansion']} expansion points")

    # Add to standard metrics table
    table_data.append({
        'Word1': word1,
        'Word2': word2,
        'Euclidean': metrics['Euclidean'],
        'Manhattan': metrics['Manhattan'],
        'Cosine': metrics['Cosine'],
        'Correlation': metrics['Correlation']
    })

    # Add to DTW table
    dtw_table_data.append({
        'Word1': word1,
        'Word2': word2,
        'DTW Distance': dtw_results['distance'],
        'Total Length': dtw_results['path_stats']['total_length'],
        'Std Dev': dtw_results['path_stats']['std_dev'],
        'Diagonal Deviation': dtw_results['path_stats']['diagonal_deviation'],
        'Turning Points': dtw_results['path_stats']['turning_points'],
        'Compression Points': dtw_results['path_stats']['num_compression'],
        'Expansion Points': dtw_results['path_stats']['num_expansion']
    })

    # Add to combined table
    combined_table_data.append({
        'Word1': word1,
        'Word2': word2,
        'Euclidean': metrics['Euclidean'],
        'Manhattan': metrics['Manhattan'],
        'Cosine': metrics['Cosine'],
        'Correlation': metrics['Correlation'],
        'DTW Distance': dtw_results['distance'],
        'Total Length': dtw_results['path_stats']['total_length'],
        'Std Dev': dtw_results['path_stats']['std_dev'],
        'Diagonal Deviation': dtw_results['path_stats']['diagonal_deviation'],
        'Turning Points': dtw_results['path_stats']['turning_points'],
        'Compression Points': dtw_results['path_stats']['num_compression'],
        'Expansion Points': dtw_results['path_stats']['num_expansion']
    })

# Print standard metrics table
print("\n📊 Standard Metrics Comparison Table:")
print("| Word1 | Word2 | Euclidean | Manhattan | Cosine | Correlation |")
print("|-------|-------|-----------|-----------|--------|-------------|")
for row in table_data:
    print(f"| {row['Word1']} | {row['Word2']} | {row['Euclidean']:8.2f} | {row['Manhattan']:8.2f} | {row['Cosine']:6.2f} | {row['Correlation']:6.2f} |")

# Print DTW results table
print("\n📊 DTW Results Comparison Table:")
print("| Word1 | Word2 | DTW Distance | Total Length | Std Dev | Diagonal Deviation | Turning Points | Compression Points | Expansion Points |")
print("|-------|-------|--------------|--------------|---------|--------------------|----------------|--------------------|------------------|")
for row in dtw_table_data:
    print(f"| {row['Word1']} | {row['Word2']} | {row['DTW Distance']:11.2f} | {row['Total Length']:11.2f} | {row['Std Dev']:7.2f} | {row['Diagonal Deviation']:17.2f} | {row['Turning Points']:13.2f} | {row['Compression Points']:17.0f} | {row['Expansion Points']:15.0f} |")

# Save tables to CSV files
if table_data:
    df_standard = pd.DataFrame(table_data)
    df_standard.to_csv('dtw/standard_metrics.csv', index=False)
    print("\nStandard metrics saved to standard_metrics.csv")
else:
    print("\nNo standard metrics data to save to CSV.")

if dtw_table_data:
    df_dtw = pd.DataFrame(dtw_table_data)
    df_dtw.to_csv('dtw/dtw_results.csv', index=False)
    print("DTW results saved to dtw_results.csv")
else:
    print("No DTW results data to save to CSV.")

if combined_table_data:
    df_combined = pd.DataFrame(combined_table_data)
    df_combined.to_csv('dtw/combined_metrics.csv', index=False)
    print("Combined metrics saved to combined_metrics.csv")
else:
    print("No combined metrics data to save to CSV.")
# Out:
# 🔍 Comparing Salam_01 vs Salam_02
# 📏 Standard Metrics: {'Euclidean': 8.59812952224131, 'Manhattan': np.float64(190.54705987301293), 'Cosine': np.float64(0.018955854174677045), 'Correlation': np.float64(0.018955854174677045)}
# 📐 DTW (window_size=0.2):
#   Distance: 55.72
#   Path Stats: {'total_length': np.float64(69.88225099390857), 'std_dev': np.float64(0.08116894978836614), 'diagonal_deviation': np.float64(0.5882352941176471), 'turning_points': np.float64(1.5), 'compression_points': [array([30, 30])], 'expansion_points': [array([1, 0])], 'num_compression': 1, 'num_expansion': 1}
#   Diagonal Deviation Analysis: Mean deviation from diagonal is 0.59
#   Critical Points: 1 compression points, 1 expansion points
#
# 🔍 Comparing Salam_01 vs Bale_01
# 📏 Standard Metrics: {'Euclidean': 22.969408787441722, 'Manhattan': np.float64(455.02153657559154), 'Cosine': np.float64(0.13528044616528379), 'Correlation': np.float64(0.13528044616528379)}
# 📐 DTW (window_size=0.2):
#   Distance: 136.82
#   Path Stats: {'total_length': np.float64(75.1543289325507), 'std_dev': np.float64(0.19607381743601895), 'diagonal_deviation': np.float64(7.2), 'turning_points': np.float64(3.5), 'compression_points': [array([47, 38]), array([47, 39]), array([47, 40]), array([47, 41]), array([47, 42]), array([47, 43]), array([47, 44]), array([47, 45]), array([47, 46]), array([47, 47])], 'expansion_points': [array([1, 0]), array([2, 0]), array([3, 0]), array([9, 5]), array([10,  5]), array([11,  5]), array([12,  5]), array([14,  6]), array([15,  6]), array([16,  6])], 'num_compression': 10, 'num_expansion': 10}
#   Diagonal Deviation Analysis: Mean deviation from diagonal is 7.20
#   Critical Points: 10 compression points, 10 expansion points
#
# 🔍 Comparing Bale_01 vs Kheir_01
# 📏 Standard Metrics: {'Euclidean': 21.330302722440834, 'Manhattan': np.float64(472.0012862888525), 'Cosine': np.float64(0.11666200364896562), 'Correlation': np.float64(0.11666200364896562)}
# 📐 DTW (window_size=0.2):
#   Distance: 144.04
#   Path Stats: {'total_length': np.float64(72.22539674441617), 'std_dev': np.float64(0.16090031453665968), 'diagonal_deviation': np.float64(3.618181818181818), 'turning_points': np.float64(2.5), 'compression_points': [array([0, 1]), array([0, 2]), array([12, 15]), array([12, 16]), array([12, 17])], 'expansion_points': [array([43, 47]), array([44, 47]), array([45, 47]), array([46, 47]), array([47, 47])], 'num_compression': 5, 'num_expansion': 5}
#   Diagonal Deviation Analysis: Mean deviation from diagonal is 3.62
#   Critical Points: 5 compression points, 5 expansion points
#
# 🔍 Comparing Bale_01 vs Motshakeram_01
# 📏 Standard Metrics: {'Euclidean': 25.15658222705403, 'Manhattan': np.float64(483.0840970644267), 'Cosine': np.float64(0.1622701613709051), 'Correlation': np.float64(0.1622701613709051)}
# 📐 DTW (window_size=0.2):
#   Distance: 159.11
#   Path Stats: {'total_length': np.float64(74.5685424949238), 'std_dev': np.float64(0.19162958951763928), 'diagonal_deviation': np.float64(3.135593220338983), 'turning_points': np.float64(3.5), 'compression_points': [array([0, 1]), array([0, 2]), array([ 8, 11]), array([ 8, 12]), array([ 8, 13]), array([ 8, 14]), array([ 8, 15]), array([ 8, 16]), array([10, 19])], 'expansion_points': [array([19, 27]), array([20, 27]), array([21, 27]), array([22, 27]), array([23, 27]), array([24, 27]), array([25, 27]), array([26, 27]), array([27, 27])], 'num_compression': 9, 'num_expansion': 9}
#   Diagonal Deviation Analysis: Mean deviation from diagonal is 3.14
#   Critical Points: 9 compression points, 9 expansion points
#
# 🔍 Comparing BesiarAali_03 vs BesiarAali_02
# 📏 Standard Metrics: {'Euclidean': 4.532393455703507, 'Manhattan': np.float64(115.65064130783091), 'Cosine': np.float64(0.005267330881359444), 'Correlation': np.float64(0.005267330881359444)}
# 📐 DTW (window_size=0.2):
#   Distance: 29.27
#   Path Stats: {'total_length': np.float64(70.46803743153546), 'std_dev': np.float64(0.11136098487967118), 'diagonal_deviation': np.float64(0.34615384615384615), 'turning_points': np.float64(4.0), 'compression_points': [array([16, 16]), array([34, 35])], 'expansion_points': [array([11, 10]), array([46, 46])], 'num_compression': 2, 'num_expansion': 2}
#   Diagonal Deviation Analysis: Mean deviation from diagonal is 0.35
#   Critical Points: 2 compression points, 2 expansion points
#
# 🔍 Comparing Motshakeram_01 vs Motshakeram_02
# 📏 Standard Metrics: {'Euclidean': 5.492591957415893, 'Manhattan': np.float64(130.24467347701625), 'Cosine': np.float64(0.0077355298488898105), 'Correlation': np.float64(0.0077355298488898105)}
# 📐 DTW (window_size=0.2):
#   Distance: 35.35
#   Path Stats: {'total_length': np.float64(69.88225099390857), 'std_dev': np.float64(0.08116894978836614), 'diagonal_deviation': np.float64(0.43137254901960786), 'turning_points': np.float64(2.0), 'compression_points': [array([26, 27])], 'expansion_points': [array([48, 48])], 'num_compression': 1, 'num_expansion': 1}
#   Diagonal Deviation Analysis: Mean deviation from diagonal is 0.43
#   Critical Points: 1 compression points, 1 expansion points
#
# 🔍 Comparing Salam_01 vs Motshakeram_02
# 📏 Standard Metrics: {'Euclidean': 14.395042932027668, 'Manhattan': np.float64(352.7375631055713), 'Cosine': np.float64(0.05313263102946686), 'Correlation': np.float64(0.05313263102946686)}
# 📐 DTW (window_size=0.2):
#   Distance: 92.41
#   Path Stats: {'total_length': np.float64(73.39696961966999), 'std_dev': np.float64(0.17935973380357528), 'diagonal_deviation': np.float64(4.385964912280702), 'turning_points': np.float64(5.5), 'compression_points': [array([6, 6]), array([6, 7]), array([6, 8]), array([6, 9]), array([ 6, 10]), array([ 6, 11]), array([ 6, 12])], 'expansion_points': [array([1, 0]), array([40, 45]), array([42, 46]), array([43, 46]), array([45, 47]), array([47, 48]), array([48, 48])], 'num_compression': 7, 'num_expansion': 7}
#   Diagonal Deviation Analysis: Mean deviation from diagonal is 4.39
#   Critical Points: 7 compression points, 7 expansion points
#
# 🔍 Comparing BesiarAali_05 vs BesiarAali_03
# 📏 Standard Metrics: {'Euclidean': 4.541316895171634, 'Manhattan': np.float64(113.91030403266069), 'Cosine': np.float64(0.005288092087787466), 'Correlation': np.float64(0.005288092087787466)}
# 📐 DTW (window_size=0.2):
#   Distance: 27.58
#   Path Stats: {'total_length': np.float64(70.46803743153546), 'std_dev': np.float64(0.11136098487967117), 'diagonal_deviation': np.float64(0.6730769230769231), 'turning_points': np.float64(4.0), 'compression_points': [array([12, 12]), array([48, 48])], 'expansion_points': [array([5, 4]), array([22, 21])], 'num_compression': 2, 'num_expansion': 2}
#   Diagonal Deviation Analysis: Mean deviation from diagonal is 0.67
#   Critical Points: 2 compression points, 2 expansion points
#
# 🔍 Comparing BesiarAali_03 vs BesiarAali_02
# 📏 Standard Metrics: {'Euclidean': 4.532393455703507, 'Manhattan': np.float64(115.65064130783091), 'Cosine': np.float64(0.005267330881359444), 'Correlation': np.float64(0.005267330881359444)}
# 📐 DTW (window_size=0.2):
#   Distance: 29.27
#   Path Stats: {'total_length': np.float64(70.46803743153546), 'std_dev': np.float64(0.11136098487967118), 'diagonal_deviation': np.float64(0.34615384615384615), 'turning_points': np.float64(4.0), 'compression_points': [array([16, 16]), array([34, 35])], 'expansion_points': [array([11, 10]), array([46, 46])], 'num_compression': 2, 'num_expansion': 2}
#   Diagonal Deviation Analysis: Mean deviation from diagonal is 0.35
#   Critical Points: 2 compression points, 2 expansion points
#
# 🔍 Comparing BesiarAali_04 vs BesiarAali_05
# 📏 Standard Metrics: {'Euclidean': 5.999000678579549, 'Manhattan': np.float64(145.72601502258314), 'Cosine': np.float64(0.009227694651692375), 'Correlation': np.float64(0.009227694651692375)}
# 📐 DTW (window_size=0.2):
#   Distance: 38.36
#   Path Stats: {'total_length': np.float64(70.46803743153546), 'std_dev': np.float64(0.11136098487967117), 'diagonal_deviation': np.float64(0.6923076923076923), 'turning_points': np.float64(3.0), 'compression_points': [array([3, 3]), array([16, 17])], 'expansion_points': [array([1, 0]), array([49, 49])], 'num_compression': 2, 'num_expansion': 2}
#   Diagonal Deviation Analysis: Mean deviation from diagonal is 0.69
#   Critical Points: 2 compression points, 2 expansion points
#
# 🔍 Comparing BesiarAali_02 vs BesiarAali_05
# 📏 Standard Metrics: {'Euclidean': 4.5171109432547505, 'Manhattan': np.float64(118.14258393029057), 'Cosine': np.float64(0.005231869557351776), 'Correlation': np.float64(0.005231869557351776)}
# 📐 DTW (window_size=0.2):
#   Distance: 29.69
#   Path Stats: {'total_length': np.float64(69.88225099390857), 'std_dev': np.float64(0.08116894978836615), 'diagonal_deviation': np.float64(0.1568627450980392), 'turning_points': np.float64(2.0), 'compression_points': [array([4, 5])], 'expansion_points': [array([12, 12])], 'num_compression': 1, 'num_expansion': 1}
#   Diagonal Deviation Analysis: Mean deviation from diagonal is 0.16
#   Critical Points: 1 compression points, 1 expansion points
#
# 🔍 Comparing BesiarAali_03 vs Salam_02
# 📏 Standard Metrics: {'Euclidean': 16.852614631221623, 'Manhattan': np.float64(386.01788922190036), 'Cosine': np.float64(0.072823235873965), 'Correlation': np.float64(0.072823235873965)}
# 📐 DTW (window_size=0.2):
#   Distance: 114.60
#   Path Stats: {'total_length': np.float64(69.29646455628166), 'std_dev': np.float64(0.0), 'diagonal_deviation': np.float64(0.0), 'turning_points': np.float64(0.0), 'compression_points': [], 'expansion_points': [], 'num_compression': 0, 'num_expansion': 0}
#   Diagonal Deviation Analysis: Mean deviation from diagonal is 0.00
#   Critical Points: 0 compression points, 0 expansion points
#
# 🔍 Comparing BesiarAali_02 vs Motshakeram_04
# 📏 Standard Metrics: {'Euclidean': 16.924364148946097, 'Manhattan': np.float64(412.62790280755706), 'Cosine': np.float64(0.07344464149900742), 'Correlation': np.float64(0.07344464149900742)}
# 📐 DTW (window_size=0.2):
#   Distance: 114.62
#   Path Stats: {'total_length': np.float64(69.88225099390857), 'std_dev': np.float64(0.08116894978836614), 'diagonal_deviation': np.float64(0.9607843137254902), 'turning_points': np.float64(1.0), 'compression_points': [array([0, 1])], 'expansion_points': [array([49, 49])], 'num_compression': 1, 'num_expansion': 1}
#   Diagonal Deviation Analysis: Mean deviation from diagonal is 0.96
#   Critical Points: 1 compression points, 1 expansion points
#
# 🔍 Comparing Salam_02 vs Motshakeram_03
# 📏 Standard Metrics: {'Euclidean': 16.022019749223777, 'Manhattan': np.float64(384.3673444719377), 'Cosine': np.float64(0.06582182483192789), 'Correlation': np.float64(0.06582182483192789)}
# 📐 DTW (window_size=0.2):
#   Distance: 108.66
#   Path Stats: {'total_length': np.float64(72.81118318204308), 'std_dev': np.float64(0.1710749713675805), 'diagonal_deviation': np.float64(4.517857142857143), 'turning_points': np.float64(4.5), 'compression_points': [array([0, 1]), array([6, 8]), array([6, 9]), array([ 6, 10]), array([ 6, 11]), array([ 6, 12])], 'expansion_points': [array([41, 46]), array([43, 47]), array([44, 47]), array([45, 47]), array([47, 48]), array([48, 48])], 'num_compression': 6, 'num_expansion': 6}
#   Diagonal Deviation Analysis: Mean deviation from diagonal is 4.52
#   Critical Points: 6 compression points, 6 expansion points
#
# 🔍 Comparing Salam_01 vs Motshakeram_03
# 📏 Standard Metrics: {'Euclidean': 13.995305725583979, 'Manhattan': np.float64(349.61084489986155), 'Cosine': np.float64(0.0502227134237353), 'Correlation': np.float64(0.0502227134237353)}
# 📐 DTW (window_size=0.2):
#   Distance: 87.76
#   Path Stats: {'total_length': np.float64(73.9827560572969), 'std_dev': np.float64(0.18612357197926796), 'diagonal_deviation': np.float64(5.396551724137931), 'turning_points': np.float64(7.5), 'compression_points': [array([6, 7]), array([6, 8]), array([6, 9]), array([ 6, 10]), array([ 6, 11]), array([ 6, 12]), array([ 7, 14]), array([18, 26])], 'expansion_points': [array([38, 45]), array([40, 46]), array([41, 46]), array([42, 46]), array([44, 47]), array([45, 47]), array([47, 48]), array([49, 49])], 'num_compression': 8, 'num_expansion': 8}
#   Diagonal Deviation Analysis: Mean deviation from diagonal is 5.40
#   Critical Points: 8 compression points, 8 expansion points
#
# 🔍 Comparing Salam_01 vs Motshakeram_04
# 📏 Standard Metrics: {'Euclidean': 16.282894276284242, 'Manhattan': np.float64(373.82573274570524), 'Cosine': np.float64(0.06798272974683361), 'Correlation': np.float64(0.06798272974683361)}
# 📐 DTW (window_size=0.2):
#   Distance: 100.12
#   Path Stats: {'total_length': np.float64(73.98275605729691), 'std_dev': np.float64(0.18612357197926796), 'diagonal_deviation': np.float64(5.879310344827586), 'turning_points': np.float64(4.5), 'compression_points': [array([5, 6]), array([5, 7]), array([5, 8]), array([5, 9]), array([ 5, 10]), array([ 5, 11]), array([ 5, 12]), array([ 5, 13])], 'expansion_points': [array([39, 46]), array([40, 46]), array([42, 47]), array([44, 48]), array([45, 48]), array([46, 48]), array([48, 49]), array([49, 49])], 'num_compression': 8, 'num_expansion': 8}
#   Diagonal Deviation Analysis: Mean deviation from diagonal is 5.88
#   Critical Points: 8 compression points, 8 expansion points
#
# 🔍 Comparing Salam_03 vs Motshakeram_05
# 📏 Standard Metrics: {'Euclidean': 16.70309224067625, 'Manhattan': np.float64(389.046518822705), 'Cosine': np.float64(0.0715367411283433), 'Correlation': np.float64(0.0715367411283433)}
# 📐 DTW (window_size=0.2):
#   Distance: 104.04
#   Path Stats: {'total_length': np.float64(74.5685424949238), 'std_dev': np.float64(0.19162958951763928), 'diagonal_deviation': np.float64(6.593220338983051), 'turning_points': np.float64(5.5), 'compression_points': [array([4, 5]), array([4, 6]), array([4, 7]), array([4, 8]), array([4, 9]), array([ 4, 10]), array([ 4, 11]), array([ 4, 12]), array([ 4, 13])], 'expansion_points': [array([37, 45]), array([39, 46]), array([40, 46]), array([42, 47]), array([43, 47]), array([45, 48]), array([46, 48]), array([48, 49]), array([49, 49])], 'num_compression': 9, 'num_expansion': 9}
#   Diagonal Deviation Analysis: Mean deviation from diagonal is 6.59
#   Critical Points: 9 compression points, 9 expansion points
#
# 📊 Standard Metrics Comparison Table:
# | Word1 | Word2 | Euclidean | Manhattan | Cosine | Correlation |
# |-------|-------|-----------|-----------|--------|-------------|
# | Salam | Salam |     8.60 |   190.55 |   0.02 |   0.02 |
# | Salam | Bale |    22.97 |   455.02 |   0.14 |   0.14 |
# | Bale | Kheir |    21.33 |   472.00 |   0.12 |   0.12 |
# | Bale | Motshakeram |    25.16 |   483.08 |   0.16 |   0.16 |
# | BesiarAali | BesiarAali |     4.53 |   115.65 |   0.01 |   0.01 |
# | Motshakeram | Motshakeram |     5.49 |   130.24 |   0.01 |   0.01 |
# | Salam | Motshakeram |    14.40 |   352.74 |   0.05 |   0.05 |
# | BesiarAali | BesiarAali |     4.54 |   113.91 |   0.01 |   0.01 |
# | BesiarAali | BesiarAali |     4.53 |   115.65 |   0.01 |   0.01 |
# | BesiarAali | BesiarAali |     6.00 |   145.73 |   0.01 |   0.01 |
# | BesiarAali | BesiarAali |     4.52 |   118.14 |   0.01 |   0.01 |
# | BesiarAali | Salam |    16.85 |   386.02 |   0.07 |   0.07 |
# | BesiarAali | Motshakeram |    16.92 |   412.63 |   0.07 |   0.07 |
# | Salam | Motshakeram |    16.02 |   384.37 |   0.07 |   0.07 |
# | Salam | Motshakeram |    14.00 |   349.61 |   0.05 |   0.05 |
# | Salam | Motshakeram |    16.28 |   373.83 |   0.07 |   0.07 |
# | Salam | Motshakeram |    16.70 |   389.05 |   0.07 |   0.07 |
#
# 📊 DTW Results Comparison Table:
# | Word1 | Word2 | DTW Distance | Total Length | Std Dev | Diagonal Deviation | Turning Points | Compression Points | Expansion Points |
# |-------|-------|--------------|--------------|---------|--------------------|----------------|--------------------|------------------|
# | Salam | Salam |       55.72 |       69.88 |    0.08 |              0.59 |          1.50 |                 1 |               1 |
# | Salam | Bale |      136.82 |       75.15 |    0.20 |              7.20 |          3.50 |                10 |              10 |
# | Bale | Kheir |      144.04 |       72.23 |    0.16 |              3.62 |          2.50 |                 5 |               5 |
# | Bale | Motshakeram |      159.11 |       74.57 |    0.19 |              3.14 |          3.50 |                 9 |               9 |
# | BesiarAali | BesiarAali |       29.27 |       70.47 |    0.11 |              0.35 |          4.00 |                 2 |               2 |
# | Motshakeram | Motshakeram |       35.35 |       69.88 |    0.08 |              0.43 |          2.00 |                 1 |               1 |
# | Salam | Motshakeram |       92.41 |       73.40 |    0.18 |              4.39 |          5.50 |                 7 |               7 |
# | BesiarAali | BesiarAali |       27.58 |       70.47 |    0.11 |              0.67 |          4.00 |                 2 |               2 |
# | BesiarAali | BesiarAali |       29.27 |       70.47 |    0.11 |              0.35 |          4.00 |                 2 |               2 |
# | BesiarAali | BesiarAali |       38.36 |       70.47 |    0.11 |              0.69 |          3.00 |                 2 |               2 |
# | BesiarAali | BesiarAali |       29.69 |       69.88 |    0.08 |              0.16 |          2.00 |                 1 |               1 |
# | BesiarAali | Salam |      114.60 |       69.30 |    0.00 |              0.00 |          0.00 |                 0 |               0 |
# | BesiarAali | Motshakeram |      114.62 |       69.88 |    0.08 |              0.96 |          1.00 |                 1 |               1 |
# | Salam | Motshakeram |      108.66 |       72.81 |    0.17 |              4.52 |          4.50 |                 6 |               6 |
# | Salam | Motshakeram |       87.76 |       73.98 |    0.19 |              5.40 |          7.50 |                 8 |               8 |
# | Salam | Motshakeram |      100.12 |       73.98 |    0.19 |              5.88 |          4.50 |                 8 |               8 |
# | Salam | Motshakeram |      104.04 |       74.57 |    0.19 |              6.59 |          5.50 |                 9 |               9 |
#
# Standard metrics saved to standard_metrics.csv
# DTW results saved to dtw_results.csv
# Combined metrics saved to combined_metrics.csv

# %%
import numpy as np
import pickle
import os
import pandas as pd
from scipy.spatial.distance import euclidean, cityblock, cosine, correlation
import random

class DTWBasedASR:
    def __init__(self, feature_dir='data/mfcc_features', target_length=50, window_size=0.2):
        self.feature_dir = feature_dir
        self.target_length = target_length
        self.window_size = window_size
        self.templates = {}  # Dictionary to store training templates
        self.word_list = []

    def normalize_zscore(self, features):
        """Apply z-score normalization to features."""
        return (features - np.mean(features)) / np.std(features)

    def compute_dtw_distance(self, seq1, seq2, distance_metric='euclidean'):
        """Compute DTW distance between two sequences with fixed window size."""
        n, m = seq1.shape[1], seq2.shape[1]
        w = int(self.window_size * max(n, m))

        # Initialize cost matrix
        cost_matrix = np.full((n + 1, m + 1), np.inf)
        cost_matrix[0, 0] = 0

        for i in range(1, n + 1):
            for j in range(max(1, i - w), min(m + 1, i + w)):
                if distance_metric == 'euclidean':
                    cost = euclidean(seq1[:, i-1], seq2[:, j-1])
                elif distance_metric == 'manhattan':
                    cost = cityblock(seq1[:, i-1], seq2[:, j-1])
                elif distance_metric == 'cosine':
                    cost = cosine(seq1[:, i-1], seq2[:, j-1])
                elif distance_metric == 'correlation':
                    cost = correlation(seq1[:, i-1], seq2[:, j-1])
                else:
                    raise ValueError("Unsupported distance metric")

                cost_matrix[i, j] = cost + min(
                    cost_matrix[i-1, j],    # Insertion
                    cost_matrix[i, j-1],    # Deletion
                    cost_matrix[i-1, j-1]   # Match
                )

        return cost_matrix[n, m]

    def compute_metrics(self, seq1, seq2):
        """Compute Euclidean, Manhattan, Cosine, and Correlation distances."""
        seq1_flat = seq1.flatten()
        seq2_flat = seq2.flatten()
        return {
            'Euclidean': euclidean(seq1_flat, seq2_flat),
            'Manhattan': cityblock(seq1_flat, seq2_flat),
            'Cosine': cosine(seq1_flat, seq2_flat),
            'Correlation': correlation(seq1_flat, seq2_flat)
        }

    def train(self, training_data):
        """Train the system by loading MFCC features from .npy files."""
        self.templates = {}
        for word in training_data:
            self.templates[word] = []
            for sample in training_data[word]:
                npy_path = os.path.join(self.feature_dir, sample)
                try:
                    mfcc = np.load(npy_path)
                    if mfcc.shape != (39, self.target_length):
                        print(f"Warning: Skipping {npy_path} due to incorrect shape {mfcc.shape}")
                        continue
                    self.templates[word].append(self.normalize_zscore(mfcc))
                except FileNotFoundError:
                    print(f"Error: File {npy_path} not found")
                    continue
        print("Training completed.")

    def predict(self, test_sample):
        """Predict the word for a test sample using DTW distance."""
        npy_path = os.path.join(self.feature_dir, test_sample)
        try:
            mfcc = np.load(npy_path)
            if mfcc.shape != (39, self.target_length):
                print(f"Error: Incorrect shape for {npy_path}: {mfcc.shape}")
                return None, None, None
            mfcc = self.normalize_zscore(mfcc)
        except FileNotFoundError:
            print(f"Error: File {npy_path} not found")
            return None, None, None

        distances = {}
        for word in self.templates:
            distances[word] = []
            for template in self.templates[word]:
                distance = self.compute_dtw_distance(mfcc, template)
                distances[word].append(distance)

        # Compute average distance per word
        avg_distances = {word: np.mean(dists) for word, dists in distances.items()}
        
        # Find the word with minimum average distance
        predicted_word = min(avg_distances, key=avg_distances.get)
        
        # Compute confidence as normalized inverse distance
        total_dist = np.sum([1/d for d in avg_distances.values() if d != 0])
        confidence = (1 / avg_distances[predicted_word]) / total_dist if total_dist != 0 else 1.0
        
        return predicted_word, confidence, avg_distances

    def compare_all_pairs(self, training_data):
        """Compare all pairs of training samples using multiple metrics."""
        table_data = []
        for word1 in training_data:
            for word2 in training_data:
                for sample1 in training_data[word1]:
                    for sample2 in training_data[word2]:
                        npy_path1 = os.path.join(self.feature_dir, sample1)
                        npy_path2 = os.path.join(self.feature_dir, sample2)
                        try:
                            mfcc1 = np.load(npy_path1)
                            mfcc2 = np.load(npy_path2)
                            if mfcc1.shape != (39, self.target_length) or mfcc2.shape != (39, self.target_length):
                                print(f"Warning: Skipping pair {sample1} vs {sample2} due to incorrect shape")
                                continue
                            mfcc1 = self.normalize_zscore(mfcc1)
                            mfcc2 = self.normalize_zscore(mfcc2)
                            metrics = self.compute_metrics(mfcc1, mfcc2)
                            table_data.append({
                                'Word1': word1,
                                'Word2': word2,
                                'Sample1': sample1,
                                'Sample2': sample2,
                                'Euclidean': metrics['Euclidean'],
                                'Manhattan': metrics['Manhattan'],
                                'Cosine': metrics['Cosine'],
                                'Correlation': metrics['Correlation']
                            })
                        except FileNotFoundError:
                            print(f"Error: File not found for {sample1} or {sample2}")
                            continue
        return table_data

    def save_model(self, path):
        """Save the trained templates to a file."""
        os.makedirs(os.path.dirname(path), exist_ok=True)
        with open(path, 'wb') as f:
            pickle.dump(self.templates, f)
        print(f"Model saved to {path}")

    def load_model(self, path):
        """Load trained templates from a file."""
        with open(path, 'rb') as f:
            self.templates = pickle.load(f)
        print(f"Model loaded from {path}")

# Dynamically create training and test data with 60/40 split
feature_dir = 'data/mfcc_features'
all_files = [f for f in os.listdir(feature_dir) if f.endswith('.npy')]

# Extract unique words
words = set()
for f in all_files:
    word = f.split('_')[0]
    words.add(word)
words = sorted(list(words))

# Organize files by word
word_files = {word: [] for word in words}
for f in all_files:
    word = f.split('_')[0]
    word_files[word].append(f)

# Split into 60% training and 40% testing
training_data = {}
test_data = {}
for word, files in word_files.items():
    random.shuffle(files)  # Randomize the order
    total_samples = len(files)
    train_count = int(total_samples * 0.6)  # 60% for training
    train_files = files[:train_count]
    test_files = files[train_count:]  # 40% for testing
    training_data[word] = train_files
    test_data[word] = test_files
    print(f"Word: {word}, Total samples: {total_samples}, Training: {len(train_files)}, Testing: {len(test_files)}")

# Initialize and train the system
asr_system = DTWBasedASR(feature_dir='data/mfcc_features')
asr_system.word_list = words
asr_system.train(training_data)
asr_system.save_model('model_res/dtw_asr_model.pkl')

# Test and evaluate
results = []
confidences = []
confusion_matrix = {word: {w: 0 for w in words} for word in words}
word_lengths = {
    'Salam': 5,
    'Bale': 4,
    'BesiarAali': 10,
    'Kheir': 5,
    'Khodahafez': 10,
    'Motshakeram': 10
}

for word in test_data:
    for sample in test_data[word]:
        prediction, confidence, distances = asr_system.predict(sample)
        if prediction is None:
            print(f"Skipping {sample} due to error in prediction")
            continue
        results.append({
            'True': word,
            'Predicted': prediction,
            'Confidence': confidence,
            'Sample': sample
        })
        confidences.append(confidence)
        confusion_matrix[word][prediction] += 1
        print(f"True: {word}, Predicted: {prediction}, Confidence: {confidence:.3f}")

# Calculate overall accuracy
correct = sum(1 for r in results if r['True'] == r['Predicted'])
total = len(results)
overall_accuracy = correct / total if total > 0 else 0
print(f"\nOverall Model Accuracy: {overall_accuracy:.3f} ({correct}/{total})")

# Calculate per-word accuracy
per_word_accuracy = {}
for word in test_data:
    correct_word = sum(1 for r in results if r['True'] == word and r['True'] == r['Predicted'])
    total_word = len(test_data[word])
    per_word_accuracy[word] = correct_word / total_word if total_word > 0 else 0
    print(f"Accuracy for {word}: {per_word_accuracy[word]:.3f} ({correct_word}/{total_word})")

# Confidence distribution
print("\nConfidence Distribution:")
print(f"Average Confidence: {np.mean(confidences):.3f}")
print(f"Max Confidence: {np.max(confidences):.3f}")
print(f"Min Confidence: {np.min(confidences):.3f}")

# Analyze highest confidence word
max_confidence_result = max(results, key=lambda x: x['Confidence'])
print(f"\nWord with highest confidence: {max_confidence_result['True']} (Predicted: {max_confidence_result['Predicted']}, Confidence: {max_confidence_result['Confidence']:.3f})")

# Analyze word length vs accuracy
print("\nWord Length vs Accuracy:")
for word, acc in per_word_accuracy.items():
    print(f"{word} (length: {word_lengths.get(word, len(word))}): Accuracy = {acc:.3f}")

# Save confusion matrix to CSV
os.makedirs('model_res', exist_ok=True)
confusion_df = pd.DataFrame(confusion_matrix)
confusion_df.to_csv('model_res/confusion_matrix.csv')
print("\nConfusion matrix saved to model_res/confusion_matrix.csv")

# Save results to CSV
results_df = pd.DataFrame(results)
results_df.to_csv('model_res/test_results.csv')
print("Test results saved to model_res/test_results.csv")

# Save overall accuracy to CSV
accuracy_data = [{'Overall Accuracy': overall_accuracy, 'Correct Predictions': correct, 'Total Predictions': total}]
accuracy_df = pd.DataFrame(accuracy_data)
accuracy_df.to_csv('model_res/overall_accuracy.csv', index=False)
print("Overall accuracy saved to model_res/overall_accuracy.csv")

# Compare all pairs of training samples
metrics_table = asr_system.compare_all_pairs(training_data)
metrics_df = pd.DataFrame(metrics_table)
metrics_df.to_csv('model_res/metrics_comparison.csv', index=False)
print("\nMetrics comparison table saved to model_res/metrics_comparison.csv")

# Print metrics table
print("\nMetrics Comparison Table:")
print("| Word1 | Word2 | Sample1 | Sample2 | Euclidean | Manhattan | Cosine | Correlation |")
print("|-------|-------|---------|---------|-----------|-----------|--------|-------------|")
for row in metrics_table:
    print(f"| {row['Word1']} | {row['Word2']} | {row['Sample1']} | {row['Sample2']} | {row['Euclidean']:8.2f} | {row['Manhattan']:8.2f} | {row['Cosine']:6.2f} | {row['Correlation']:6.2f} |")
# Out:
# Word: Bale, Total samples: 15, Training: 9, Testing: 6
# Word: BesiarAali, Total samples: 14, Training: 8, Testing: 6
# Word: Kheir, Total samples: 15, Training: 9, Testing: 6
# Word: Khodahafez, Total samples: 10, Training: 6, Testing: 4
# Word: Motshakeram, Total samples: 15, Training: 9, Testing: 6
# Word: Salam, Total samples: 15, Training: 9, Testing: 6
# Training completed.
# Model saved to model_res/dtw_asr_model.pkl
# True: Bale, Predicted: Bale, Confidence: 0.210
# True: Bale, Predicted: Bale, Confidence: 0.210
# True: Bale, Predicted: Bale, Confidence: 0.213
# True: Bale, Predicted: Bale, Confidence: 0.230
# True: Bale, Predicted: Bale, Confidence: 0.217
# True: Bale, Predicted: Bale, Confidence: 0.202
# True: BesiarAali, Predicted: BesiarAali, Confidence: 0.257
# True: BesiarAali, Predicted: BesiarAali, Confidence: 0.267
# True: BesiarAali, Predicted: BesiarAali, Confidence: 0.272
# True: BesiarAali, Predicted: BesiarAali, Confidence: 0.248
# True: BesiarAali, Predicted: BesiarAali, Confidence: 0.241
# True: BesiarAali, Predicted: BesiarAali, Confidence: 0.265
# True: Kheir, Predicted: Kheir, Confidence: 0.240
# True: Kheir, Predicted: Kheir, Confidence: 0.252
# True: Kheir, Predicted: Kheir, Confidence: 0.252
# True: Kheir, Predicted: Kheir, Confidence: 0.239
# True: Kheir, Predicted: Kheir, Confidence: 0.285
# True: Kheir, Predicted: Kheir, Confidence: 0.238
# True: Khodahafez, Predicted: Khodahafez, Confidence: 0.305
# True: Khodahafez, Predicted: Khodahafez, Confidence: 0.296
# True: Khodahafez, Predicted: Khodahafez, Confidence: 0.280
# True: Khodahafez, Predicted: Khodahafez, Confidence: 0.274
# True: Motshakeram, Predicted: Motshakeram, Confidence: 0.265
# True: Motshakeram, Predicted: Motshakeram, Confidence: 0.255
# True: Motshakeram, Predicted: Motshakeram, Confidence: 0.260
# True: Motshakeram, Predicted: Motshakeram, Confidence: 0.251
# True: Motshakeram, Predicted: Motshakeram, Confidence: 0.250
# True: Motshakeram, Predicted: Motshakeram, Confidence: 0.265
# True: Salam, Predicted: Salam, Confidence: 0.230
# True: Salam, Predicted: Salam, Confidence: 0.216
# True: Salam, Predicted: Salam, Confidence: 0.221
# True: Salam, Predicted: Salam, Confidence: 0.234
# True: Salam, Predicted: Salam, Confidence: 0.243
# True: Salam, Predicted: BesiarAali, Confidence: 0.189
#
# Overall Model Accuracy: 0.971 (33/34)
# Accuracy for Bale: 1.000 (6/6)
# Accuracy for BesiarAali: 1.000 (6/6)
# Accuracy for Kheir: 1.000 (6/6)
# Accuracy for Khodahafez: 1.000 (4/4)
# Accuracy for Motshakeram: 1.000 (6/6)
# Accuracy for Salam: 0.833 (5/6)
#
# Confidence Distribution:
# Average Confidence: 0.246
# Max Confidence: 0.305
# Min Confidence: 0.189
#
# Word with highest confidence: Khodahafez (Predicted: Khodahafez, Confidence: 0.305)
#
# Word Length vs Accuracy:
# Bale (length: 4): Accuracy = 1.000
# BesiarAali (length: 10): Accuracy = 1.000
# Kheir (length: 5): Accuracy = 1.000
# Khodahafez (length: 10): Accuracy = 1.000
# Motshakeram (length: 10): Accuracy = 1.000
# Salam (length: 5): Accuracy = 0.833
#
# Confusion matrix saved to model_res/confusion_matrix.csv
# Test results saved to model_res/test_results.csv
# Overall accuracy saved to model_res/overall_accuracy.csv
#
# Metrics comparison table saved to model_res/metrics_comparison.csv
#
# Metrics Comparison Table:
# | Word1 | Word2 | Sample1 | Sample2 | Euclidean | Manhattan | Cosine | Correlation |
# |-------|-------|---------|---------|-----------|-----------|--------|-------------|
# | Bale | Bale | Bale_02.npy | Bale_02.npy |     0.00 |     0.00 |   0.00 |   0.00 |
# | Bale | Bale | Bale_02.npy | Bale_000003.npy |    13.42 |   313.02 |   0.05 |   0.05 |
# | Bale | Bale | Bale_02.npy | Bale_01.npy |    25.58 |   539.68 |   0.17 |   0.17 |
# | Bale | Bale | Bale_02.npy | Bale_000005.npy |    12.73 |   289.29 |   0.04 |   0.04 |
# | Bale | Bale | Bale_02.npy | Bale_03.npy |    12.18 |   262.80 |   0.04 |   0.04 |
# | Bale | Bale | Bale_02.npy | Bale_005.npy |    17.52 |   376.04 |   0.08 |   0.08 |
# | Bale | Bale | Bale_02.npy | Bale_05.npy |    12.20 |   240.34 |   0.04 |   0.04 |
# | Bale | Bale | Bale_02.npy | Bale_004.npy |    17.55 |   372.45 |   0.08 |   0.08 |
# | Bale | Bale | Bale_02.npy | Bale_002.npy |    18.07 |   390.19 |   0.08 |   0.08 |
# | Bale | Bale | Bale_000003.npy | Bale_02.npy |    13.42 |   313.02 |   0.05 |   0.05 |
# | Bale | Bale | Bale_000003.npy | Bale_000003.npy |     0.00 |     0.00 |   0.00 |   0.00 |
# | Bale | Bale | Bale_000003.npy | Bale_01.npy |    24.39 |   509.68 |   0.15 |   0.15 |
# | Bale | Bale | Bale_000003.npy | Bale_000005.npy |     4.73 |   111.21 |   0.01 |   0.01 |
# | Bale | Bale | Bale_000003.npy | Bale_03.npy |    14.32 |   328.03 |   0.05 |   0.05 |
# | Bale | Bale | Bale_000003.npy | Bale_005.npy |    13.62 |   276.15 |   0.05 |   0.05 |
# | Bale | Bale | Bale_000003.npy | Bale_05.npy |    15.31 |   358.56 |   0.06 |   0.06 |
# | Bale | Bale | Bale_000003.npy | Bale_004.npy |    13.61 |   286.24 |   0.05 |   0.05 |
# | Bale | Bale | Bale_000003.npy | Bale_002.npy |    14.52 |   304.63 |   0.05 |   0.05 |
# | Bale | Bale | Bale_01.npy | Bale_02.npy |    25.58 |   539.68 |   0.17 |   0.17 |
# | Bale | Bale | Bale_01.npy | Bale_000003.npy |    24.39 |   509.68 |   0.15 |   0.15 |
# | Bale | Bale | Bale_01.npy | Bale_01.npy |     0.00 |     0.00 |   0.00 |   0.00 |
# | Bale | Bale | Bale_01.npy | Bale_000005.npy |    25.45 |   525.95 |   0.17 |   0.17 |
# | Bale | Bale | Bale_01.npy | Bale_03.npy |    27.35 |   529.61 |   0.19 |   0.19 |
# | Bale | Bale | Bale_01.npy | Bale_005.npy |    15.07 |   337.34 |   0.06 |   0.06 |
# | Bale | Bale | Bale_01.npy | Bale_05.npy |    27.17 |   536.84 |   0.19 |   0.19 |
# | Bale | Bale | Bale_01.npy | Bale_004.npy |    16.45 |   365.50 |   0.07 |   0.07 |
# | Bale | Bale | Bale_01.npy | Bale_002.npy |    16.38 |   368.12 |   0.07 |   0.07 |
# | Bale | Bale | Bale_000005.npy | Bale_02.npy |    12.73 |   289.29 |   0.04 |   0.04 |
# | Bale | Bale | Bale_000005.npy | Bale_000003.npy |     4.73 |   111.21 |   0.01 |   0.01 |
# | Bale | Bale | Bale_000005.npy | Bale_01.npy |    25.45 |   525.95 |   0.17 |   0.17 |
# | Bale | Bale | Bale_000005.npy | Bale_000005.npy |     0.00 |     0.00 |   0.00 |   0.00 |
# | Bale | Bale | Bale_000005.npy | Bale_03.npy |    12.70 |   281.41 |   0.04 |   0.04 |
# | Bale | Bale | Bale_000005.npy | Bale_005.npy |    14.42 |   293.59 |   0.05 |   0.05 |
# | Bale | Bale | Bale_000005.npy | Bale_05.npy |    14.25 |   324.67 |   0.05 |   0.05 |
# | Bale | Bale | Bale_000005.npy | Bale_004.npy |    14.47 |   295.48 |   0.05 |   0.05 |
# | Bale | Bale | Bale_000005.npy | Bale_002.npy |    15.69 |   323.17 |   0.06 |   0.06 |
# | Bale | Bale | Bale_03.npy | Bale_02.npy |    12.18 |   262.80 |   0.04 |   0.04 |
# | Bale | Bale | Bale_03.npy | Bale_000003.npy |    14.32 |   328.03 |   0.05 |   0.05 |
# | Bale | Bale | Bale_03.npy | Bale_01.npy |    27.35 |   529.61 |   0.19 |   0.19 |
# | Bale | Bale | Bale_03.npy | Bale_000005.npy |    12.70 |   281.41 |   0.04 |   0.04 |
# | Bale | Bale | Bale_03.npy | Bale_03.npy |     0.00 |     0.00 |   0.00 |   0.00 |
# | Bale | Bale | Bale_03.npy | Bale_005.npy |    18.33 |   353.13 |   0.09 |   0.09 |
# | Bale | Bale | Bale_03.npy | Bale_05.npy |     7.88 |   190.48 |   0.02 |   0.02 |
# | Bale | Bale | Bale_03.npy | Bale_004.npy |    18.09 |   333.13 |   0.08 |   0.08 |
# | Bale | Bale | Bale_03.npy | Bale_002.npy |    19.29 |   360.19 |   0.10 |   0.10 |
# | Bale | Bale | Bale_005.npy | Bale_02.npy |    17.52 |   376.04 |   0.08 |   0.08 |
# | Bale | Bale | Bale_005.npy | Bale_000003.npy |    13.62 |   276.15 |   0.05 |   0.05 |
# | Bale | Bale | Bale_005.npy | Bale_01.npy |    15.07 |   337.34 |   0.06 |   0.06 |
# | Bale | Bale | Bale_005.npy | Bale_000005.npy |    14.42 |   293.59 |   0.05 |   0.05 |
# | Bale | Bale | Bale_005.npy | Bale_03.npy |    18.33 |   353.13 |   0.09 |   0.09 |
# | Bale | Bale | Bale_005.npy | Bale_005.npy |     0.00 |     0.00 |   0.00 |   0.00 |
# | Bale | Bale | Bale_005.npy | Bale_05.npy |    18.79 |   377.73 |   0.09 |   0.09 |
# | Bale | Bale | Bale_005.npy | Bale_004.npy |     4.01 |    97.65 |   0.00 |   0.00 |
# | Bale | Bale | Bale_005.npy | Bale_002.npy |     5.15 |   128.09 |   0.01 |   0.01 |
# | Bale | Bale | Bale_05.npy | Bale_02.npy |    12.20 |   240.34 |   0.04 |   0.04 |
# | Bale | Bale | Bale_05.npy | Bale_000003.npy |    15.31 |   358.56 |   0.06 |   0.06 |
# | Bale | Bale | Bale_05.npy | Bale_01.npy |    27.17 |   536.84 |   0.19 |   0.19 |
# | Bale | Bale | Bale_05.npy | Bale_000005.npy |    14.25 |   324.67 |   0.05 |   0.05 |
# | Bale | Bale | Bale_05.npy | Bale_03.npy |     7.88 |   190.48 |   0.02 |   0.02 |
# | Bale | Bale | Bale_05.npy | Bale_005.npy |    18.79 |   377.73 |   0.09 |   0.09 |
# | Bale | Bale | Bale_05.npy | Bale_05.npy |     0.00 |     0.00 |   0.00 |   0.00 |
# | Bale | Bale | Bale_05.npy | Bale_004.npy |    18.43 |   375.56 |   0.09 |   0.09 |
# | Bale | Bale | Bale_05.npy | Bale_002.npy |    19.37 |   395.47 |   0.10 |   0.10 |
# | Bale | Bale | Bale_004.npy | Bale_02.npy |    17.55 |   372.45 |   0.08 |   0.08 |
# | Bale | Bale | Bale_004.npy | Bale_000003.npy |    13.61 |   286.24 |   0.05 |   0.05 |
# | Bale | Bale | Bale_004.npy | Bale_01.npy |    16.45 |   365.50 |   0.07 |   0.07 |
# | Bale | Bale | Bale_004.npy | Bale_000005.npy |    14.47 |   295.48 |   0.05 |   0.05 |
# | Bale | Bale | Bale_004.npy | Bale_03.npy |    18.09 |   333.13 |   0.08 |   0.08 |
# | Bale | Bale | Bale_004.npy | Bale_005.npy |     4.01 |    97.65 |   0.00 |   0.00 |
# | Bale | Bale | Bale_004.npy | Bale_05.npy |    18.43 |   375.56 |   0.09 |   0.09 |
# | Bale | Bale | Bale_004.npy | Bale_004.npy |     0.00 |     0.00 |   0.00 |   0.00 |
# | Bale | Bale | Bale_004.npy | Bale_002.npy |     4.40 |   114.15 |   0.00 |   0.00 |
# | Bale | Bale | Bale_002.npy | Bale_02.npy |    18.07 |   390.19 |   0.08 |   0.08 |
# | Bale | Bale | Bale_002.npy | Bale_000003.npy |    14.52 |   304.63 |   0.05 |   0.05 |
# | Bale | Bale | Bale_002.npy | Bale_01.npy |    16.38 |   368.12 |   0.07 |   0.07 |
# | Bale | Bale | Bale_002.npy | Bale_000005.npy |    15.69 |   323.17 |   0.06 |   0.06 |
# | Bale | Bale | Bale_002.npy | Bale_03.npy |    19.29 |   360.19 |   0.10 |   0.10 |
# | Bale | Bale | Bale_002.npy | Bale_005.npy |     5.15 |   128.09 |   0.01 |   0.01 |
# | Bale | Bale | Bale_002.npy | Bale_05.npy |    19.37 |   395.47 |   0.10 |   0.10 |
# | Bale | Bale | Bale_002.npy | Bale_004.npy |     4.40 |   114.15 |   0.00 |   0.00 |
# | Bale | Bale | Bale_002.npy | Bale_002.npy |     0.00 |     0.00 |   0.00 |   0.00 |
# | Bale | BesiarAali | Bale_02.npy | BesiarAali_02.npy |    17.91 |   396.42 |   0.08 |   0.08 |
# | Bale | BesiarAali | Bale_02.npy | BesiarAali_003.npy |    20.44 |   474.84 |   0.11 |   0.11 |
# | Bale | BesiarAali | Bale_02.npy | BesiarAali_000001.npy |    19.17 |   445.36 |   0.09 |   0.09 |
# | Bale | BesiarAali | Bale_02.npy | BesiarAali_000005.npy |    20.26 |   466.36 |   0.11 |   0.11 |
# | Bale | BesiarAali | Bale_02.npy | BesiarAali_001.npy |    20.70 |   484.79 |   0.11 |   0.11 |
# | Bale | BesiarAali | Bale_02.npy | BesiarAali_05.npy |    17.97 |   400.23 |   0.08 |   0.08 |
# | Bale | BesiarAali | Bale_02.npy | BesiarAali_000003.npy |    19.57 |   470.43 |   0.10 |   0.10 |
# | Bale | BesiarAali | Bale_02.npy | BesiarAali_03.npy |    17.44 |   392.84 |   0.08 |   0.08 |
# | Bale | BesiarAali | Bale_000003.npy | BesiarAali_02.npy |    18.38 |   452.48 |   0.09 |   0.09 |
# | Bale | BesiarAali | Bale_000003.npy | BesiarAali_003.npy |    19.10 |   456.40 |   0.09 |   0.09 |
# | Bale | BesiarAali | Bale_000003.npy | BesiarAali_000001.npy |    18.28 |   435.94 |   0.09 |   0.09 |
# | Bale | BesiarAali | Bale_000003.npy | BesiarAali_000005.npy |    17.83 |   417.33 |   0.08 |   0.08 |
# | Bale | BesiarAali | Bale_000003.npy | BesiarAali_001.npy |    19.24 |   468.47 |   0.09 |   0.09 |
# | Bale | BesiarAali | Bale_000003.npy | BesiarAali_05.npy |    17.75 |   443.00 |   0.08 |   0.08 |
# | Bale | BesiarAali | Bale_000003.npy | BesiarAali_000003.npy |    18.10 |   436.38 |   0.08 |   0.08 |
# | Bale | BesiarAali | Bale_000003.npy | BesiarAali_03.npy |    17.91 |   441.98 |   0.08 |   0.08 |
# | Bale | BesiarAali | Bale_01.npy | BesiarAali_02.npy |    23.49 |   488.46 |   0.14 |   0.14 |
# | Bale | BesiarAali | Bale_01.npy | BesiarAali_003.npy |    20.13 |   422.68 |   0.10 |   0.10 |
# | Bale | BesiarAali | Bale_01.npy | BesiarAali_000001.npy |    25.46 |   534.47 |   0.17 |   0.17 |
# | Bale | BesiarAali | Bale_01.npy | BesiarAali_000005.npy |    24.09 |   521.99 |   0.15 |   0.15 |
# | Bale | BesiarAali | Bale_01.npy | BesiarAali_001.npy |    22.13 |   468.38 |   0.13 |   0.13 |
# | Bale | BesiarAali | Bale_01.npy | BesiarAali_05.npy |    23.31 |   474.35 |   0.14 |   0.14 |
# | Bale | BesiarAali | Bale_01.npy | BesiarAali_000003.npy |    22.92 |   498.76 |   0.13 |   0.13 |
# | Bale | BesiarAali | Bale_01.npy | BesiarAali_03.npy |    22.92 |   470.76 |   0.13 |   0.13 |
# | Bale | BesiarAali | Bale_000005.npy | BesiarAali_02.npy |    18.42 |   431.75 |   0.09 |   0.09 |
# | Bale | BesiarAali | Bale_000005.npy | BesiarAali_003.npy |    20.03 |   465.16 |   0.10 |   0.10 |
# | Bale | BesiarAali | Bale_000005.npy | BesiarAali_000001.npy |    18.68 |   432.90 |   0.09 |   0.09 |
# | Bale | BesiarAali | Bale_000005.npy | BesiarAali_000005.npy |    18.49 |   418.48 |   0.09 |   0.09 |
# | Bale | BesiarAali | Bale_000005.npy | BesiarAali_001.npy |    19.91 |   468.67 |   0.10 |   0.10 |
# | Bale | BesiarAali | Bale_000005.npy | BesiarAali_05.npy |    17.63 |   424.50 |   0.08 |   0.08 |
# | Bale | BesiarAali | Bale_000005.npy | BesiarAali_000003.npy |    18.25 |   433.08 |   0.09 |   0.09 |
# | Bale | BesiarAali | Bale_000005.npy | BesiarAali_03.npy |    18.02 |   429.35 |   0.08 |   0.08 |
# | Bale | BesiarAali | Bale_03.npy | BesiarAali_02.npy |    16.64 |   366.53 |   0.07 |   0.07 |
# | Bale | BesiarAali | Bale_03.npy | BesiarAali_003.npy |    19.55 |   437.56 |   0.10 |   0.10 |
# | Bale | BesiarAali | Bale_03.npy | BesiarAali_000001.npy |    16.64 |   403.99 |   0.07 |   0.07 |
# | Bale | BesiarAali | Bale_03.npy | BesiarAali_000005.npy |    18.58 |   426.33 |   0.09 |   0.09 |
# | Bale | BesiarAali | Bale_03.npy | BesiarAali_001.npy |    19.27 |   447.38 |   0.10 |   0.10 |
# | Bale | BesiarAali | Bale_03.npy | BesiarAali_05.npy |    16.46 |   360.04 |   0.07 |   0.07 |
# | Bale | BesiarAali | Bale_03.npy | BesiarAali_000003.npy |    17.59 |   423.51 |   0.08 |   0.08 |
# | Bale | BesiarAali | Bale_03.npy | BesiarAali_03.npy |    16.24 |   358.84 |   0.07 |   0.07 |
# | Bale | BesiarAali | Bale_005.npy | BesiarAali_02.npy |    17.59 |   402.11 |   0.08 |   0.08 |
# | Bale | BesiarAali | Bale_005.npy | BesiarAali_003.npy |    16.73 |   370.21 |   0.07 |   0.07 |
# | Bale | BesiarAali | Bale_005.npy | BesiarAali_000001.npy |    19.10 |   423.96 |   0.09 |   0.09 |
# | Bale | BesiarAali | Bale_005.npy | BesiarAali_000005.npy |    18.55 |   422.66 |   0.09 |   0.09 |
# | Bale | BesiarAali | Bale_005.npy | BesiarAali_001.npy |    18.02 |   407.25 |   0.08 |   0.08 |
# | Bale | BesiarAali | Bale_005.npy | BesiarAali_05.npy |    16.86 |   384.22 |   0.07 |   0.07 |
# | Bale | BesiarAali | Bale_005.npy | BesiarAali_000003.npy |    17.37 |   405.44 |   0.08 |   0.08 |
# | Bale | BesiarAali | Bale_005.npy | BesiarAali_03.npy |    17.17 |   390.99 |   0.08 |   0.08 |
# | Bale | BesiarAali | Bale_05.npy | BesiarAali_02.npy |    14.88 |   353.93 |   0.06 |   0.06 |
# | Bale | BesiarAali | Bale_05.npy | BesiarAali_003.npy |    19.28 |   446.34 |   0.10 |   0.10 |
# | Bale | BesiarAali | Bale_05.npy | BesiarAali_000001.npy |    16.69 |   402.72 |   0.07 |   0.07 |
# | Bale | BesiarAali | Bale_05.npy | BesiarAali_000005.npy |    18.15 |   415.87 |   0.08 |   0.08 |
# | Bale | BesiarAali | Bale_05.npy | BesiarAali_001.npy |    19.20 |   451.18 |   0.09 |   0.09 |
# | Bale | BesiarAali | Bale_05.npy | BesiarAali_05.npy |    14.81 |   349.90 |   0.06 |   0.06 |
# | Bale | BesiarAali | Bale_05.npy | BesiarAali_000003.npy |    17.34 |   422.44 |   0.08 |   0.08 |
# | Bale | BesiarAali | Bale_05.npy | BesiarAali_03.npy |    14.78 |   364.27 |   0.06 |   0.06 |
# | Bale | BesiarAali | Bale_004.npy | BesiarAali_02.npy |    17.24 |   404.57 |   0.08 |   0.08 |
# | Bale | BesiarAali | Bale_004.npy | BesiarAali_003.npy |    16.65 |   374.38 |   0.07 |   0.07 |
# | Bale | BesiarAali | Bale_004.npy | BesiarAali_000001.npy |    18.94 |   426.15 |   0.09 |   0.09 |
# | Bale | BesiarAali | Bale_004.npy | BesiarAali_000005.npy |    18.88 |   439.62 |   0.09 |   0.09 |
# | Bale | BesiarAali | Bale_004.npy | BesiarAali_001.npy |    17.93 |   410.73 |   0.08 |   0.08 |
# | Bale | BesiarAali | Bale_004.npy | BesiarAali_05.npy |    16.56 |   386.12 |   0.07 |   0.07 |
# | Bale | BesiarAali | Bale_004.npy | BesiarAali_000003.npy |    17.83 |   417.77 |   0.08 |   0.08 |
# | Bale | BesiarAali | Bale_004.npy | BesiarAali_03.npy |    17.16 |   395.77 |   0.08 |   0.08 |
# | Bale | BesiarAali | Bale_002.npy | BesiarAali_02.npy |    17.77 |   417.00 |   0.08 |   0.08 |
# | Bale | BesiarAali | Bale_002.npy | BesiarAali_003.npy |    16.91 |   378.61 |   0.07 |   0.07 |
# | Bale | BesiarAali | Bale_002.npy | BesiarAali_000001.npy |    19.47 |   438.09 |   0.10 |   0.10 |
# | Bale | BesiarAali | Bale_002.npy | BesiarAali_000005.npy |    19.47 |   451.33 |   0.10 |   0.10 |
# | Bale | BesiarAali | Bale_002.npy | BesiarAali_001.npy |    18.37 |   410.71 |   0.09 |   0.09 |
# | Bale | BesiarAali | Bale_002.npy | BesiarAali_05.npy |    16.92 |   393.58 |   0.07 |   0.07 |
# | Bale | BesiarAali | Bale_002.npy | BesiarAali_000003.npy |    18.36 |   431.75 |   0.09 |   0.09 |
# | Bale | BesiarAali | Bale_002.npy | BesiarAali_03.npy |    17.48 |   404.68 |   0.08 |   0.08 |
# | Bale | Kheir | Bale_02.npy | Kheir_01.npy |    17.88 |   405.94 |   0.08 |   0.08 |
# | Bale | Kheir | Bale_02.npy | Kheir_004.npy |    18.47 |   432.30 |   0.09 |   0.09 |
# | Bale | Kheir | Bale_02.npy | Kheir_03.npy |    16.34 |   354.01 |   0.07 |   0.07 |
# | Bale | Kheir | Bale_02.npy | Kheir_001.npy |    18.86 |   429.24 |   0.09 |   0.09 |
# | Bale | Kheir | Bale_02.npy | Kheir_05.npy |    15.74 |   342.36 |   0.06 |   0.06 |
# | Bale | Kheir | Bale_02.npy | Kheir_003.npy |    18.20 |   419.31 |   0.08 |   0.08 |
# | Bale | Kheir | Bale_02.npy | Kheir_000001.npy |    18.02 |   421.98 |   0.08 |   0.08 |
# | Bale | Kheir | Bale_02.npy | Kheir_000003.npy |    18.52 |   445.29 |   0.09 |   0.09 |
# | Bale | Kheir | Bale_02.npy | Kheir_005.npy |    18.76 |   447.52 |   0.09 |   0.09 |
# | Bale | Kheir | Bale_000003.npy | Kheir_01.npy |    14.90 |   372.38 |   0.06 |   0.06 |
# | Bale | Kheir | Bale_000003.npy | Kheir_004.npy |    17.23 |   407.33 |   0.08 |   0.08 |
# | Bale | Kheir | Bale_000003.npy | Kheir_03.npy |    14.38 |   358.77 |   0.05 |   0.05 |
# | Bale | Kheir | Bale_000003.npy | Kheir_001.npy |    17.57 |   412.14 |   0.08 |   0.08 |
# | Bale | Kheir | Bale_000003.npy | Kheir_05.npy |    13.62 |   332.30 |   0.05 |   0.05 |
# | Bale | Kheir | Bale_000003.npy | Kheir_003.npy |    15.87 |   375.45 |   0.06 |   0.06 |
# | Bale | Kheir | Bale_000003.npy | Kheir_000001.npy |    14.40 |   349.60 |   0.05 |   0.05 |
# | Bale | Kheir | Bale_000003.npy | Kheir_000003.npy |    16.32 |   378.77 |   0.07 |   0.07 |
# | Bale | Kheir | Bale_000003.npy | Kheir_005.npy |    16.55 |   397.53 |   0.07 |   0.07 |
# | Bale | Kheir | Bale_01.npy | Kheir_01.npy |    21.33 |   472.00 |   0.12 |   0.12 |
# | Bale | Kheir | Bale_01.npy | Kheir_004.npy |    22.14 |   452.25 |   0.13 |   0.13 |
# | Bale | Kheir | Bale_01.npy | Kheir_03.npy |    22.24 |   461.40 |   0.13 |   0.13 |
# | Bale | Kheir | Bale_01.npy | Kheir_001.npy |    21.52 |   454.16 |   0.12 |   0.12 |
# | Bale | Kheir | Bale_01.npy | Kheir_05.npy |    22.26 |   456.37 |   0.13 |   0.13 |
# | Bale | Kheir | Bale_01.npy | Kheir_003.npy |    21.40 |   453.52 |   0.12 |   0.12 |
# | Bale | Kheir | Bale_01.npy | Kheir_000001.npy |    23.12 |   475.15 |   0.14 |   0.14 |
# | Bale | Kheir | Bale_01.npy | Kheir_000003.npy |    22.70 |   474.53 |   0.13 |   0.13 |
# | Bale | Kheir | Bale_01.npy | Kheir_005.npy |    19.52 |   418.49 |   0.10 |   0.10 |
# | Bale | Kheir | Bale_000005.npy | Kheir_01.npy |    15.00 |   372.26 |   0.06 |   0.06 |
# | Bale | Kheir | Bale_000005.npy | Kheir_004.npy |    17.59 |   409.10 |   0.08 |   0.08 |
# | Bale | Kheir | Bale_000005.npy | Kheir_03.npy |    14.65 |   354.90 |   0.05 |   0.05 |
# | Bale | Kheir | Bale_000005.npy | Kheir_001.npy |    17.87 |   408.22 |   0.08 |   0.08 |
# | Bale | Kheir | Bale_000005.npy | Kheir_05.npy |    13.66 |   332.48 |   0.05 |   0.05 |
# | Bale | Kheir | Bale_000005.npy | Kheir_003.npy |    16.04 |   380.31 |   0.07 |   0.07 |
# | Bale | Kheir | Bale_000005.npy | Kheir_000001.npy |    15.88 |   378.28 |   0.06 |   0.06 |
# | Bale | Kheir | Bale_000005.npy | Kheir_000003.npy |    17.61 |   403.37 |   0.08 |   0.08 |
# | Bale | Kheir | Bale_000005.npy | Kheir_005.npy |    16.86 |   397.11 |   0.07 |   0.07 |
# | Bale | Kheir | Bale_03.npy | Kheir_01.npy |    17.67 |   420.82 |   0.08 |   0.08 |
# | Bale | Kheir | Bale_03.npy | Kheir_004.npy |    17.46 |   414.82 |   0.08 |   0.08 |
# | Bale | Kheir | Bale_03.npy | Kheir_03.npy |    16.04 |   366.66 |   0.07 |   0.07 |
# | Bale | Kheir | Bale_03.npy | Kheir_001.npy |    17.64 |   403.43 |   0.08 |   0.08 |
# | Bale | Kheir | Bale_03.npy | Kheir_05.npy |    14.61 |   344.93 |   0.05 |   0.05 |
# | Bale | Kheir | Bale_03.npy | Kheir_003.npy |    17.31 |   403.50 |   0.08 |   0.08 |
# | Bale | Kheir | Bale_03.npy | Kheir_000001.npy |    16.97 |   412.57 |   0.07 |   0.07 |
# | Bale | Kheir | Bale_03.npy | Kheir_000003.npy |    17.37 |   426.55 |   0.08 |   0.08 |
# | Bale | Kheir | Bale_03.npy | Kheir_005.npy |    17.99 |   416.80 |   0.08 |   0.08 |
# | Bale | Kheir | Bale_005.npy | Kheir_01.npy |    12.56 |   314.43 |   0.04 |   0.04 |
# | Bale | Kheir | Bale_005.npy | Kheir_004.npy |    15.63 |   352.56 |   0.06 |   0.06 |
# | Bale | Kheir | Bale_005.npy | Kheir_03.npy |    14.26 |   330.50 |   0.05 |   0.05 |
# | Bale | Kheir | Bale_005.npy | Kheir_001.npy |    15.00 |   348.55 |   0.06 |   0.06 |
# | Bale | Kheir | Bale_005.npy | Kheir_05.npy |    13.70 |   316.49 |   0.05 |   0.05 |
# | Bale | Kheir | Bale_005.npy | Kheir_003.npy |    13.92 |   329.48 |   0.05 |   0.05 |
# | Bale | Kheir | Bale_005.npy | Kheir_000001.npy |    15.80 |   366.92 |   0.06 |   0.06 |
# | Bale | Kheir | Bale_005.npy | Kheir_000003.npy |    16.71 |   379.45 |   0.07 |   0.07 |
# | Bale | Kheir | Bale_005.npy | Kheir_005.npy |    12.09 |   310.64 |   0.04 |   0.04 |
# | Bale | Kheir | Bale_05.npy | Kheir_01.npy |    17.88 |   424.35 |   0.08 |   0.08 |
# | Bale | Kheir | Bale_05.npy | Kheir_004.npy |    16.71 |   388.24 |   0.07 |   0.07 |
# | Bale | Kheir | Bale_05.npy | Kheir_03.npy |    15.51 |   357.21 |   0.06 |   0.06 |
# | Bale | Kheir | Bale_05.npy | Kheir_001.npy |    17.24 |   395.02 |   0.08 |   0.08 |
# | Bale | Kheir | Bale_05.npy | Kheir_05.npy |    14.60 |   346.12 |   0.05 |   0.05 |
# | Bale | Kheir | Bale_05.npy | Kheir_003.npy |    16.83 |   393.44 |   0.07 |   0.07 |
# | Bale | Kheir | Bale_05.npy | Kheir_000001.npy |    17.25 |   418.60 |   0.08 |   0.08 |
# | Bale | Kheir | Bale_05.npy | Kheir_000003.npy |    17.13 |   414.23 |   0.08 |   0.08 |
# | Bale | Kheir | Bale_05.npy | Kheir_005.npy |    18.39 |   433.60 |   0.09 |   0.09 |
# | Bale | Kheir | Bale_004.npy | Kheir_01.npy |    12.78 |   332.38 |   0.04 |   0.04 |
# | Bale | Kheir | Bale_004.npy | Kheir_004.npy |    15.56 |   360.51 |   0.06 |   0.06 |
# | Bale | Kheir | Bale_004.npy | Kheir_03.npy |    14.09 |   333.14 |   0.05 |   0.05 |
# | Bale | Kheir | Bale_004.npy | Kheir_001.npy |    14.87 |   349.44 |   0.06 |   0.06 |
# | Bale | Kheir | Bale_004.npy | Kheir_05.npy |    13.76 |   323.81 |   0.05 |   0.05 |
# | Bale | Kheir | Bale_004.npy | Kheir_003.npy |    14.15 |   341.40 |   0.05 |   0.05 |
# | Bale | Kheir | Bale_004.npy | Kheir_000001.npy |    15.57 |   363.17 |   0.06 |   0.06 |
# | Bale | Kheir | Bale_004.npy | Kheir_000003.npy |    17.01 |   388.76 |   0.07 |   0.07 |
# | Bale | Kheir | Bale_004.npy | Kheir_005.npy |    11.98 |   307.90 |   0.04 |   0.04 |
# | Bale | Kheir | Bale_002.npy | Kheir_01.npy |    13.90 |   354.78 |   0.05 |   0.05 |
# | Bale | Kheir | Bale_002.npy | Kheir_004.npy |    15.83 |   366.22 |   0.06 |   0.06 |
# | Bale | Kheir | Bale_002.npy | Kheir_03.npy |    15.19 |   360.00 |   0.06 |   0.06 |
# | Bale | Kheir | Bale_002.npy | Kheir_001.npy |    15.52 |   364.20 |   0.06 |   0.06 |
# | Bale | Kheir | Bale_002.npy | Kheir_05.npy |    15.10 |   362.67 |   0.06 |   0.06 |
# | Bale | Kheir | Bale_002.npy | Kheir_003.npy |    14.61 |   346.04 |   0.05 |   0.05 |
# | Bale | Kheir | Bale_002.npy | Kheir_000001.npy |    15.99 |   363.58 |   0.07 |   0.07 |
# | Bale | Kheir | Bale_002.npy | Kheir_000003.npy |    17.56 |   389.89 |   0.08 |   0.08 |
# | Bale | Kheir | Bale_002.npy | Kheir_005.npy |    12.73 |   320.69 |   0.04 |   0.04 |
# | Bale | Khodahafez | Bale_02.npy | Khodahafez_000002.npy |    17.75 |   429.40 |   0.08 |   0.08 |
# | Bale | Khodahafez | Bale_02.npy | Khodahafez_001.npy |    17.03 |   410.28 |   0.07 |   0.07 |
# | Bale | Khodahafez | Bale_02.npy | Khodahafez_000001.npy |    17.75 |   429.49 |   0.08 |   0.08 |
# | Bale | Khodahafez | Bale_02.npy | Khodahafez_002.npy |    17.69 |   436.13 |   0.08 |   0.08 |
# | Bale | Khodahafez | Bale_02.npy | Khodahafez_004.npy |    17.32 |   418.73 |   0.08 |   0.08 |
# | Bale | Khodahafez | Bale_02.npy | Khodahafez_000005.npy |    17.66 |   434.34 |   0.08 |   0.08 |
# | Bale | Khodahafez | Bale_000003.npy | Khodahafez_000002.npy |    17.10 |   400.21 |   0.07 |   0.07 |
# | Bale | Khodahafez | Bale_000003.npy | Khodahafez_001.npy |    16.05 |   396.98 |   0.07 |   0.07 |
# | Bale | Khodahafez | Bale_000003.npy | Khodahafez_000001.npy |    15.70 |   374.18 |   0.06 |   0.06 |
# | Bale | Khodahafez | Bale_000003.npy | Khodahafez_002.npy |    15.64 |   387.82 |   0.06 |   0.06 |
# | Bale | Khodahafez | Bale_000003.npy | Khodahafez_004.npy |    16.49 |   394.66 |   0.07 |   0.07 |
# | Bale | Khodahafez | Bale_000003.npy | Khodahafez_000005.npy |    15.99 |   369.52 |   0.07 |   0.07 |
# | Bale | Khodahafez | Bale_01.npy | Khodahafez_000002.npy |    21.63 |   436.26 |   0.12 |   0.12 |
# | Bale | Khodahafez | Bale_01.npy | Khodahafez_001.npy |    21.15 |   428.69 |   0.11 |   0.11 |
# | Bale | Khodahafez | Bale_01.npy | Khodahafez_000001.npy |    21.01 |   438.82 |   0.11 |   0.11 |
# | Bale | Khodahafez | Bale_01.npy | Khodahafez_002.npy |    19.58 |   400.22 |   0.10 |   0.10 |
# | Bale | Khodahafez | Bale_01.npy | Khodahafez_004.npy |    19.27 |   386.38 |   0.10 |   0.10 |
# | Bale | Khodahafez | Bale_01.npy | Khodahafez_000005.npy |    19.11 |   379.00 |   0.09 |   0.09 |
# | Bale | Khodahafez | Bale_000005.npy | Khodahafez_000002.npy |    16.88 |   398.66 |   0.07 |   0.07 |
# | Bale | Khodahafez | Bale_000005.npy | Khodahafez_001.npy |    15.82 |   390.00 |   0.06 |   0.06 |
# | Bale | Khodahafez | Bale_000005.npy | Khodahafez_000001.npy |    15.57 |   369.25 |   0.06 |   0.06 |
# | Bale | Khodahafez | Bale_000005.npy | Khodahafez_002.npy |    15.80 |   381.92 |   0.06 |   0.06 |
# | Bale | Khodahafez | Bale_000005.npy | Khodahafez_004.npy |    16.27 |   389.97 |   0.07 |   0.07 |
# | Bale | Khodahafez | Bale_000005.npy | Khodahafez_000005.npy |    15.94 |   368.29 |   0.07 |   0.07 |
# | Bale | Khodahafez | Bale_03.npy | Khodahafez_000002.npy |    14.76 |   361.17 |   0.06 |   0.06 |
# | Bale | Khodahafez | Bale_03.npy | Khodahafez_001.npy |    13.97 |   333.31 |   0.05 |   0.05 |
# | Bale | Khodahafez | Bale_03.npy | Khodahafez_000001.npy |    14.87 |   351.95 |   0.06 |   0.06 |
# | Bale | Khodahafez | Bale_03.npy | Khodahafez_002.npy |    15.41 |   363.25 |   0.06 |   0.06 |
# | Bale | Khodahafez | Bale_03.npy | Khodahafez_004.npy |    15.43 |   360.13 |   0.06 |   0.06 |
# | Bale | Khodahafez | Bale_03.npy | Khodahafez_000005.npy |    15.22 |   357.52 |   0.06 |   0.06 |
# | Bale | Khodahafez | Bale_005.npy | Khodahafez_000002.npy |    15.16 |   342.27 |   0.06 |   0.06 |
# | Bale | Khodahafez | Bale_005.npy | Khodahafez_001.npy |    13.67 |   316.12 |   0.05 |   0.05 |
# | Bale | Khodahafez | Bale_005.npy | Khodahafez_000001.npy |    13.27 |   320.18 |   0.05 |   0.05 |
# | Bale | Khodahafez | Bale_005.npy | Khodahafez_002.npy |    13.01 |   313.18 |   0.04 |   0.04 |
# | Bale | Khodahafez | Bale_005.npy | Khodahafez_004.npy |    12.83 |   299.99 |   0.04 |   0.04 |
# | Bale | Khodahafez | Bale_005.npy | Khodahafez_000005.npy |    13.36 |   298.45 |   0.05 |   0.05 |
# | Bale | Khodahafez | Bale_05.npy | Khodahafez_000002.npy |    15.45 |   369.26 |   0.06 |   0.06 |
# | Bale | Khodahafez | Bale_05.npy | Khodahafez_001.npy |    14.61 |   346.13 |   0.05 |   0.05 |
# | Bale | Khodahafez | Bale_05.npy | Khodahafez_000001.npy |    15.53 |   365.94 |   0.06 |   0.06 |
# | Bale | Khodahafez | Bale_05.npy | Khodahafez_002.npy |    14.99 |   362.07 |   0.06 |   0.06 |
# | Bale | Khodahafez | Bale_05.npy | Khodahafez_004.npy |    15.78 |   368.62 |   0.06 |   0.06 |
# | Bale | Khodahafez | Bale_05.npy | Khodahafez_000005.npy |    16.52 |   388.83 |   0.07 |   0.07 |
# | Bale | Khodahafez | Bale_004.npy | Khodahafez_000002.npy |    15.62 |   356.09 |   0.06 |   0.06 |
# | Bale | Khodahafez | Bale_004.npy | Khodahafez_001.npy |    13.69 |   312.88 |   0.05 |   0.05 |
# | Bale | Khodahafez | Bale_004.npy | Khodahafez_000001.npy |    13.39 |   325.73 |   0.05 |   0.05 |
# | Bale | Khodahafez | Bale_004.npy | Khodahafez_002.npy |    13.15 |   318.65 |   0.04 |   0.04 |
# | Bale | Khodahafez | Bale_004.npy | Khodahafez_004.npy |    13.33 |   314.78 |   0.05 |   0.05 |
# | Bale | Khodahafez | Bale_004.npy | Khodahafez_000005.npy |    14.60 |   325.98 |   0.05 |   0.05 |
# | Bale | Khodahafez | Bale_002.npy | Khodahafez_000002.npy |    16.24 |   372.72 |   0.07 |   0.07 |
# | Bale | Khodahafez | Bale_002.npy | Khodahafez_001.npy |    14.54 |   337.09 |   0.05 |   0.05 |
# | Bale | Khodahafez | Bale_002.npy | Khodahafez_000001.npy |    14.14 |   344.17 |   0.05 |   0.05 |
# | Bale | Khodahafez | Bale_002.npy | Khodahafez_002.npy |    13.99 |   339.28 |   0.05 |   0.05 |
# | Bale | Khodahafez | Bale_002.npy | Khodahafez_004.npy |    13.92 |   326.53 |   0.05 |   0.05 |
# | Bale | Khodahafez | Bale_002.npy | Khodahafez_000005.npy |    14.99 |   330.74 |   0.06 |   0.06 |
# | Bale | Motshakeram | Bale_02.npy | Motshakeram_002.npy |    20.14 |   445.68 |   0.10 |   0.10 |
# | Bale | Motshakeram | Bale_02.npy | Motshakeram_03.npy |    17.57 |   416.31 |   0.08 |   0.08 |
# | Bale | Motshakeram | Bale_02.npy | Motshakeram_05.npy |    18.17 |   431.32 |   0.08 |   0.08 |
# | Bale | Motshakeram | Bale_02.npy | Motshakeram_000005.npy |    22.04 |   511.44 |   0.12 |   0.12 |
# | Bale | Motshakeram | Bale_02.npy | Motshakeram_01.npy |    17.73 |   419.40 |   0.08 |   0.08 |
# | Bale | Motshakeram | Bale_02.npy | Motshakeram_000002.npy |    19.94 |   479.87 |   0.10 |   0.10 |
# | Bale | Motshakeram | Bale_02.npy | Motshakeram_003.npy |    20.32 |   453.59 |   0.11 |   0.11 |
# | Bale | Motshakeram | Bale_02.npy | Motshakeram_04.npy |    19.08 |   434.82 |   0.09 |   0.09 |
# | Bale | Motshakeram | Bale_02.npy | Motshakeram_004.npy |    20.79 |   463.89 |   0.11 |   0.11 |
# | Bale | Motshakeram | Bale_000003.npy | Motshakeram_002.npy |    16.80 |   383.15 |   0.07 |   0.07 |
# | Bale | Motshakeram | Bale_000003.npy | Motshakeram_03.npy |    15.04 |   370.14 |   0.06 |   0.06 |
# | Bale | Motshakeram | Bale_000003.npy | Motshakeram_05.npy |    15.74 |   384.76 |   0.06 |   0.06 |
# | Bale | Motshakeram | Bale_000003.npy | Motshakeram_000005.npy |    18.66 |   408.56 |   0.09 |   0.09 |
# | Bale | Motshakeram | Bale_000003.npy | Motshakeram_01.npy |    13.93 |   347.97 |   0.05 |   0.05 |
# | Bale | Motshakeram | Bale_000003.npy | Motshakeram_000002.npy |    15.93 |   372.62 |   0.07 |   0.07 |
# | Bale | Motshakeram | Bale_000003.npy | Motshakeram_003.npy |    17.04 |   396.79 |   0.07 |   0.07 |
# | Bale | Motshakeram | Bale_000003.npy | Motshakeram_04.npy |    16.63 |   392.48 |   0.07 |   0.07 |
# | Bale | Motshakeram | Bale_000003.npy | Motshakeram_004.npy |    17.57 |   395.41 |   0.08 |   0.08 |
# | Bale | Motshakeram | Bale_01.npy | Motshakeram_002.npy |    24.41 |   482.77 |   0.15 |   0.15 |
# | Bale | Motshakeram | Bale_01.npy | Motshakeram_03.npy |    25.78 |   505.18 |   0.17 |   0.17 |
# | Bale | Motshakeram | Bale_01.npy | Motshakeram_05.npy |    24.53 |   494.96 |   0.15 |   0.15 |
# | Bale | Motshakeram | Bale_01.npy | Motshakeram_000005.npy |    24.31 |   508.60 |   0.15 |   0.15 |
# | Bale | Motshakeram | Bale_01.npy | Motshakeram_01.npy |    25.16 |   483.08 |   0.16 |   0.16 |
# | Bale | Motshakeram | Bale_01.npy | Motshakeram_000002.npy |    21.29 |   462.64 |   0.12 |   0.12 |
# | Bale | Motshakeram | Bale_01.npy | Motshakeram_003.npy |    24.95 |   508.67 |   0.16 |   0.16 |
# | Bale | Motshakeram | Bale_01.npy | Motshakeram_04.npy |    25.01 |   494.36 |   0.16 |   0.16 |
# | Bale | Motshakeram | Bale_01.npy | Motshakeram_004.npy |    24.74 |   496.47 |   0.16 |   0.16 |
# | Bale | Motshakeram | Bale_000005.npy | Motshakeram_002.npy |    16.40 |   379.27 |   0.07 |   0.07 |
# | Bale | Motshakeram | Bale_000005.npy | Motshakeram_03.npy |    14.01 |   353.36 |   0.05 |   0.05 |
# | Bale | Motshakeram | Bale_000005.npy | Motshakeram_05.npy |    15.07 |   370.68 |   0.06 |   0.06 |
# | Bale | Motshakeram | Bale_000005.npy | Motshakeram_000005.npy |    18.47 |   416.00 |   0.09 |   0.09 |
# | Bale | Motshakeram | Bale_000005.npy | Motshakeram_01.npy |    13.19 |   338.63 |   0.04 |   0.04 |
# | Bale | Motshakeram | Bale_000005.npy | Motshakeram_000002.npy |    17.05 |   393.91 |   0.07 |   0.07 |
# | Bale | Motshakeram | Bale_000005.npy | Motshakeram_003.npy |    16.33 |   385.35 |   0.07 |   0.07 |
# | Bale | Motshakeram | Bale_000005.npy | Motshakeram_04.npy |    15.65 |   375.61 |   0.06 |   0.06 |
# | Bale | Motshakeram | Bale_000005.npy | Motshakeram_004.npy |    17.19 |   394.31 |   0.08 |   0.08 |
# | Bale | Motshakeram | Bale_03.npy | Motshakeram_002.npy |    17.16 |   384.52 |   0.08 |   0.08 |
# | Bale | Motshakeram | Bale_03.npy | Motshakeram_03.npy |    15.03 |   353.29 |   0.06 |   0.06 |
# | Bale | Motshakeram | Bale_03.npy | Motshakeram_05.npy |    15.99 |   383.30 |   0.07 |   0.07 |
# | Bale | Motshakeram | Bale_03.npy | Motshakeram_000005.npy |    18.33 |   449.24 |   0.09 |   0.09 |
# | Bale | Motshakeram | Bale_03.npy | Motshakeram_01.npy |    15.69 |   361.67 |   0.06 |   0.06 |
# | Bale | Motshakeram | Bale_03.npy | Motshakeram_000002.npy |    19.71 |   464.62 |   0.10 |   0.10 |
# | Bale | Motshakeram | Bale_03.npy | Motshakeram_003.npy |    17.27 |   400.48 |   0.08 |   0.08 |
# | Bale | Motshakeram | Bale_03.npy | Motshakeram_04.npy |    16.60 |   384.27 |   0.07 |   0.07 |
# | Bale | Motshakeram | Bale_03.npy | Motshakeram_004.npy |    17.55 |   397.35 |   0.08 |   0.08 |
# | Bale | Motshakeram | Bale_005.npy | Motshakeram_002.npy |    15.99 |   348.30 |   0.07 |   0.07 |
# | Bale | Motshakeram | Bale_005.npy | Motshakeram_03.npy |    16.43 |   384.70 |   0.07 |   0.07 |
# | Bale | Motshakeram | Bale_005.npy | Motshakeram_05.npy |    15.88 |   376.29 |   0.06 |   0.06 |
# | Bale | Motshakeram | Bale_005.npy | Motshakeram_000005.npy |    17.30 |   399.53 |   0.08 |   0.08 |
# | Bale | Motshakeram | Bale_005.npy | Motshakeram_01.npy |    15.66 |   354.62 |   0.06 |   0.06 |
# | Bale | Motshakeram | Bale_005.npy | Motshakeram_000002.npy |    16.06 |   376.73 |   0.07 |   0.07 |
# | Bale | Motshakeram | Bale_005.npy | Motshakeram_003.npy |    16.38 |   366.21 |   0.07 |   0.07 |
# | Bale | Motshakeram | Bale_005.npy | Motshakeram_04.npy |    16.39 |   375.68 |   0.07 |   0.07 |
# | Bale | Motshakeram | Bale_005.npy | Motshakeram_004.npy |    16.38 |   358.65 |   0.07 |   0.07 |
# | Bale | Motshakeram | Bale_05.npy | Motshakeram_002.npy |    17.53 |   378.52 |   0.08 |   0.08 |
# | Bale | Motshakeram | Bale_05.npy | Motshakeram_03.npy |    15.38 |   370.84 |   0.06 |   0.06 |
# | Bale | Motshakeram | Bale_05.npy | Motshakeram_05.npy |    15.62 |   376.30 |   0.06 |   0.06 |
# | Bale | Motshakeram | Bale_05.npy | Motshakeram_000005.npy |    19.13 |   448.61 |   0.09 |   0.09 |
# | Bale | Motshakeram | Bale_05.npy | Motshakeram_01.npy |    16.37 |   381.69 |   0.07 |   0.07 |
# | Bale | Motshakeram | Bale_05.npy | Motshakeram_000002.npy |    20.26 |   455.70 |   0.11 |   0.11 |
# | Bale | Motshakeram | Bale_05.npy | Motshakeram_003.npy |    18.13 |   402.51 |   0.08 |   0.08 |
# | Bale | Motshakeram | Bale_05.npy | Motshakeram_04.npy |    15.79 |   373.79 |   0.06 |   0.06 |
# | Bale | Motshakeram | Bale_05.npy | Motshakeram_004.npy |    17.96 |   400.28 |   0.08 |   0.08 |
# | Bale | Motshakeram | Bale_004.npy | Motshakeram_002.npy |    16.20 |   352.57 |   0.07 |   0.07 |
# | Bale | Motshakeram | Bale_004.npy | Motshakeram_03.npy |    15.70 |   373.76 |   0.06 |   0.06 |
# | Bale | Motshakeram | Bale_004.npy | Motshakeram_05.npy |    15.40 |   376.21 |   0.06 |   0.06 |
# | Bale | Motshakeram | Bale_004.npy | Motshakeram_000005.npy |    17.99 |   422.54 |   0.08 |   0.08 |
# | Bale | Motshakeram | Bale_004.npy | Motshakeram_01.npy |    15.06 |   346.16 |   0.06 |   0.06 |
# | Bale | Motshakeram | Bale_004.npy | Motshakeram_000002.npy |    16.24 |   392.61 |   0.07 |   0.07 |
# | Bale | Motshakeram | Bale_004.npy | Motshakeram_003.npy |    16.77 |   373.67 |   0.07 |   0.07 |
# | Bale | Motshakeram | Bale_004.npy | Motshakeram_04.npy |    15.90 |   370.55 |   0.06 |   0.06 |
# | Bale | Motshakeram | Bale_004.npy | Motshakeram_004.npy |    16.56 |   368.23 |   0.07 |   0.07 |
# | Bale | Motshakeram | Bale_002.npy | Motshakeram_002.npy |    17.44 |   378.91 |   0.08 |   0.08 |
# | Bale | Motshakeram | Bale_002.npy | Motshakeram_03.npy |    17.75 |   417.54 |   0.08 |   0.08 |
# | Bale | Motshakeram | Bale_002.npy | Motshakeram_05.npy |    17.19 |   406.24 |   0.08 |   0.08 |
# | Bale | Motshakeram | Bale_002.npy | Motshakeram_000005.npy |    19.15 |   450.38 |   0.09 |   0.09 |
# | Bale | Motshakeram | Bale_002.npy | Motshakeram_01.npy |    16.98 |   386.28 |   0.07 |   0.07 |
# | Bale | Motshakeram | Bale_002.npy | Motshakeram_000002.npy |    17.92 |   425.58 |   0.08 |   0.08 |
# | Bale | Motshakeram | Bale_002.npy | Motshakeram_003.npy |    17.98 |   393.49 |   0.08 |   0.08 |
# | Bale | Motshakeram | Bale_002.npy | Motshakeram_04.npy |    17.73 |   409.83 |   0.08 |   0.08 |
# | Bale | Motshakeram | Bale_002.npy | Motshakeram_004.npy |    17.85 |   389.26 |   0.08 |   0.08 |
# | Bale | Salam | Bale_02.npy | Salam_003.npy |    19.64 |   453.86 |   0.10 |   0.10 |
# | Bale | Salam | Bale_02.npy | Salam_01.npy |    14.07 |   331.21 |   0.05 |   0.05 |
# | Bale | Salam | Bale_02.npy | Salam_000001.npy |    15.80 |   376.48 |   0.06 |   0.06 |
# | Bale | Salam | Bale_02.npy | Salam_000003.npy |    20.64 |   454.39 |   0.11 |   0.11 |
# | Bale | Salam | Bale_02.npy | Salam_03.npy |    13.90 |   327.90 |   0.05 |   0.05 |
# | Bale | Salam | Bale_02.npy | Salam_005.npy |    15.51 |   374.05 |   0.06 |   0.06 |
# | Bale | Salam | Bale_02.npy | Salam_004.npy |    19.43 |   445.93 |   0.10 |   0.10 |
# | Bale | Salam | Bale_02.npy | Salam_000002.npy |    16.63 |   384.41 |   0.07 |   0.07 |
# | Bale | Salam | Bale_02.npy | Salam_02.npy |    16.27 |   379.63 |   0.07 |   0.07 |
# | Bale | Salam | Bale_000003.npy | Salam_003.npy |    18.48 |   409.60 |   0.09 |   0.09 |
# | Bale | Salam | Bale_000003.npy | Salam_01.npy |    12.13 |   300.89 |   0.04 |   0.04 |
# | Bale | Salam | Bale_000003.npy | Salam_000001.npy |    11.54 |   289.75 |   0.03 |   0.03 |
# | Bale | Salam | Bale_000003.npy | Salam_000003.npy |    18.92 |   392.49 |   0.09 |   0.09 |
# | Bale | Salam | Bale_000003.npy | Salam_03.npy |    14.10 |   335.60 |   0.05 |   0.05 |
# | Bale | Salam | Bale_000003.npy | Salam_005.npy |    14.68 |   329.98 |   0.06 |   0.06 |
# | Bale | Salam | Bale_000003.npy | Salam_004.npy |    18.64 |   409.64 |   0.09 |   0.09 |
# | Bale | Salam | Bale_000003.npy | Salam_000002.npy |    12.27 |   301.56 |   0.04 |   0.04 |
# | Bale | Salam | Bale_000003.npy | Salam_02.npy |    14.97 |   365.75 |   0.06 |   0.06 |
# | Bale | Salam | Bale_01.npy | Salam_003.npy |    25.82 |   527.92 |   0.17 |   0.17 |
# | Bale | Salam | Bale_01.npy | Salam_01.npy |    22.97 |   455.02 |   0.14 |   0.14 |
# | Bale | Salam | Bale_01.npy | Salam_000001.npy |    22.97 |   500.09 |   0.14 |   0.14 |
# | Bale | Salam | Bale_01.npy | Salam_000003.npy |    12.86 |   258.12 |   0.04 |   0.04 |
# | Bale | Salam | Bale_01.npy | Salam_03.npy |    21.74 |   424.86 |   0.12 |   0.12 |
# | Bale | Salam | Bale_01.npy | Salam_005.npy |    22.58 |   472.85 |   0.13 |   0.13 |
# | Bale | Salam | Bale_01.npy | Salam_004.npy |    24.95 |   504.31 |   0.16 |   0.16 |
# | Bale | Salam | Bale_01.npy | Salam_000002.npy |    25.41 |   552.22 |   0.17 |   0.17 |
# | Bale | Salam | Bale_01.npy | Salam_02.npy |    22.45 |   462.42 |   0.13 |   0.13 |
# | Bale | Salam | Bale_000005.npy | Salam_003.npy |    19.22 |   419.75 |   0.09 |   0.09 |
# | Bale | Salam | Bale_000005.npy | Salam_01.npy |    11.88 |   299.46 |   0.04 |   0.04 |
# | Bale | Salam | Bale_000005.npy | Salam_000001.npy |    12.28 |   299.02 |   0.04 |   0.04 |
# | Bale | Salam | Bale_000005.npy | Salam_000003.npy |    20.27 |   420.60 |   0.11 |   0.11 |
# | Bale | Salam | Bale_000005.npy | Salam_03.npy |    14.45 |   340.03 |   0.05 |   0.05 |
# | Bale | Salam | Bale_000005.npy | Salam_005.npy |    15.43 |   339.64 |   0.06 |   0.06 |
# | Bale | Salam | Bale_000005.npy | Salam_004.npy |    19.41 |   414.86 |   0.10 |   0.10 |
# | Bale | Salam | Bale_000005.npy | Salam_000002.npy |    12.48 |   297.91 |   0.04 |   0.04 |
# | Bale | Salam | Bale_000005.npy | Salam_02.npy |    15.48 |   369.17 |   0.06 |   0.06 |
# | Bale | Salam | Bale_03.npy | Salam_003.npy |    18.31 |   408.88 |   0.09 |   0.09 |
# | Bale | Salam | Bale_03.npy | Salam_01.npy |    14.61 |   312.24 |   0.05 |   0.05 |
# | Bale | Salam | Bale_03.npy | Salam_000001.npy |    16.51 |   376.95 |   0.07 |   0.07 |
# | Bale | Salam | Bale_03.npy | Salam_000003.npy |    23.16 |   449.97 |   0.14 |   0.14 |
# | Bale | Salam | Bale_03.npy | Salam_03.npy |    14.71 |   315.37 |   0.06 |   0.06 |
# | Bale | Salam | Bale_03.npy | Salam_005.npy |    16.53 |   375.43 |   0.07 |   0.07 |
# | Bale | Salam | Bale_03.npy | Salam_004.npy |    18.72 |   418.37 |   0.09 |   0.09 |
# | Bale | Salam | Bale_03.npy | Salam_000002.npy |    17.15 |   393.05 |   0.08 |   0.08 |
# | Bale | Salam | Bale_03.npy | Salam_02.npy |    15.62 |   329.45 |   0.06 |   0.06 |
# | Bale | Salam | Bale_005.npy | Salam_003.npy |    19.41 |   415.45 |   0.10 |   0.10 |
# | Bale | Salam | Bale_005.npy | Salam_01.npy |    14.08 |   317.88 |   0.05 |   0.05 |
# | Bale | Salam | Bale_005.npy | Salam_000001.npy |    14.45 |   333.95 |   0.05 |   0.05 |
# | Bale | Salam | Bale_005.npy | Salam_000003.npy |    10.62 |   245.03 |   0.03 |   0.03 |
# | Bale | Salam | Bale_005.npy | Salam_03.npy |    13.71 |   309.43 |   0.05 |   0.05 |
# | Bale | Salam | Bale_005.npy | Salam_005.npy |    14.45 |   306.65 |   0.05 |   0.05 |
# | Bale | Salam | Bale_005.npy | Salam_004.npy |    18.94 |   396.90 |   0.09 |   0.09 |
# | Bale | Salam | Bale_005.npy | Salam_000002.npy |    16.14 |   375.82 |   0.07 |   0.07 |
# | Bale | Salam | Bale_005.npy | Salam_02.npy |    14.23 |   337.78 |   0.05 |   0.05 |
# | Bale | Salam | Bale_05.npy | Salam_003.npy |    17.87 |   388.87 |   0.08 |   0.08 |
# | Bale | Salam | Bale_05.npy | Salam_01.npy |    15.31 |   343.56 |   0.06 |   0.06 |
# | Bale | Salam | Bale_05.npy | Salam_000001.npy |    16.45 |   384.04 |   0.07 |   0.07 |
# | Bale | Salam | Bale_05.npy | Salam_000003.npy |    22.52 |   448.00 |   0.13 |   0.13 |
# | Bale | Salam | Bale_05.npy | Salam_03.npy |    14.53 |   325.89 |   0.05 |   0.05 |
# | Bale | Salam | Bale_05.npy | Salam_005.npy |    15.87 |   372.75 |   0.06 |   0.06 |
# | Bale | Salam | Bale_05.npy | Salam_004.npy |    17.65 |   378.68 |   0.08 |   0.08 |
# | Bale | Salam | Bale_05.npy | Salam_000002.npy |    16.84 |   382.48 |   0.07 |   0.07 |
# | Bale | Salam | Bale_05.npy | Salam_02.npy |    16.66 |   376.83 |   0.07 |   0.07 |
# | Bale | Salam | Bale_004.npy | Salam_003.npy |    19.22 |   408.14 |   0.09 |   0.09 |
# | Bale | Salam | Bale_004.npy | Salam_01.npy |    13.64 |   304.38 |   0.05 |   0.05 |
# | Bale | Salam | Bale_004.npy | Salam_000001.npy |    13.98 |   324.93 |   0.05 |   0.05 |
# | Bale | Salam | Bale_004.npy | Salam_000003.npy |    11.42 |   269.89 |   0.03 |   0.03 |
# | Bale | Salam | Bale_004.npy | Salam_03.npy |    13.36 |   314.43 |   0.05 |   0.05 |
# | Bale | Salam | Bale_004.npy | Salam_005.npy |    14.26 |   297.88 |   0.05 |   0.05 |
# | Bale | Salam | Bale_004.npy | Salam_004.npy |    18.90 |   395.48 |   0.09 |   0.09 |
# | Bale | Salam | Bale_004.npy | Salam_000002.npy |    15.45 |   368.04 |   0.06 |   0.06 |
# | Bale | Salam | Bale_004.npy | Salam_02.npy |    13.53 |   328.75 |   0.05 |   0.05 |
# | Bale | Salam | Bale_002.npy | Salam_003.npy |    19.73 |   415.38 |   0.10 |   0.10 |
# | Bale | Salam | Bale_002.npy | Salam_01.npy |    14.31 |   326.38 |   0.05 |   0.05 |
# | Bale | Salam | Bale_002.npy | Salam_000001.npy |    14.98 |   347.20 |   0.06 |   0.06 |
# | Bale | Salam | Bale_002.npy | Salam_000003.npy |    10.91 |   272.01 |   0.03 |   0.03 |
# | Bale | Salam | Bale_002.npy | Salam_03.npy |    13.38 |   318.29 |   0.05 |   0.05 |
# | Bale | Salam | Bale_002.npy | Salam_005.npy |    15.04 |   304.75 |   0.06 |   0.06 |
# | Bale | Salam | Bale_002.npy | Salam_004.npy |    19.19 |   398.69 |   0.09 |   0.09 |
# | Bale | Salam | Bale_002.npy | Salam_000002.npy |    16.35 |   380.78 |   0.07 |   0.07 |
# | Bale | Salam | Bale_002.npy | Salam_02.npy |    14.08 |   344.16 |   0.05 |   0.05 |
# | BesiarAali | Bale | BesiarAali_02.npy | Bale_02.npy |    17.91 |   396.42 |   0.08 |   0.08 |
# | BesiarAali | Bale | BesiarAali_02.npy | Bale_000003.npy |    18.38 |   452.48 |   0.09 |   0.09 |
# | BesiarAali | Bale | BesiarAali_02.npy | Bale_01.npy |    23.49 |   488.46 |   0.14 |   0.14 |
# | BesiarAali | Bale | BesiarAali_02.npy | Bale_000005.npy |    18.42 |   431.75 |   0.09 |   0.09 |
# | BesiarAali | Bale | BesiarAali_02.npy | Bale_03.npy |    16.64 |   366.53 |   0.07 |   0.07 |
# | BesiarAali | Bale | BesiarAali_02.npy | Bale_005.npy |    17.59 |   402.11 |   0.08 |   0.08 |
# | BesiarAali | Bale | BesiarAali_02.npy | Bale_05.npy |    14.88 |   353.93 |   0.06 |   0.06 |
# | BesiarAali | Bale | BesiarAali_02.npy | Bale_004.npy |    17.24 |   404.57 |   0.08 |   0.08 |
# | BesiarAali | Bale | BesiarAali_02.npy | Bale_002.npy |    17.77 |   417.00 |   0.08 |   0.08 |
# | BesiarAali | Bale | BesiarAali_003.npy | Bale_02.npy |    20.44 |   474.84 |   0.11 |   0.11 |
# | BesiarAali | Bale | BesiarAali_003.npy | Bale_000003.npy |    19.10 |   456.40 |   0.09 |   0.09 |
# | BesiarAali | Bale | BesiarAali_003.npy | Bale_01.npy |    20.13 |   422.68 |   0.10 |   0.10 |
# | BesiarAali | Bale | BesiarAali_003.npy | Bale_000005.npy |    20.03 |   465.16 |   0.10 |   0.10 |
# | BesiarAali | Bale | BesiarAali_003.npy | Bale_03.npy |    19.55 |   437.56 |   0.10 |   0.10 |
# | BesiarAali | Bale | BesiarAali_003.npy | Bale_005.npy |    16.73 |   370.21 |   0.07 |   0.07 |
# | BesiarAali | Bale | BesiarAali_003.npy | Bale_05.npy |    19.28 |   446.34 |   0.10 |   0.10 |
# | BesiarAali | Bale | BesiarAali_003.npy | Bale_004.npy |    16.65 |   374.38 |   0.07 |   0.07 |
# | BesiarAali | Bale | BesiarAali_003.npy | Bale_002.npy |    16.91 |   378.61 |   0.07 |   0.07 |
# | BesiarAali | Bale | BesiarAali_000001.npy | Bale_02.npy |    19.17 |   445.36 |   0.09 |   0.09 |
# | BesiarAali | Bale | BesiarAali_000001.npy | Bale_000003.npy |    18.28 |   435.94 |   0.09 |   0.09 |
# | BesiarAali | Bale | BesiarAali_000001.npy | Bale_01.npy |    25.46 |   534.47 |   0.17 |   0.17 |
# | BesiarAali | Bale | BesiarAali_000001.npy | Bale_000005.npy |    18.68 |   432.90 |   0.09 |   0.09 |
# | BesiarAali | Bale | BesiarAali_000001.npy | Bale_03.npy |    16.64 |   403.99 |   0.07 |   0.07 |
# | BesiarAali | Bale | BesiarAali_000001.npy | Bale_005.npy |    19.10 |   423.96 |   0.09 |   0.09 |
# | BesiarAali | Bale | BesiarAali_000001.npy | Bale_05.npy |    16.69 |   402.72 |   0.07 |   0.07 |
# | BesiarAali | Bale | BesiarAali_000001.npy | Bale_004.npy |    18.94 |   426.15 |   0.09 |   0.09 |
# ...
# | Salam | Khodahafez | Salam_02.npy | Khodahafez_004.npy |    13.37 |   318.14 |   0.05 |   0.05 |
# | Salam | Khodahafez | Salam_02.npy | Khodahafez_000005.npy |    14.92 |   362.46 |   0.06 |   0.06 |
# | Salam | Motshakeram | Salam_003.npy | Motshakeram_002.npy |    16.36 |   350.36 |   0.07 |   0.07 |
# | Salam | Motshakeram | Salam_003.npy | Motshakeram_03.npy |    17.06 |   370.51 |   0.07 |   0.07 |
# | Salam | Motshakeram | Salam_003.npy | Motshakeram_05.npy |    16.68 |   346.98 |   0.07 |   0.07 |
# | Salam | Motshakeram | Salam_003.npy | Motshakeram_000005.npy |    16.40 |   376.27 |   0.07 |   0.07 |
# | Salam | Motshakeram | Salam_003.npy | Motshakeram_01.npy |    17.87 |   381.59 |   0.08 |   0.08 |
# | Salam | Motshakeram | Salam_003.npy | Motshakeram_000002.npy |    16.72 |   350.20 |   0.07 |   0.07 |
# | Salam | Motshakeram | Salam_003.npy | Motshakeram_003.npy |    16.87 |   365.11 |   0.07 |   0.07 |
# | Salam | Motshakeram | Salam_003.npy | Motshakeram_04.npy |    17.39 |   363.49 |   0.08 |   0.08 |
# | Salam | Motshakeram | Salam_003.npy | Motshakeram_004.npy |    16.08 |   347.17 |   0.07 |   0.07 |
# | Salam | Motshakeram | Salam_01.npy | Motshakeram_002.npy |    18.75 |   426.87 |   0.09 |   0.09 |
# | Salam | Motshakeram | Salam_01.npy | Motshakeram_03.npy |    14.00 |   349.61 |   0.05 |   0.05 |
# | Salam | Motshakeram | Salam_01.npy | Motshakeram_05.npy |    15.61 |   379.69 |   0.06 |   0.06 |
# | Salam | Motshakeram | Salam_01.npy | Motshakeram_000005.npy |    19.89 |   460.10 |   0.10 |   0.10 |
# | Salam | Motshakeram | Salam_01.npy | Motshakeram_01.npy |    14.05 |   340.24 |   0.05 |   0.05 |
# | Salam | Motshakeram | Salam_01.npy | Motshakeram_000002.npy |    17.90 |   410.89 |   0.08 |   0.08 |
# | Salam | Motshakeram | Salam_01.npy | Motshakeram_003.npy |    18.97 |   432.05 |   0.09 |   0.09 |
# | Salam | Motshakeram | Salam_01.npy | Motshakeram_04.npy |    16.28 |   373.83 |   0.07 |   0.07 |
# | Salam | Motshakeram | Salam_01.npy | Motshakeram_004.npy |    19.18 |   430.04 |   0.09 |   0.09 |
# | Salam | Motshakeram | Salam_000001.npy | Motshakeram_002.npy |    18.51 |   418.87 |   0.09 |   0.09 |
# | Salam | Motshakeram | Salam_000001.npy | Motshakeram_03.npy |    13.98 |   345.50 |   0.05 |   0.05 |
# | Salam | Motshakeram | Salam_000001.npy | Motshakeram_05.npy |    15.38 |   362.33 |   0.06 |   0.06 |
# | Salam | Motshakeram | Salam_000001.npy | Motshakeram_000005.npy |    18.30 |   409.21 |   0.09 |   0.09 |
# | Salam | Motshakeram | Salam_000001.npy | Motshakeram_01.npy |    14.34 |   340.95 |   0.05 |   0.05 |
# | Salam | Motshakeram | Salam_000001.npy | Motshakeram_000002.npy |    13.27 |   304.97 |   0.05 |   0.05 |
# | Salam | Motshakeram | Salam_000001.npy | Motshakeram_003.npy |    18.56 |   422.58 |   0.09 |   0.09 |
# | Salam | Motshakeram | Salam_000001.npy | Motshakeram_04.npy |    16.36 |   377.78 |   0.07 |   0.07 |
# | Salam | Motshakeram | Salam_000001.npy | Motshakeram_004.npy |    18.45 |   411.48 |   0.09 |   0.09 |
# | Salam | Motshakeram | Salam_000003.npy | Motshakeram_002.npy |    21.10 |   420.19 |   0.11 |   0.11 |
# | Salam | Motshakeram | Salam_000003.npy | Motshakeram_03.npy |    21.27 |   437.29 |   0.12 |   0.12 |
# | Salam | Motshakeram | Salam_000003.npy | Motshakeram_05.npy |    20.60 |   424.14 |   0.11 |   0.11 |
# | Salam | Motshakeram | Salam_000003.npy | Motshakeram_000005.npy |    20.95 |   426.44 |   0.11 |   0.11 |
# | Salam | Motshakeram | Salam_000003.npy | Motshakeram_01.npy |    20.70 |   414.26 |   0.11 |   0.11 |
# | Salam | Motshakeram | Salam_000003.npy | Motshakeram_000002.npy |    17.82 |   380.95 |   0.08 |   0.08 |
# | Salam | Motshakeram | Salam_000003.npy | Motshakeram_003.npy |    21.86 |   444.26 |   0.12 |   0.12 |
# | Salam | Motshakeram | Salam_000003.npy | Motshakeram_04.npy |    21.22 |   428.04 |   0.12 |   0.12 |
# | Salam | Motshakeram | Salam_000003.npy | Motshakeram_004.npy |    21.83 |   439.02 |   0.12 |   0.12 |
# | Salam | Motshakeram | Salam_03.npy | Motshakeram_002.npy |    19.33 |   417.10 |   0.10 |   0.10 |
# | Salam | Motshakeram | Salam_03.npy | Motshakeram_03.npy |    16.04 |   374.82 |   0.07 |   0.07 |
# | Salam | Motshakeram | Salam_03.npy | Motshakeram_05.npy |    16.70 |   389.05 |   0.07 |   0.07 |
# | Salam | Motshakeram | Salam_03.npy | Motshakeram_000005.npy |    21.02 |   476.46 |   0.11 |   0.11 |
# | Salam | Motshakeram | Salam_03.npy | Motshakeram_01.npy |    15.97 |   366.77 |   0.07 |   0.07 |
# | Salam | Motshakeram | Salam_03.npy | Motshakeram_000002.npy |    19.21 |   432.03 |   0.09 |   0.09 |
# | Salam | Motshakeram | Salam_03.npy | Motshakeram_003.npy |    19.77 |   421.85 |   0.10 |   0.10 |
# | Salam | Motshakeram | Salam_03.npy | Motshakeram_04.npy |    17.44 |   384.52 |   0.08 |   0.08 |
# | Salam | Motshakeram | Salam_03.npy | Motshakeram_004.npy |    19.69 |   415.45 |   0.10 |   0.10 |
# | Salam | Motshakeram | Salam_005.npy | Motshakeram_002.npy |    18.63 |   376.90 |   0.09 |   0.09 |
# | Salam | Motshakeram | Salam_005.npy | Motshakeram_03.npy |    15.62 |   349.84 |   0.06 |   0.06 |
# | Salam | Motshakeram | Salam_005.npy | Motshakeram_05.npy |    16.09 |   344.57 |   0.07 |   0.07 |
# | Salam | Motshakeram | Salam_005.npy | Motshakeram_000005.npy |    18.18 |   411.14 |   0.08 |   0.08 |
# | Salam | Motshakeram | Salam_005.npy | Motshakeram_01.npy |    16.21 |   348.88 |   0.07 |   0.07 |
# | Salam | Motshakeram | Salam_005.npy | Motshakeram_000002.npy |    13.53 |   313.24 |   0.05 |   0.05 |
# | Salam | Motshakeram | Salam_005.npy | Motshakeram_003.npy |    18.80 |   386.86 |   0.09 |   0.09 |
# | Salam | Motshakeram | Salam_005.npy | Motshakeram_04.npy |    17.84 |   371.54 |   0.08 |   0.08 |
# | Salam | Motshakeram | Salam_005.npy | Motshakeram_004.npy |    18.55 |   382.75 |   0.09 |   0.09 |
# | Salam | Motshakeram | Salam_004.npy | Motshakeram_002.npy |    17.49 |   373.12 |   0.08 |   0.08 |
# | Salam | Motshakeram | Salam_004.npy | Motshakeram_03.npy |    17.89 |   390.13 |   0.08 |   0.08 |
# | Salam | Motshakeram | Salam_004.npy | Motshakeram_05.npy |    17.54 |   370.26 |   0.08 |   0.08 |
# | Salam | Motshakeram | Salam_004.npy | Motshakeram_000005.npy |    17.36 |   394.19 |   0.08 |   0.08 |
# | Salam | Motshakeram | Salam_004.npy | Motshakeram_01.npy |    18.72 |   401.18 |   0.09 |   0.09 |
# | Salam | Motshakeram | Salam_004.npy | Motshakeram_000002.npy |    17.27 |   369.71 |   0.08 |   0.08 |
# | Salam | Motshakeram | Salam_004.npy | Motshakeram_003.npy |    17.95 |   388.67 |   0.08 |   0.08 |
# | Salam | Motshakeram | Salam_004.npy | Motshakeram_04.npy |    18.18 |   379.18 |   0.08 |   0.08 |
# | Salam | Motshakeram | Salam_004.npy | Motshakeram_004.npy |    17.34 |   378.49 |   0.08 |   0.08 |
# | Salam | Motshakeram | Salam_000002.npy | Motshakeram_002.npy |    18.93 |   425.95 |   0.09 |   0.09 |
# | Salam | Motshakeram | Salam_000002.npy | Motshakeram_03.npy |    14.20 |   361.39 |   0.05 |   0.05 |
# | Salam | Motshakeram | Salam_000002.npy | Motshakeram_05.npy |    16.22 |   380.12 |   0.07 |   0.07 |
# | Salam | Motshakeram | Salam_000002.npy | Motshakeram_000005.npy |    19.31 |   429.05 |   0.10 |   0.10 |
# | Salam | Motshakeram | Salam_000002.npy | Motshakeram_01.npy |    15.01 |   358.58 |   0.06 |   0.06 |
# | Salam | Motshakeram | Salam_000002.npy | Motshakeram_000002.npy |    15.17 |   343.37 |   0.06 |   0.06 |
# | Salam | Motshakeram | Salam_000002.npy | Motshakeram_003.npy |    18.94 |   429.80 |   0.09 |   0.09 |
# | Salam | Motshakeram | Salam_000002.npy | Motshakeram_04.npy |    16.87 |   390.11 |   0.07 |   0.07 |
# | Salam | Motshakeram | Salam_000002.npy | Motshakeram_004.npy |    18.59 |   414.50 |   0.09 |   0.09 |
# | Salam | Motshakeram | Salam_02.npy | Motshakeram_002.npy |    19.30 |   448.53 |   0.10 |   0.10 |
# | Salam | Motshakeram | Salam_02.npy | Motshakeram_03.npy |    16.02 |   384.37 |   0.07 |   0.07 |
# | Salam | Motshakeram | Salam_02.npy | Motshakeram_05.npy |    16.78 |   403.43 |   0.07 |   0.07 |
# | Salam | Motshakeram | Salam_02.npy | Motshakeram_000005.npy |    20.80 |   486.83 |   0.11 |   0.11 |
# | Salam | Motshakeram | Salam_02.npy | Motshakeram_01.npy |    16.07 |   384.12 |   0.07 |   0.07 |
# | Salam | Motshakeram | Salam_02.npy | Motshakeram_000002.npy |    18.33 |   435.53 |   0.09 |   0.09 |
# | Salam | Motshakeram | Salam_02.npy | Motshakeram_003.npy |    19.74 |   453.03 |   0.10 |   0.10 |
# | Salam | Motshakeram | Salam_02.npy | Motshakeram_04.npy |    17.65 |   404.22 |   0.08 |   0.08 |
# | Salam | Motshakeram | Salam_02.npy | Motshakeram_004.npy |    19.12 |   435.10 |   0.09 |   0.09 |
# | Salam | Salam | Salam_003.npy | Salam_003.npy |     0.00 |     0.00 |   0.00 |   0.00 |
# | Salam | Salam | Salam_003.npy | Salam_01.npy |    17.71 |   375.29 |   0.08 |   0.08 |
# | Salam | Salam | Salam_003.npy | Salam_000001.npy |    15.30 |   318.33 |   0.06 |   0.06 |
# | Salam | Salam | Salam_003.npy | Salam_000003.npy |    21.85 |   441.00 |   0.12 |   0.12 |
# | Salam | Salam | Salam_003.npy | Salam_03.npy |    18.21 |   391.11 |   0.09 |   0.09 |
# | Salam | Salam | Salam_003.npy | Salam_005.npy |    12.21 |   236.62 |   0.04 |   0.04 |
# | Salam | Salam | Salam_003.npy | Salam_004.npy |     5.01 |   123.27 |   0.01 |   0.01 |
# | Salam | Salam | Salam_003.npy | Salam_000002.npy |    16.24 |   347.58 |   0.07 |   0.07 |
# | Salam | Salam | Salam_003.npy | Salam_02.npy |    18.31 |   406.39 |   0.09 |   0.09 |
# | Salam | Salam | Salam_01.npy | Salam_003.npy |    17.71 |   375.29 |   0.08 |   0.08 |
# | Salam | Salam | Salam_01.npy | Salam_01.npy |     0.00 |     0.00 |   0.00 |   0.00 |
# | Salam | Salam | Salam_01.npy | Salam_000001.npy |     9.05 |   234.48 |   0.02 |   0.02 |
# | Salam | Salam | Salam_01.npy | Salam_000003.npy |    18.22 |   367.88 |   0.09 |   0.09 |
# | Salam | Salam | Salam_01.npy | Salam_03.npy |     7.07 |   173.57 |   0.01 |   0.01 |
# | Salam | Salam | Salam_01.npy | Salam_005.npy |    13.22 |   291.09 |   0.04 |   0.04 |
# | Salam | Salam | Salam_01.npy | Salam_004.npy |    17.47 |   363.41 |   0.08 |   0.08 |
# | Salam | Salam | Salam_01.npy | Salam_000002.npy |    10.30 |   255.78 |   0.03 |   0.03 |
# | Salam | Salam | Salam_01.npy | Salam_02.npy |     8.60 |   190.55 |   0.02 |   0.02 |
# | Salam | Salam | Salam_000001.npy | Salam_003.npy |    15.30 |   318.33 |   0.06 |   0.06 |
# | Salam | Salam | Salam_000001.npy | Salam_01.npy |     9.05 |   234.48 |   0.02 |   0.02 |
# | Salam | Salam | Salam_000001.npy | Salam_000001.npy |     0.00 |     0.00 |   0.00 |   0.00 |
# | Salam | Salam | Salam_000001.npy | Salam_000003.npy |    17.39 |   365.50 |   0.08 |   0.08 |
# | Salam | Salam | Salam_000001.npy | Salam_03.npy |    12.14 |   302.70 |   0.04 |   0.04 |
# | Salam | Salam | Salam_000001.npy | Salam_005.npy |     9.96 |   224.98 |   0.03 |   0.03 |
# | Salam | Salam | Salam_000001.npy | Salam_004.npy |    15.11 |   315.32 |   0.06 |   0.06 |
# | Salam | Salam | Salam_000001.npy | Salam_000002.npy |     5.25 |   126.30 |   0.01 |   0.01 |
# | Salam | Salam | Salam_000001.npy | Salam_02.npy |    12.58 |   300.53 |   0.04 |   0.04 |
# | Salam | Salam | Salam_000003.npy | Salam_003.npy |    21.85 |   441.00 |   0.12 |   0.12 |
# | Salam | Salam | Salam_000003.npy | Salam_01.npy |    18.22 |   367.88 |   0.09 |   0.09 |
# | Salam | Salam | Salam_000003.npy | Salam_000001.npy |    17.39 |   365.50 |   0.08 |   0.08 |
# | Salam | Salam | Salam_000003.npy | Salam_000003.npy |     0.00 |     0.00 |   0.00 |   0.00 |
# | Salam | Salam | Salam_000003.npy | Salam_03.npy |    17.12 |   354.21 |   0.08 |   0.08 |
# | Salam | Salam | Salam_000003.npy | Salam_005.npy |    16.59 |   343.11 |   0.07 |   0.07 |
# | Salam | Salam | Salam_000003.npy | Salam_004.npy |    20.64 |   415.39 |   0.11 |   0.11 |
# | Salam | Salam | Salam_000003.npy | Salam_000002.npy |    19.48 |   410.31 |   0.10 |   0.10 |
# | Salam | Salam | Salam_000003.npy | Salam_02.npy |    18.32 |   386.66 |   0.09 |   0.09 |
# | Salam | Salam | Salam_03.npy | Salam_003.npy |    18.21 |   391.11 |   0.09 |   0.09 |
# | Salam | Salam | Salam_03.npy | Salam_01.npy |     7.07 |   173.57 |   0.01 |   0.01 |
# | Salam | Salam | Salam_03.npy | Salam_000001.npy |    12.14 |   302.70 |   0.04 |   0.04 |
# | Salam | Salam | Salam_03.npy | Salam_000003.npy |    17.12 |   354.21 |   0.08 |   0.08 |
# | Salam | Salam | Salam_03.npy | Salam_03.npy |     0.00 |     0.00 |   0.00 |   0.00 |
# | Salam | Salam | Salam_03.npy | Salam_005.npy |    13.91 |   323.67 |   0.05 |   0.05 |
# | Salam | Salam | Salam_03.npy | Salam_004.npy |    17.72 |   375.70 |   0.08 |   0.08 |
# | Salam | Salam | Salam_03.npy | Salam_000002.npy |    13.84 |   333.03 |   0.05 |   0.05 |
# | Salam | Salam | Salam_03.npy | Salam_02.npy |     6.81 |   162.26 |   0.01 |   0.01 |
# | Salam | Salam | Salam_005.npy | Salam_003.npy |    12.21 |   236.62 |   0.04 |   0.04 |
# | Salam | Salam | Salam_005.npy | Salam_01.npy |    13.22 |   291.09 |   0.04 |   0.04 |
# | Salam | Salam | Salam_005.npy | Salam_000001.npy |     9.96 |   224.98 |   0.03 |   0.03 |
# | Salam | Salam | Salam_005.npy | Salam_000003.npy |    16.59 |   343.11 |   0.07 |   0.07 |
# | Salam | Salam | Salam_005.npy | Salam_03.npy |    13.91 |   323.67 |   0.05 |   0.05 |
# | Salam | Salam | Salam_005.npy | Salam_005.npy |     0.00 |     0.00 |   0.00 |   0.00 |
# | Salam | Salam | Salam_005.npy | Salam_004.npy |    11.40 |   211.02 |   0.03 |   0.03 |
# | Salam | Salam | Salam_005.npy | Salam_000002.npy |    11.29 |   263.86 |   0.03 |   0.03 |
# | Salam | Salam | Salam_005.npy | Salam_02.npy |    14.73 |   342.99 |   0.06 |   0.06 |
# | Salam | Salam | Salam_004.npy | Salam_003.npy |     5.01 |   123.27 |   0.01 |   0.01 |
# | Salam | Salam | Salam_004.npy | Salam_01.npy |    17.47 |   363.41 |   0.08 |   0.08 |
# | Salam | Salam | Salam_004.npy | Salam_000001.npy |    15.11 |   315.32 |   0.06 |   0.06 |
# | Salam | Salam | Salam_004.npy | Salam_000003.npy |    20.64 |   415.39 |   0.11 |   0.11 |
# | Salam | Salam | Salam_004.npy | Salam_03.npy |    17.72 |   375.70 |   0.08 |   0.08 |
# | Salam | Salam | Salam_004.npy | Salam_005.npy |    11.40 |   211.02 |   0.03 |   0.03 |
# | Salam | Salam | Salam_004.npy | Salam_004.npy |     0.00 |     0.00 |   0.00 |   0.00 |
# | Salam | Salam | Salam_004.npy | Salam_000002.npy |    16.06 |   345.62 |   0.07 |   0.07 |
# | Salam | Salam | Salam_004.npy | Salam_02.npy |    18.54 |   416.51 |   0.09 |   0.09 |
# | Salam | Salam | Salam_000002.npy | Salam_003.npy |    16.24 |   347.58 |   0.07 |   0.07 |
# | Salam | Salam | Salam_000002.npy | Salam_01.npy |    10.30 |   255.78 |   0.03 |   0.03 |
# | Salam | Salam | Salam_000002.npy | Salam_000001.npy |     5.25 |   126.30 |   0.01 |   0.01 |
# | Salam | Salam | Salam_000002.npy | Salam_000003.npy |    19.48 |   410.31 |   0.10 |   0.10 |
# | Salam | Salam | Salam_000002.npy | Salam_03.npy |    13.84 |   333.03 |   0.05 |   0.05 |
# | Salam | Salam | Salam_000002.npy | Salam_005.npy |    11.29 |   263.86 |   0.03 |   0.03 |
# | Salam | Salam | Salam_000002.npy | Salam_004.npy |    16.06 |   345.62 |   0.07 |   0.07 |
# | Salam | Salam | Salam_000002.npy | Salam_000002.npy |     0.00 |     0.00 |   0.00 |   0.00 |
# | Salam | Salam | Salam_000002.npy | Salam_02.npy |    14.21 |   336.59 |   0.05 |   0.05 |
# | Salam | Salam | Salam_02.npy | Salam_003.npy |    18.31 |   406.39 |   0.09 |   0.09 |
# | Salam | Salam | Salam_02.npy | Salam_01.npy |     8.60 |   190.55 |   0.02 |   0.02 |
# | Salam | Salam | Salam_02.npy | Salam_000001.npy |    12.58 |   300.53 |   0.04 |   0.04 |
# | Salam | Salam | Salam_02.npy | Salam_000003.npy |    18.32 |   386.66 |   0.09 |   0.09 |
# | Salam | Salam | Salam_02.npy | Salam_03.npy |     6.81 |   162.26 |   0.01 |   0.01 |
# | Salam | Salam | Salam_02.npy | Salam_005.npy |    14.73 |   342.99 |   0.06 |   0.06 |
# | Salam | Salam | Salam_02.npy | Salam_004.npy |    18.54 |   416.51 |   0.09 |   0.09 |
# | Salam | Salam | Salam_02.npy | Salam_000002.npy |    14.21 |   336.59 |   0.05 |   0.05 |
# | Salam | Salam | Salam_02.npy | Salam_02.npy |     0.00 |     0.00 |   0.00 |   0.00 |

# %% [markdown]
# ### preprocess_audio_continuous_speech

# %%
import os
import librosa
import soundfile as sf
import scipy.signal as signal
import numpy as np

# مسیرها
input_dir = 'data/Sentence/'
output_dir = 'data/continuous_speech'
os.makedirs(output_dir, exist_ok=True)

# تنظیمات
target_sr = 16000
subtype = 'PCM_16'
low_cut = 300
high_cut = 3400
order = 5

# توابع پردازش
def normalize_audio(y):
    return y / np.max(np.abs(y))

def trim_silence(y, top_db=30):
    return librosa.effects.trim(y, top_db=top_db)[0]

def bandpass_filter(y, sr, low_cut, high_cut, order=5):
    nyquist = 0.5 * sr
    low = low_cut / nyquist
    high = high_cut / nyquist
    b, a = signal.butter(order, [low, high], btype='band')
    return signal.lfilter(b, a, y)

# پردازش فایل‌ها
for filename in os.listdir(input_dir):
    if filename.endswith('.wav'):
        input_path = os.path.join(input_dir, filename)
        output_path = os.path.join(output_dir, filename)

        # 1. بارگذاری و تبدیل به نرخ ۱۶kHz
        y, sr = librosa.load(input_path, sr=target_sr)

        # 2. نرمال‌سازی دامنه
        y = normalize_audio(y)

        # 3. حذف سکوت از ابتدا و انتها
        y = trim_silence(y)

        # 4. فیلتر باندپَس (حذف نویز خارج از بازه گفتار)
        y = bandpass_filter(y, sr, low_cut, high_cut, order)

        # 5. ذخیره با فرمت ۱۶ بیت
        sf.write(output_path, y, sr, subtype=subtype)

        print(f'✅ Processed and saved: {filename}')
# Out:
# ✅ Processed and saved: asre_be_kheir_salam.wav
# ✅ Processed and saved: bale_hatman_anjam_midam.wav
# ✅ Processed and saved: bale_salam.wav
# ✅ Processed and saved: fekhrkonam_bale.wav
# ✅ Processed and saved: felan_khodahafez.wav
# ✅ Processed and saved: kheili_moteshaker.wav
# ✅ Processed and saved: khir_intor_nist.wav
# ✅ Processed and saved: khodahafez_ta_faeda.wav
# ✅ Processed and saved: moteshakeram_lotf.wav
# ✅ Processed and saved: na_khir_ashtebah_shode.wav
# ✅ Processed and saved: no_key_01.wav
# ✅ Processed and saved: no_key_02.wav
# ✅ Processed and saved: no_key_03.wav
# ✅ Processed and saved: no_key_04.wav
# ✅ Processed and saved: no_key_05.wav
# ✅ Processed and saved: no_key_06.wav
# ✅ Processed and saved: no_key_07.wav
# ✅ Processed and saved: no_key_08.wav
# ✅ Processed and saved: no_key_09.wav
# ✅ Processed and saved: no_key_10.wav
# ✅ Processed and saved: salam_mo_kh.wav
# ✅ Processed and saved: salam_sob_be_kheir.wav
# ✅ Processed and saved: ye_salam_garm_be_hame.wav

# %% [markdown]
# ### plot_waveform_continuous_speech

# %%
import os
import librosa
import soundfile as sf
import scipy.signal as signal
import numpy as np
import matplotlib.pyplot as plt
import librosa.display

# Path to preprocessed audio files and output directory
input_dir = 'data/continuous_speech/'
output_dir = 'plot_waveform_continuous_speech'
target_sr = 16000

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Feature extraction functions
def compute_rms(y):
    return np.sqrt(np.mean(y**2))

def compute_zcr(y):
    return np.mean(librosa.zero_crossings(y, pad=False))

def compute_energy(y):
    return np.sum(y**2)

def save_waveform_plot(y, sr, title, rms, zcr, energy):
    plt.figure(figsize=(10, 2.5))
    librosa.display.waveshow(y, sr=sr)
    plt.title(f'Waveform: {title}')
    plt.xlabel("Time (seconds)")
    plt.ylabel("Amplitude")
    
    # Add feature text to the plot
    text_str = f'RMS: {rms:.4f}\nZCR: {zcr:.4f}\nEnergy: {energy:.2f}'
    plt.text(0.02, 0.98, text_str, transform=plt.gca().transAxes, 
             verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
    
    plt.tight_layout()
    output_path = os.path.join(output_dir, f'waveform_{title}.png')
    plt.savefig(output_path)
    plt.close()

def save_fft_plot(y, sr, title, rms, zcr, energy):
    Y = np.fft.rfft(y)
    freqs = np.fft.rfftfreq(len(y), 1/sr)
    plt.figure(figsize=(10, 2.5))
    plt.plot(freqs, np.abs(Y))
    plt.title(f'Frequency Spectrum (FFT): {title}')
    plt.xlabel("Frequency (Hz)")
    plt.ylabel("Magnitude")
    plt.xlim(0, 8000)
    
    # Add feature text to the plot
    text_str = f'RMS: {rms:.4f}\nZCR: {zcr:.4f}\nEnergy: {energy:.2f}'
    plt.text(0.02, 0.98, text_str, transform=plt.gca().transAxes, 
             verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
    
    plt.tight_layout()
    output_path = os.path.join(output_dir, f'fft_{title}.png')
    plt.savefig(output_path)
    plt.close()

def save_features_to_text(filename, rms, zcr, energy):
    output_path = os.path.join(output_dir, f'features_{filename}.txt')
    with open(output_path, 'w') as f:
        f.write(f'File: {filename}\n')
        f.write(f'RMS: {rms:.4f}\n')
        f.write(f'Zero-Crossing Rate: {zcr:.4f}\n')
        f.write(f'Energy: {energy:.2f}\n')

# Analyze each audio file
for filename in os.listdir(input_dir):
    if filename.endswith('.wav'):
        path = os.path.join(input_dir, filename)
        y, sr = librosa.load(path, sr=target_sr)

        # Compute features
        rms = compute_rms(y)
        zcr = compute_zcr(y)
        energy = compute_energy(y)

        # Save features to text file
        save_features_to_text(filename, rms, zcr, energy)

        # Save visualizations with features annotated
        save_waveform_plot(y, sr, filename, rms, zcr, energy)
        save_fft_plot(y, sr, filename, rms, zcr, energy)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 88
#      85 save_features_to_text(filename, rms, zcr, energy)
#      87 # Save visualizations with features annotated
# ---> 88 save_waveform_plot(y, sr, filename, rms, zcr, energy)
#      89 save_fft_plot(y, sr, filename, rms, zcr, energy)
#
# Cell In[24], line 30, in save_waveform_plot(y, sr, title, rms, zcr, energy)
#      28 def save_waveform_plot(y, sr, title, rms, zcr, energy):
#      29     plt.figure(figsize=(10, 2.5))
# ---> 30     librosa.display.waveshow(y, sr=sr)
#      31     plt.title(f'Waveform: {title}')
#      32     plt.xlabel("Time (seconds)")
#
# File c:\Users\amir\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\display.py:2037, in waveshow(y, sr, max_points, axis, offset, marker, where, label, transpose, ax, x_axis, **kwargs)
#    2034     raise ParameterError(f"max_points={max_points} must be strictly positive")
#    2036 # Create the adaptive drawing object
# -> 2037 axes = __check_axes(ax)
#    2039 # Handle the x_axis->axis rename deprecation
#    2040 axis = rename_kw(
#    2041     old_name="x_axis",
#    2042     old_value=x_axis,
#    (...)
#    2046     version_removed="1.0",
#    2047 )
#
# File c:\Users\amir\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\display.py:1326, in __check_axes(axes)
#    1324 """Check if "axes" is an instance of an axis object. If not, use `gca`."""
#    1325 if axes is None:
# -> 1326     axes = plt.gca()
#    1327 elif not isinstance(axes, mplaxes.Axes):
#    1328     raise ParameterError(
#    1329         "`axes` must be an instance of matplotlib.axes.Axes. "
#    1330         "Found type(axes)={}".format(type(axes))
#    1331     )
#
# File c:\Users\amir\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:2785, in gca()
#    2783 @_copy_docstring_and_deprecators(Figure.gca)
#    2784 def gca() -> Axes:
# -> 2785     return gcf().gca()
#
# File c:\Users\amir\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\figure.py:1719, in FigureBase.gca(self)
#    1709 """
#    1710 Get the current Axes.
#    1711
#    (...)
#    1716 whether `.pyplot.get_fignums()` is empty.)
#    1717 """
#    1718 ax = self._axstack.current()
# -> 1719 return ax if ax is not None else self.add_subplot()
#
# File c:\Users\amir\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\figure.py:768, in FigureBase.add_subplot(self, *args, **kwargs)
#     766         args = tuple(map(int, str(args[0])))
#     767     projection_class, pkw = self._process_projection_requirements(**kwargs)
# --> 768     ax = projection_class(self, *args, **pkw)
#     769     key = (projection_class, pkw)
#     770 return self._add_axes_internal(ax, key)
#
# File c:\Users\amir\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_base.py:732, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, forward_navigation_events, *args, **kwargs)
#     729 self.set_axisbelow(mpl.rcParams['axes.axisbelow'])
#     731 self._rasterization_zorder = None
# --> 732 self.clear()
#     734 # funcs used to format x and y - fall back on major formatters
#     735 self.fmt_xdata = None
#
# File c:\Users\amir\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_base.py:1452, in _AxesBase.clear(self)
#    1450     self.cla()
#    1451 else:
# -> 1452     self.__clear()
#
# File c:\Users\amir\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_base.py:1419, in _AxesBase.__clear(self)
#    1415 self.patch.set_transform(self.transAxes)
#    1417 self.set_axis_on()
# -> 1419 self.xaxis.set_clip_path(self.patch)
#    1420 self.yaxis.set_clip_path(self.patch)
#    1422 if self._sharex is not None:
#
# File c:\Users\amir\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axis.py:1117, in Axis.set_clip_path(self, path, transform)
#    1115 def set_clip_path(self, path, transform=None):
#    1116     super().set_clip_path(path, transform)
# -> 1117     for child in self.majorTicks + self.minorTicks:
#    1118         child.set_clip_path(path, transform)
#    1119     self.stale = True
#
# File c:\Users\amir\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axis.py:552, in _LazyTickList.__get__(self, instance, owner)
#     550 else:
#     551     instance.minorTicks = []
# --> 552     tick = instance._get_tick(major=False)
#     553     instance.minorTicks = [tick]
#     554     return instance.minorTicks
#
# File c:\Users\amir\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axis.py:1592, in Axis._get_tick(self, major)
#    1588     raise NotImplementedError(
#    1589         f"The Axis subclass {self.__class__.__name__} must define "
#    1590         "_tick_class or reimplement _get_tick()")
#    1591 tick_kw = self._major_tick_kw if major else self._minor_tick_kw
# -> 1592 return self._tick_class(self.axes, 0, major=major, **tick_kw)
#
# File c:\Users\amir\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axis.py:375, in XTick.__init__(self, *args, **kwargs)
#     371 self.tick1line.set(
#     372     data=([0], [0]), transform=ax.get_xaxis_transform("tick1"))
#     373 self.tick2line.set(
#     374     data=([0], [1]), transform=ax.get_xaxis_transform("tick2"))
# --> 375 self.gridline.set(
#     376     data=([0, 0], [0, 1]), transform=ax.get_xaxis_transform("grid"))
#     377 # the y loc is 3 points below the min of y axis
#     378 trans, va, ha = self._get_text1_transform()
#
# File c:\Users\amir\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:146, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     138 if not hasattr(cls.set, '_autogenerated_signature'):
#     139     # Don't overwrite cls.set if the subclass or one of its parents
#     140     # has defined a set method set itself.
#     141     # If there was no explicit definition, cls.set is inherited from
#     142     # the hierarchy of auto-generated set methods, which hold the
#     143     # flag _autogenerated_signature.
#     144     return
# --> 146 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     147 cls.set.__name__ = "set"
#     148 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File c:\Users\amir\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:1241, in Artist.set(self, **kwargs)
#    1237 def set(self, **kwargs):
#    1238     # docstring and signature are auto-generated via
#    1239     # Artist._update_set_signature_and_docstring() at the end of the
#    1240     # module.
# -> 1241     return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#
# File c:\Users\amir\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\cbook.py:1791, in normalize_kwargs(kw, alias_mapping)
#    1787 elif (isinstance(alias_mapping, type) and issubclass(alias_mapping, Artist)
#    1788       or isinstance(alias_mapping, Artist)):
#    1789     alias_mapping = getattr(alias_mapping, "_alias_map", {})
# -> 1791 to_canonical = {alias: canonical
#    1792                 for canonical, alias_list in alias_mapping.items()
#    1793                 for alias in alias_list}
#    1794 canonical_to_seen = {}
#    1795 ret = {}  # output dictionary
#
# File c:\Users\amir\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\cbook.py:1791, in <dictcomp>(.0)
#    1787 elif (isinstance(alias_mapping, type) and issubclass(alias_mapping, Artist)
#    1788       or isinstance(alias_mapping, Artist)):
#    1789     alias_mapping = getattr(alias_mapping, "_alias_map", {})
# -> 1791 to_canonical = {alias: canonical
#    1792                 for canonical, alias_list in alias_mapping.items()
#    1793                 for alias in alias_list}
#    1794 canonical_to_seen = {}
#    1795 ret = {}  # output dictionary
#
# KeyboardInterrupt:

# %% [markdown]
# ### MFCC_continuous_speech

# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

class FeatureExtractor:
    def __init__(self, sample_rate=16000, n_mfcc=13, n_fft=2048,
                 hop_length=512, n_mels=128):
        self.sample_rate = sample_rate
        self.n_mfcc = n_mfcc
        self.n_fft = n_fft
        self.hop_length = hop_length
        self.n_mels = n_mels

    def pre_emphasis(self, signal, pre_emph_coef=0.97):
        return np.append(signal[0], signal[1:] - pre_emph_coef * signal[:-1])

    def remove_silence(self, y, threshold=0.01):
        try:
            energy = librosa.feature.rms(y=y)[0]
            frames = np.nonzero(energy > threshold)
            if frames[0].size:
                y = y[librosa.frames_to_samples(frames[0][0]):librosa.frames_to_samples(frames[0][-1])]
            return y
        except Exception as e:
            print(f"Error in remove_silence: {e}")
            return y

    def extract_mfcc(self, y):
        try:
            y = self.pre_emphasis(y)
            mfcc = librosa.feature.mfcc(y=y, sr=self.sample_rate, n_mfcc=self.n_mfcc,
                                        n_fft=self.n_fft, hop_length=self.hop_length,
                                        n_mels=self.n_mels)
            mfcc = (mfcc - np.mean(mfcc)) / np.std(mfcc)
            return mfcc
        except Exception as e:
            print(f"Error in extract_mfcc: {e}")
            return None

    def extract_delta_features(self, mfcc):
        try:
            delta = librosa.feature.delta(mfcc)
            delta_delta = librosa.feature.delta(mfcc, order=2)
            combined = np.vstack([mfcc, delta, delta_delta])
            return combined
        except Exception as e:
            print(f"Error in extract_delta_features: {e}")
            return None

    def normalize_feature_length(self, features, target_length=50):
        try:
            n_features, original_length = features.shape
            x_old = np.linspace(0, 1, original_length)
            x_new = np.linspace(0, 1, target_length)
            interpolated = np.zeros((n_features, target_length))
            for i in range(n_features):
                f = interp1d(x_old, features[i], kind='linear')
                interpolated[i] = f(x_new)
            return interpolated
        except Exception as e:
            print(f"Error in normalize_feature_length: {e}")
            return None

    def extract_energy(self, y):
        try:
            return np.sum(y ** 2)
        except Exception as e:
            print(f"Error in extract_energy: {e}")
            return 0.0

    def save_mfcc_spectrogram(self, mfcc, title, energy):
        try:
            plt.figure(figsize=(8, 3))
            librosa.display.specshow(mfcc, x_axis='time', sr=self.sample_rate)
            plt.colorbar()
            plt.title(f'MFCC: {title}')
            text_str = f'Energy: {energy:.2f}'
            plt.text(0.02, 0.98, text_str, transform=plt.gca().transAxes, 
                     verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
            plt.tight_layout()
            output_path = os.path.join(plot_dir, f'mfcc_{title}.png')
            plt.savefig(output_path)
            plt.close()
            print(f"✅ Saved MFCC spectrogram: {output_path}")
        except Exception as e:
            print(f"Error in save_mfcc_spectrogram for {title}: {e}")

# Paths for input and output
input_dir = 'data/continuous_speech/'
output_dir = 'data/mfcc_features_continuous_speech'
plot_dir = 'mfcc_plot_continuous_speech'
os.makedirs(output_dir, exist_ok=True)
os.makedirs(plot_dir, exist_ok=True)

# Check if input directory exists and has files
if not os.path.exists(input_dir):
    print(f"Error: Input directory {input_dir} does not exist.")
    exit()
if not os.listdir(input_dir):
    print(f"Error: No files found in {input_dir}.")
    exit()

# Extract unique filenames (treating each file as a whole unit)
sentences = []
for filename in os.listdir(input_dir):
    if filename.endswith('.wav'):
        sentence = os.path.splitext(filename)[0]
        sentences.append(sentence)
sentences = sorted(sentences)

if not sentences:
    print(f"Error: No .wav files found in {input_dir}.")
    exit()

extractor = FeatureExtractor()
sentence_features = {}

for sentence in sentences:
    mfccs = []
    energies = []
    lengths = []
    print(f'\n🔍 Processing Sentence: {sentence}')
    
    # Process the sentence file
    filename = sentence + '.wav'
    wav_path = os.path.join(input_dir, filename)
    
    try:
        y, sr = librosa.load(wav_path, sr=16000)
    except Exception as e:
        print(f"Error loading {wav_path}: {e}")
        continue

    y = extractor.remove_silence(y)
    if y is None or len(y) == 0:
        print(f"Warning: Empty audio after silence removal for {filename}")
        continue

    energy = extractor.extract_energy(y)
    mfcc = extractor.extract_mfcc(y)
    if mfcc is None:
        print(f"Warning: Failed to extract MFCC for {filename}")
        continue

    mfcc = extractor.extract_delta_features(mfcc)
    if mfcc is None:
        print(f"Warning: Failed to extract delta features for {filename}")
        continue

    mfcc = extractor.normalize_feature_length(mfcc)
    if mfcc is None:
        print(f"Warning: Failed to normalize feature length for {filename}")
        continue

    # Save features to npy file
    npy_filename = filename.replace('.wav', '.npy')
    npy_path = os.path.join(output_dir, npy_filename)
    try:
        np.save(npy_path, mfcc)
        print(f"✅ Saved MFCC features: {npy_path}")
    except Exception as e:
        print(f"Error saving MFCC features for {npy_filename}: {e}")

    # Save MFCC spectrogram
    extractor.save_mfcc_spectrogram(mfcc, filename, energy)

    # Collect statistics
    mfccs.append(mfcc)
    energies.append(energy)
    lengths.append(len(y) / sr)

    # Store for final analysis
    sentence_features[sentence] = {
        'mfccs': mfccs,
        'energies': energies,
        'lengths': lengths
    }

    print(f"📏 Avg length: {np.mean(lengths):.2f}s")
    print(f"⚡ Avg energy: {np.mean(energies):.2f}")

print("\n🎉 Processing completed!")
# Out:
# 🔍 Processing Sentence: asre_be_kheir_salam
# ✅ Saved MFCC features: data/mfcc_features_continuous_speech\asre_be_kheir_salam.npy
# ✅ Saved MFCC spectrogram: mfcc_plot_continuous_speech\mfcc_asre_be_kheir_salam.wav.png
# 📏 Avg length: 1.25s
# ⚡ Avg energy: 449.56
#
# 🔍 Processing Sentence: bale_hatman_anjam_midam
# ✅ Saved MFCC features: data/mfcc_features_continuous_speech\bale_hatman_anjam_midam.npy
# ✅ Saved MFCC spectrogram: mfcc_plot_continuous_speech\mfcc_bale_hatman_anjam_midam.wav.png
# 📏 Avg length: 1.92s
# ⚡ Avg energy: 424.27
#
# 🔍 Processing Sentence: bale_salam
# ✅ Saved MFCC features: data/mfcc_features_continuous_speech\bale_salam.npy
# ✅ Saved MFCC spectrogram: mfcc_plot_continuous_speech\mfcc_bale_salam.wav.png
# 📏 Avg length: 1.38s
# ⚡ Avg energy: 405.26
#
# 🔍 Processing Sentence: fekhrkonam_bale
# ✅ Saved MFCC features: data/mfcc_features_continuous_speech\fekhrkonam_bale.npy
# ✅ Saved MFCC spectrogram: mfcc_plot_continuous_speech\mfcc_fekhrkonam_bale.wav.png
# 📏 Avg length: 1.63s
# ⚡ Avg energy: 569.94
#
# 🔍 Processing Sentence: felan_khodahafez
# ✅ Saved MFCC features: data/mfcc_features_continuous_speech\felan_khodahafez.npy
# ✅ Saved MFCC spectrogram: mfcc_plot_continuous_speech\mfcc_felan_khodahafez.wav.png
# 📏 Avg length: 1.12s
# ⚡ Avg energy: 479.00
#
# 🔍 Processing Sentence: kheili_moteshaker
# ✅ Saved MFCC features: data/mfcc_features_continuous_speech\kheili_moteshaker.npy
# ✅ Saved MFCC spectrogram: mfcc_plot_continuous_speech\mfcc_kheili_moteshaker.wav.png
# 📏 Avg length: 1.54s
# ⚡ Avg energy: 466.61
#
# 🔍 Processing Sentence: khir_intor_nist
# ✅ Saved MFCC features: data/mfcc_features_continuous_speech\khir_intor_nist.npy
# ✅ Saved MFCC spectrogram: mfcc_plot_continuous_speech\mfcc_khir_intor_nist.wav.png
# 📏 Avg length: 1.12s
# ⚡ Avg energy: 284.49
#
# 🔍 Processing Sentence: khodahafez_ta_faeda
# ✅ Saved MFCC features: data/mfcc_features_continuous_speech\khodahafez_ta_faeda.npy
# ✅ Saved MFCC spectrogram: mfcc_plot_continuous_speech\mfcc_khodahafez_ta_faeda.wav.png
# 📏 Avg length: 1.41s
# ⚡ Avg energy: 466.53
#
# 🔍 Processing Sentence: moteshakeram_lotf
# ✅ Saved MFCC features: data/mfcc_features_continuous_speech\moteshakeram_lotf.npy
# ✅ Saved MFCC spectrogram: mfcc_plot_continuous_speech\mfcc_moteshakeram_lotf.wav.png
# 📏 Avg length: 1.63s
# ⚡ Avg energy: 539.42
#
# 🔍 Processing Sentence: na_khir_ashtebah_shode
# ✅ Saved MFCC features: data/mfcc_features_continuous_speech\na_khir_ashtebah_shode.npy
# ✅ Saved MFCC spectrogram: mfcc_plot_continuous_speech\mfcc_na_khir_ashtebah_shode.wav.png
# 📏 Avg length: 1.47s
# ⚡ Avg energy: 436.50
#
# 🔍 Processing Sentence: no_key_01
# ✅ Saved MFCC features: data/mfcc_features_continuous_speech\no_key_01.npy
# ✅ Saved MFCC spectrogram: mfcc_plot_continuous_speech\mfcc_no_key_01.wav.png
# 📏 Avg length: 1.44s
# ⚡ Avg energy: 352.62
#
# 🔍 Processing Sentence: no_key_02
# ✅ Saved MFCC features: data/mfcc_features_continuous_speech\no_key_02.npy
# ✅ Saved MFCC spectrogram: mfcc_plot_continuous_speech\mfcc_no_key_02.wav.png
# 📏 Avg length: 1.50s
# ⚡ Avg energy: 307.26
#
# 🔍 Processing Sentence: no_key_03
# ✅ Saved MFCC features: data/mfcc_features_continuous_speech\no_key_03.npy
# ✅ Saved MFCC spectrogram: mfcc_plot_continuous_speech\mfcc_no_key_03.wav.png
# 📏 Avg length: 1.15s
# ⚡ Avg energy: 511.95
#
# 🔍 Processing Sentence: no_key_04
# ✅ Saved MFCC features: data/mfcc_features_continuous_speech\no_key_04.npy
# ✅ Saved MFCC spectrogram: mfcc_plot_continuous_speech\mfcc_no_key_04.wav.png
# 📏 Avg length: 1.50s
# ⚡ Avg energy: 422.77
#
# 🔍 Processing Sentence: no_key_05
# ✅ Saved MFCC features: data/mfcc_features_continuous_speech\no_key_05.npy
# ✅ Saved MFCC spectrogram: mfcc_plot_continuous_speech\mfcc_no_key_05.wav.png
# 📏 Avg length: 1.89s
# ⚡ Avg energy: 443.53
#
# 🔍 Processing Sentence: no_key_06
# ✅ Saved MFCC features: data/mfcc_features_continuous_speech\no_key_06.npy
# ✅ Saved MFCC spectrogram: mfcc_plot_continuous_speech\mfcc_no_key_06.wav.png
# 📏 Avg length: 1.31s
# ⚡ Avg energy: 484.68
#
# 🔍 Processing Sentence: no_key_07
# ✅ Saved MFCC features: data/mfcc_features_continuous_speech\no_key_07.npy
# ✅ Saved MFCC spectrogram: mfcc_plot_continuous_speech\mfcc_no_key_07.wav.png
# 📏 Avg length: 1.31s
# ⚡ Avg energy: 456.55
#
# 🔍 Processing Sentence: no_key_08
# ✅ Saved MFCC features: data/mfcc_features_continuous_speech\no_key_08.npy
# ✅ Saved MFCC spectrogram: mfcc_plot_continuous_speech\mfcc_no_key_08.wav.png
# 📏 Avg length: 0.90s
# ⚡ Avg energy: 527.75
#
# 🔍 Processing Sentence: no_key_09
# ✅ Saved MFCC features: data/mfcc_features_continuous_speech\no_key_09.npy
# ✅ Saved MFCC spectrogram: mfcc_plot_continuous_speech\mfcc_no_key_09.wav.png
# 📏 Avg length: 1.15s
# ⚡ Avg energy: 512.75
#
# 🔍 Processing Sentence: no_key_10
# ✅ Saved MFCC features: data/mfcc_features_continuous_speech\no_key_10.npy
# ✅ Saved MFCC spectrogram: mfcc_plot_continuous_speech\mfcc_no_key_10.wav.png
# 📏 Avg length: 1.25s
# ⚡ Avg energy: 570.12
#
# 🔍 Processing Sentence: salam_mo_kh
# ✅ Saved MFCC features: data/mfcc_features_continuous_speech\salam_mo_kh.npy
# ✅ Saved MFCC spectrogram: mfcc_plot_continuous_speech\mfcc_salam_mo_kh.wav.png
# 📏 Avg length: 2.14s
# ⚡ Avg energy: 381.97
#
# 🔍 Processing Sentence: salam_sob_be_kheir
# ✅ Saved MFCC features: data/mfcc_features_continuous_speech\salam_sob_be_kheir.npy
# ✅ Saved MFCC spectrogram: mfcc_plot_continuous_speech\mfcc_salam_sob_be_kheir.wav.png
# 📏 Avg length: 1.06s
# ⚡ Avg energy: 346.30
#
# 🔍 Processing Sentence: ye_salam_garm_be_hame
# ✅ Saved MFCC features: data/mfcc_features_continuous_speech\ye_salam_garm_be_hame.npy
# ✅ Saved MFCC spectrogram: mfcc_plot_continuous_speech\mfcc_ye_salam_garm_be_hame.wav.png
# 📏 Avg length: 1.54s
# ⚡ Avg energy: 366.94
#
# 🎉 Processing completed!

# %% [markdown]
# ### annotation

# %%
import os
import pygame
import json
import librosa
import soundfile as sf
import numpy as np

class AudioAnnotator:
    def __init__(self, audio_file, text):
        """
        ابزار برچسب‌گذاری دستی فایل‌های صوتی
        
        Args:
            audio_file: مسیر فایل صوتی
            text: متن جمله
        """
        self.audio_file = audio_file
        self.text = text
        self.annotations = []
    
    def play_segment(self, start_time, end_time):
        """
        پخش بخشی از فایل صوتی
        
        Args:
            start_time: زمان شروع (ثانیه)
            end_time: زمان پایان (ثانیه)
        """
        # بارگذاری فایل صوتی
        y, sr = librosa.load(self.audio_file, sr=None)
        start_sample = int(start_time * sr)
        end_sample = int(end_time * sr)
        segment = y[start_sample:end_sample]
        
        # ذخیره فایل موقت برای پخش
        temp_file = "temp_segment.wav"
        sf.write(temp_file, segment, sr)
        
        # پخش فایل موقت با استفاده از pygame
        pygame.mixer.init()
        pygame.mixer.music.load(temp_file)
        pygame.mixer.music.play()
        
        # صبر برای اتمام پخش
        while pygame.mixer.music.get_busy():
            pygame.time.Clock().tick(10)

    def add_annotation(self, word, start_time, end_time):
        """
        اضافه کردن برچسب برای یک کلمه کلیدی
        
        Args:
            word: کلمه کلیدی
            start_time: زمان شروع
            end_time: زمان پایان
        """
        # اعتبارسنجی ورودی‌ها
        if start_time < 0 or end_time < start_time:
            raise ValueError("زمان شروع یا پایان نامعتبر است.")
        
        # اضافه کردن به لیست annotations
        self.annotations.append({
            "word": word,
            "start_time": start_time,
            "end_time": end_time
        })
    
    def save_annotations(self, output_path):
        """
        ذخیره برچسب‌ها در فرمت JSON
        
        Args:
            output_path: مسیر ذخیره فایل JSON
        """
        data = {
            "filename": os.path.basename(self.audio_file),
            "text": self.text,
            "duration": librosa.get_duration(filename=self.audio_file),
            "keywords": self.annotations
        }
        
        with open(output_path, 'w', encoding='utf-8') as f:
            json.dump(data, f, ensure_ascii=False, indent=4)

# استفاده از annotator
def annotate_all_files(input_dir, output_dir):
    """
    برچسب‌گذاری تمام فایل‌های ضبط شده
    
    Args:
        input_dir: دایرکتوری حاوی فایل‌های صوتی
        output_dir: دایرکتوری ذخیره‌سازی برچسب‌ها
    """
    # بررسی وجود دایرکتوری خروجی
    os.makedirs(output_dir, exist_ok=True)

    # لیست کردن فایل‌های صوتی در دایرکتوری ورودی
    for filename in os.listdir(input_dir):
        if filename.endswith(".wav"):
            audio_file = os.path.join(input_dir, filename)
            text = "متن فرضی جمله"  # اینجا باید متن واقعی فایل را وارد کنید
            
            annotator = AudioAnnotator(audio_file, text)
            
            # شبیه‌سازی برچسب‌گذاری دستی برای هر فایل (شما باید این مراحل را به صورت دستی انجام دهید)
            # برای مثال:
            annotator.add_annotation("سلام", 0.2, 0.8)
            annotator.add_annotation("صبح", 1.0, 1.5)

            # ذخیره برچسب‌ها
            output_path = os.path.join(output_dir, f"{os.path.splitext(filename)[0]}.json")
            annotator.save_annotations(output_path)

# فراخوانی برچسب‌گذاری برای تمام فایل‌ها
input_dir = 'data/Sentence/'  # مسیر دایرکتوری فایل‌های صوتی
output_dir = 'data/annotations'  # مسیر دایرکتوری ذخیره‌سازی برچسب‌ها
annotate_all_files(input_dir, output_dir)
# Out:
# C:\Users\amir\AppData\Local\Temp\ipykernel_18528\513986499.py:78: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   "duration": librosa.get_duration(filename=self.audio_file),

# %% [markdown]
# ### SubsequenceDTW

# %%
import os
import json
import numpy as np
from scipy.spatial.distance import euclidean

class SubsequenceDTWKeywordDetector:
    def __init__(self, keyword_feature_dir='data/mfcc_features', 
                 speech_feature_dir='data/mfcc_features_continuous_speech', 
                 annotation_dir='data/annotations', 
                 output_dir='data/keyword_detections',
                 target_length=50, sample_rate=16000, hop_length=512):
        """
        Initialize the Subsequence DTW Keyword Detector.
        """
        self.keyword_feature_dir = keyword_feature_dir
        self.speech_feature_dir = speech_feature_dir
        self.annotation_dir = annotation_dir
        self.output_dir = output_dir
        self.target_length = target_length
        self.sample_rate = sample_rate
        self.hop_length = hop_length
        os.makedirs(self.output_dir, exist_ok=True)
        
        # Updated keyword_map to include "Khodahafez"
        self.keyword_map = {
            'Salam': 'سلام',
            'Bale': 'بله',
            'Kheir': 'خیر',
            'Motshakeram': 'متشکرم',
            'BesiarAali': 'بسیار عالی',
            'Khodahafez': 'خداحافظ'  # Added Khodahafez
        }

    def compute_subsequence_dtw(self, query, sequence, distance_metric='euclidean'):
        """
        Compute Subsequence DTW to find the best alignment of query in sequence.
        """
        n, m = query.shape[1], sequence.shape[1]
        cost_matrix = np.full((n + 1, m + 1), np.inf)
        cost_matrix[0, :] = 0
        predecessors = np.zeros((n + 1, m + 1, 2), dtype=int)

        for i in range(1, n + 1):
            for j in range(1, m + 1):
                if distance_metric == 'euclidean':
                    cost = euclidean(query[:, i-1], sequence[:, j-1])
                else:
                    raise ValueError("Unsupported distance metric")

                costs = [
                    cost_matrix[i-1, j-1],  # Match
                    cost_matrix[i-1, j],    # Insertion
                    cost_matrix[i, j-1]     # Deletion
                ]
                min_cost_idx = np.argmin(costs)
                cost_matrix[i, j] = cost + costs[min_cost_idx]
                predecessors[i, j] = [(i-1, j-1), (i-1, j), (i, j-1)][min_cost_idx]

        end_idx = np.argmin(cost_matrix[n, 1:]) + 1
        min_cost = cost_matrix[n, end_idx]
        path = []
        i, j = n, end_idx
        while i > 0:
            path.append((i-1, j-1))
            i, j = predecessors[i, j]
        path.reverse()
        start_idx = path[0][1] if path else 0
        return min_cost, start_idx, end_idx

    def frame_to_time(self, frame_idx):
        """
        Convert frame index to time in seconds.
        """
        return frame_idx * self.hop_length / self.sample_rate

    def detect_keywords(self, speech_file, keywords, threshold=40.0):
        """
        Detect keywords in a continuous speech file using Subsequence DTW.
        """
        speech_path = os.path.join(self.speech_feature_dir, speech_file)
        try:
            speech_mfcc = np.load(speech_path)
            print(f"Loaded speech MFCC: {speech_file}, Shape: {speech_mfcc.shape}")
        except FileNotFoundError:
            print(f"Error: Speech file {speech_path} not found.")
            return None

        if speech_mfcc.shape[0] != 39:
            print(f"Error: Unexpected shape for {speech_file}: {speech_mfcc.shape}. Expected (39, N).")
            return None

        annotation_path = os.path.join(self.annotation_dir, speech_file.replace('.npy', '.json'))
        try:
            with open(annotation_path, 'r', encoding='utf-8') as f:
                annotation = json.load(f)
            duration = annotation.get('duration', 0.0)
            text = annotation.get('text', '')
            print(f"Annotation loaded: {text}, Duration: {duration}")
        except FileNotFoundError:
            print(f"Warning: Annotation file {annotation_path} not found. Using default values.")
            duration = speech_mfcc.shape[1] * self.hop_length / self.sample_rate
            text = 'Unknown'

        # Filter keywords based on sentence text
        allowed_keywords = []
        for keyword in keywords:
            persian_keyword = self.keyword_map.get(keyword, keyword)
            if persian_keyword in text:
                allowed_keywords.append(keyword)
        print(f"Allowed keywords for {speech_file}: {allowed_keywords}")

        detections = {}
        for keyword in allowed_keywords:
            keyword_files = [f for f in os.listdir(self.keyword_feature_dir) 
                           if f.startswith(keyword + '_') and f.endswith('.npy')]
            if not keyword_files:
                print(f"Warning: No feature files found for keyword {keyword}.")
                continue

            best_distance = float('inf')
            best_detection = None
            for keyword_file in keyword_files:
                keyword_path = os.path.join(self.keyword_feature_dir, keyword_file)
                try:
                    keyword_mfcc = np.load(keyword_path)
                    print(f"Loaded keyword MFCC: {keyword_file}, Shape: {keyword_mfcc.shape}")
                except FileNotFoundError:
                    print(f"Error: Keyword file {keyword_path} not found.")
                    continue

                if keyword_mfcc.shape != (39, self.target_length):
                    print(f"Error: Unexpected shape for {keyword_file}: {keyword_mfcc.shape}. Expected (39, {self.target_length}).")
                    continue

                distance, start_idx, end_idx = self.compute_subsequence_dtw(keyword_mfcc, speech_mfcc)
                start_time = self.frame_to_time(start_idx)
                end_time = self.frame_to_time(end_idx)
                print(f"Keyword: {keyword_file}, DTW Distance: {distance:.2f}, Start Time: {start_time:.2f}s, End Time: {end_time:.2f}s")

                if distance < threshold and distance < best_distance:
                    best_distance = distance
                    best_detection = {
                        'word': self.keyword_map.get(keyword, keyword),
                        'start_time': round(start_time, 2),
                        'end_time': round(end_time, 2)
                    }

            if best_detection:
                detections[keyword] = best_detection

        # Convert detections to list and sort by start time
        output_detections = [det for det in detections.values() if det]
        output_detections.sort(key=lambda x: x['start_time'])

        output = {
            'filename': speech_file.replace('.npy', '.wav'),
            'text': text,
            'duration': round(duration, 6),
            'keywords': output_detections
        }

        output_path = os.path.join(self.output_dir, speech_file.replace('.npy', '.json'))
        with open(output_path, 'w', encoding='utf-8') as f:
            json.dump(output, f, ensure_ascii=False, indent=4)
        print(f"✅ Saved detections to {output_path}")
        return output

def process_all_speech_files():
    """
    Process all speech files in the speech feature directory.
    """
    detector = SubsequenceDTWKeywordDetector()
    keywords = ['Salam', 'Bale', 'Kheir', 'Motshakeram', 'BesiarAali', 'Khodahafez']  # Added 'Khodahafez'
    print(f"Keywords to search: {keywords}")
    
    for speech_file in os.listdir(detector.speech_feature_dir):
        if speech_file.endswith('.npy'):
            print(f"\n🔍 Processing speech file: {speech_file}")
            result = detector.detect_keywords(speech_file, keywords, threshold=40.0)
            if result:
                print(f"Detections: {result['keywords']}")

if __name__ == '__main__':
    process_all_speech_files()
# Out:
# Keywords to search: ['Salam', 'Bale', 'Kheir', 'Motshakeram', 'BesiarAali', 'Khodahafez']
#
# 🔍 Processing speech file: asre_be_kheir_salam.npy
# Loaded speech MFCC: asre_be_kheir_salam.npy, Shape: (39, 50)
# Annotation loaded:  عصر به خیر سلام , Duration: 2.5997708333333334
# Allowed keywords for asre_be_kheir_salam.npy: ['Salam', 'Kheir']
# Loaded keyword MFCC: Salam_000001.npy, Shape: (39, 50)
# Keyword: Salam_000001.npy, DTW Distance: 43.90, Start Time: 1.12s, End Time: 1.60s
# Loaded keyword MFCC: Salam_000002.npy, Shape: (39, 50)
# Keyword: Salam_000002.npy, DTW Distance: 50.79, Start Time: 1.12s, End Time: 1.60s
# Loaded keyword MFCC: Salam_000003.npy, Shape: (39, 50)
# Keyword: Salam_000003.npy, DTW Distance: 46.65, Start Time: 1.12s, End Time: 1.60s
# Loaded keyword MFCC: Salam_000004.npy, Shape: (39, 50)
# Keyword: Salam_000004.npy, DTW Distance: 49.71, Start Time: 1.12s, End Time: 1.60s
# Loaded keyword MFCC: Salam_000005.npy, Shape: (39, 50)
# Keyword: Salam_000005.npy, DTW Distance: 45.31, Start Time: 1.12s, End Time: 1.60s
# Loaded keyword MFCC: Salam_001.npy, Shape: (39, 50)
# Keyword: Salam_001.npy, DTW Distance: 40.43, Start Time: 1.09s, End Time: 1.60s
# Loaded keyword MFCC: Salam_002.npy, Shape: (39, 50)
# Keyword: Salam_002.npy, DTW Distance: 45.04, Start Time: 1.09s, End Time: 1.60s
# Loaded keyword MFCC: Salam_003.npy, Shape: (39, 50)
# Keyword: Salam_003.npy, DTW Distance: 43.68, Start Time: 1.09s, End Time: 1.60s
# Loaded keyword MFCC: Salam_004.npy, Shape: (39, 50)
# Keyword: Salam_004.npy, DTW Distance: 44.49, Start Time: 1.09s, End Time: 1.60s
# Loaded keyword MFCC: Salam_005.npy, Shape: (39, 50)
# Keyword: Salam_005.npy, DTW Distance: 45.59, Start Time: 1.09s, End Time: 1.60s
# Loaded keyword MFCC: Salam_01.npy, Shape: (39, 50)
# Keyword: Salam_01.npy, DTW Distance: 31.97, Start Time: 1.12s, End Time: 1.60s
# Loaded keyword MFCC: Salam_02.npy, Shape: (39, 50)
# Keyword: Salam_02.npy, DTW Distance: 35.09, Start Time: 1.12s, End Time: 1.60s
# Loaded keyword MFCC: Salam_03.npy, Shape: (39, 50)
# Keyword: Salam_03.npy, DTW Distance: 26.96, Start Time: 1.12s, End Time: 1.60s
# Loaded keyword MFCC: Salam_04.npy, Shape: (39, 50)
# Keyword: Salam_04.npy, DTW Distance: 30.72, Start Time: 1.15s, End Time: 1.60s
# Loaded keyword MFCC: Salam_05.npy, Shape: (39, 50)
# Keyword: Salam_05.npy, DTW Distance: 33.43, Start Time: 1.12s, End Time: 1.60s
# Loaded keyword MFCC: Kheir_000001.npy, Shape: (39, 50)
# Keyword: Kheir_000001.npy, DTW Distance: 47.37, Start Time: 0.32s, End Time: 1.06s
# Loaded keyword MFCC: Kheir_000002.npy, Shape: (39, 50)
# Keyword: Kheir_000002.npy, DTW Distance: 48.21, Start Time: 0.38s, End Time: 1.06s
# Loaded keyword MFCC: Kheir_000003.npy, Shape: (39, 50)
# Keyword: Kheir_000003.npy, DTW Distance: 50.04, Start Time: 0.42s, End Time: 1.09s
# Loaded keyword MFCC: Kheir_000004.npy, Shape: (39, 50)
# Keyword: Kheir_000004.npy, DTW Distance: 53.66, Start Time: 0.32s, End Time: 1.15s
# Loaded keyword MFCC: Kheir_000005.npy, Shape: (39, 50)
# Keyword: Kheir_000005.npy, DTW Distance: 50.44, Start Time: 0.32s, End Time: 1.15s
# Loaded keyword MFCC: Kheir_001.npy, Shape: (39, 50)
# Keyword: Kheir_001.npy, DTW Distance: 39.03, Start Time: 0.67s, End Time: 1.15s
# Loaded keyword MFCC: Kheir_002.npy, Shape: (39, 50)
# Keyword: Kheir_002.npy, DTW Distance: 39.42, Start Time: 0.64s, End Time: 1.09s
# Loaded keyword MFCC: Kheir_003.npy, Shape: (39, 50)
# Keyword: Kheir_003.npy, DTW Distance: 44.17, Start Time: 0.45s, End Time: 1.15s
# Loaded keyword MFCC: Kheir_004.npy, Shape: (39, 50)
# Keyword: Kheir_004.npy, DTW Distance: 41.46, Start Time: 0.64s, End Time: 1.15s
# Loaded keyword MFCC: Kheir_005.npy, Shape: (39, 50)
# Keyword: Kheir_005.npy, DTW Distance: 43.03, Start Time: 0.42s, End Time: 1.15s
# Loaded keyword MFCC: Kheir_01.npy, Shape: (39, 50)
# Keyword: Kheir_01.npy, DTW Distance: 40.83, Start Time: 0.67s, End Time: 1.15s
# Loaded keyword MFCC: Kheir_02.npy, Shape: (39, 50)
# Keyword: Kheir_02.npy, DTW Distance: 43.37, Start Time: 0.67s, End Time: 1.06s
# Loaded keyword MFCC: Kheir_03.npy, Shape: (39, 50)
# Keyword: Kheir_03.npy, DTW Distance: 35.99, Start Time: 0.67s, End Time: 1.06s
# Loaded keyword MFCC: Kheir_04.npy, Shape: (39, 50)
# Keyword: Kheir_04.npy, DTW Distance: 41.18, Start Time: 0.64s, End Time: 1.06s
# Loaded keyword MFCC: Kheir_05.npy, Shape: (39, 50)
# Keyword: Kheir_05.npy, DTW Distance: 36.85, Start Time: 0.64s, End Time: 1.06s
# ✅ Saved detections to data/keyword_detections\asre_be_kheir_salam.json
# Detections: [{'word': 'خیر', 'start_time': np.float64(0.67), 'end_time': np.float64(1.06)}, {'word': 'سلام', 'start_time': np.float64(1.12), 'end_time': np.float64(1.6)}]
#
# 🔍 Processing speech file: bale_hatman_anjam_midam.npy
# Loaded speech MFCC: bale_hatman_anjam_midam.npy, Shape: (39, 50)
# Annotation loaded:   بله حتما انجام میدهم, Duration: 2.5197708333333333
# Allowed keywords for bale_hatman_anjam_midam.npy: ['Bale']
# Loaded keyword MFCC: Bale_000001.npy, Shape: (39, 50)
# Keyword: Bale_000001.npy, DTW Distance: 38.95, Start Time: 0.35s, End Time: 0.90s
# Loaded keyword MFCC: Bale_000002.npy, Shape: (39, 50)
# Keyword: Bale_000002.npy, DTW Distance: 37.62, Start Time: 0.32s, End Time: 0.90s
# Loaded keyword MFCC: Bale_000003.npy, Shape: (39, 50)
# Keyword: Bale_000003.npy, DTW Distance: 41.36, Start Time: 0.35s, End Time: 0.90s
# Loaded keyword MFCC: Bale_000004.npy, Shape: (39, 50)
# Keyword: Bale_000004.npy, DTW Distance: 36.03, Start Time: 0.35s, End Time: 0.90s
# Loaded keyword MFCC: Bale_000005.npy, Shape: (39, 50)
# Keyword: Bale_000005.npy, DTW Distance: 37.23, Start Time: 0.35s, End Time: 0.90s
# Loaded keyword MFCC: Bale_001.npy, Shape: (39, 50)
# Keyword: Bale_001.npy, DTW Distance: 38.14, Start Time: 0.70s, End Time: 0.90s
# Loaded keyword MFCC: Bale_002.npy, Shape: (39, 50)
# Keyword: Bale_002.npy, DTW Distance: 30.93, Start Time: 1.09s, End Time: 1.22s
# Loaded keyword MFCC: Bale_003.npy, Shape: (39, 50)
# Keyword: Bale_003.npy, DTW Distance: 32.79, Start Time: 0.70s, End Time: 0.93s
# Loaded keyword MFCC: Bale_004.npy, Shape: (39, 50)
# Keyword: Bale_004.npy, DTW Distance: 32.28, Start Time: 1.09s, End Time: 1.22s
# Loaded keyword MFCC: Bale_005.npy, Shape: (39, 50)
# Keyword: Bale_005.npy, DTW Distance: 30.31, Start Time: 0.86s, End Time: 1.22s
# Loaded keyword MFCC: Bale_01.npy, Shape: (39, 50)
# Keyword: Bale_01.npy, DTW Distance: 41.25, Start Time: 1.44s, End Time: 1.60s
# Loaded keyword MFCC: Bale_02.npy, Shape: (39, 50)
# Keyword: Bale_02.npy, DTW Distance: 44.04, Start Time: 0.38s, End Time: 0.90s
# Loaded keyword MFCC: Bale_03.npy, Shape: (39, 50)
# Keyword: Bale_03.npy, DTW Distance: 30.04, Start Time: 0.38s, End Time: 0.90s
# Loaded keyword MFCC: Bale_04.npy, Shape: (39, 50)
# Keyword: Bale_04.npy, DTW Distance: 34.75, Start Time: 0.38s, End Time: 0.90s
# Loaded keyword MFCC: Bale_05.npy, Shape: (39, 50)
# Keyword: Bale_05.npy, DTW Distance: 31.80, Start Time: 0.38s, End Time: 0.90s
# ✅ Saved detections to data/keyword_detections\bale_hatman_anjam_midam.json
# Detections: [{'word': 'بله', 'start_time': np.float64(0.38), 'end_time': np.float64(0.9)}]
#
# 🔍 Processing speech file: bale_salam.npy
# Loaded speech MFCC: bale_salam.npy, Shape: (39, 50)
# Annotation loaded:   بله سلام عرض کردم, Duration: 2.439770833333333
# Allowed keywords for bale_salam.npy: ['Salam', 'Bale']
# Loaded keyword MFCC: Salam_000001.npy, Shape: (39, 50)
# Keyword: Salam_000001.npy, DTW Distance: 36.07, Start Time: 1.12s, End Time: 1.60s
# Loaded keyword MFCC: Salam_000002.npy, Shape: (39, 50)
# Keyword: Salam_000002.npy, DTW Distance: 44.11, Start Time: 1.12s, End Time: 1.60s
# Loaded keyword MFCC: Salam_000003.npy, Shape: (39, 50)
# Keyword: Salam_000003.npy, DTW Distance: 41.59, Start Time: 1.15s, End Time: 1.60s
# Loaded keyword MFCC: Salam_000004.npy, Shape: (39, 50)
# Keyword: Salam_000004.npy, DTW Distance: 46.25, Start Time: 0.51s, End Time: 0.64s
# Loaded keyword MFCC: Salam_000005.npy, Shape: (39, 50)
# Keyword: Salam_000005.npy, DTW Distance: 38.02, Start Time: 1.12s, End Time: 1.60s
# Loaded keyword MFCC: Salam_001.npy, Shape: (39, 50)
# Keyword: Salam_001.npy, DTW Distance: 34.74, Start Time: 1.12s, End Time: 1.60s
# Loaded keyword MFCC: Salam_002.npy, Shape: (39, 50)
# Keyword: Salam_002.npy, DTW Distance: 38.27, Start Time: 1.12s, End Time: 1.60s
# Loaded keyword MFCC: Salam_003.npy, Shape: (39, 50)
# Keyword: Salam_003.npy, DTW Distance: 35.16, Start Time: 1.12s, End Time: 1.60s
# Loaded keyword MFCC: Salam_004.npy, Shape: (39, 50)
# Keyword: Salam_004.npy, DTW Distance: 35.37, Start Time: 1.12s, End Time: 1.60s
# Loaded keyword MFCC: Salam_005.npy, Shape: (39, 50)
# Keyword: Salam_005.npy, DTW Distance: 35.57, Start Time: 1.12s, End Time: 1.60s
# Loaded keyword MFCC: Salam_01.npy, Shape: (39, 50)
# Keyword: Salam_01.npy, DTW Distance: 35.67, Start Time: 0.54s, End Time: 1.09s
# Loaded keyword MFCC: Salam_02.npy, Shape: (39, 50)
# Keyword: Salam_02.npy, DTW Distance: 31.81, Start Time: 0.54s, End Time: 1.09s
# Loaded keyword MFCC: Salam_03.npy, Shape: (39, 50)
# Keyword: Salam_03.npy, DTW Distance: 38.57, Start Time: 0.54s, End Time: 1.09s
# Loaded keyword MFCC: Salam_04.npy, Shape: (39, 50)
# Keyword: Salam_04.npy, DTW Distance: 34.73, Start Time: 0.58s, End Time: 1.09s
# Loaded keyword MFCC: Salam_05.npy, Shape: (39, 50)
# Keyword: Salam_05.npy, DTW Distance: 38.38, Start Time: 0.54s, End Time: 1.09s
# Loaded keyword MFCC: Bale_000001.npy, Shape: (39, 50)
# Keyword: Bale_000001.npy, DTW Distance: 33.38, Start Time: 0.00s, End Time: 0.58s
# Loaded keyword MFCC: Bale_000002.npy, Shape: (39, 50)
# Keyword: Bale_000002.npy, DTW Distance: 32.90, Start Time: 0.00s, End Time: 0.58s
# Loaded keyword MFCC: Bale_000003.npy, Shape: (39, 50)
# Keyword: Bale_000003.npy, DTW Distance: 36.63, Start Time: 0.00s, End Time: 0.58s
# Loaded keyword MFCC: Bale_000004.npy, Shape: (39, 50)
# Keyword: Bale_000004.npy, DTW Distance: 31.18, Start Time: 0.00s, End Time: 0.58s
# Loaded keyword MFCC: Bale_000005.npy, Shape: (39, 50)
# Keyword: Bale_000005.npy, DTW Distance: 32.21, Start Time: 0.00s, End Time: 0.58s
# Loaded keyword MFCC: Bale_001.npy, Shape: (39, 50)
# Keyword: Bale_001.npy, DTW Distance: 43.62, Start Time: 0.00s, End Time: 0.54s
# Loaded keyword MFCC: Bale_002.npy, Shape: (39, 50)
# Keyword: Bale_002.npy, DTW Distance: 35.00, Start Time: 1.28s, End Time: 1.60s
# Loaded keyword MFCC: Bale_003.npy, Shape: (39, 50)
# Keyword: Bale_003.npy, DTW Distance: 37.79, Start Time: 0.03s, End Time: 0.54s
# Loaded keyword MFCC: Bale_004.npy, Shape: (39, 50)
# Keyword: Bale_004.npy, DTW Distance: 30.93, Start Time: 1.28s, End Time: 1.60s
# Loaded keyword MFCC: Bale_005.npy, Shape: (39, 50)
# Keyword: Bale_005.npy, DTW Distance: 34.27, Start Time: 1.15s, End Time: 1.60s
# Loaded keyword MFCC: Bale_01.npy, Shape: (39, 50)
# Keyword: Bale_01.npy, DTW Distance: 50.53, Start Time: 0.03s, End Time: 0.61s
# Loaded keyword MFCC: Bale_02.npy, Shape: (39, 50)
# Keyword: Bale_02.npy, DTW Distance: 47.42, Start Time: 0.00s, End Time: 0.58s
# Loaded keyword MFCC: Bale_03.npy, Shape: (39, 50)
# Keyword: Bale_03.npy, DTW Distance: 26.68, Start Time: 0.00s, End Time: 0.54s
# Loaded keyword MFCC: Bale_04.npy, Shape: (39, 50)
# Keyword: Bale_04.npy, DTW Distance: 32.70, Start Time: 0.00s, End Time: 0.58s
# Loaded keyword MFCC: Bale_05.npy, Shape: (39, 50)
# Keyword: Bale_05.npy, DTW Distance: 36.60, Start Time: 0.00s, End Time: 0.54s
# ✅ Saved detections to data/keyword_detections\bale_salam.json
# Detections: [{'word': 'بله', 'start_time': np.float64(0.0), 'end_time': np.float64(0.54)}, {'word': 'سلام', 'start_time': np.float64(0.54), 'end_time': np.float64(1.09)}]
#
# 🔍 Processing speech file: fekhrkonam_bale.npy
# Loaded speech MFCC: fekhrkonam_bale.npy, Shape: (39, 50)
# Annotation loaded: فکر کنم بله, Duration: 2.5197708333333333
# Allowed keywords for fekhrkonam_bale.npy: ['Bale']
# Loaded keyword MFCC: Bale_000001.npy, Shape: (39, 50)
# Keyword: Bale_000001.npy, DTW Distance: 46.64, Start Time: 0.93s, End Time: 1.60s
# Loaded keyword MFCC: Bale_000002.npy, Shape: (39, 50)
# Keyword: Bale_000002.npy, DTW Distance: 47.84, Start Time: 0.93s, End Time: 1.60s
# Loaded keyword MFCC: Bale_000003.npy, Shape: (39, 50)
# Keyword: Bale_000003.npy, DTW Distance: 48.05, Start Time: 0.93s, End Time: 1.60s
# Loaded keyword MFCC: Bale_000004.npy, Shape: (39, 50)
# Keyword: Bale_000004.npy, DTW Distance: 43.43, Start Time: 0.93s, End Time: 1.60s
# Loaded keyword MFCC: Bale_000005.npy, Shape: (39, 50)
# Keyword: Bale_000005.npy, DTW Distance: 48.75, Start Time: 0.93s, End Time: 1.60s
# Loaded keyword MFCC: Bale_001.npy, Shape: (39, 50)
# Keyword: Bale_001.npy, DTW Distance: 42.50, Start Time: 1.25s, End Time: 1.60s
# Loaded keyword MFCC: Bale_002.npy, Shape: (39, 50)
# Keyword: Bale_002.npy, DTW Distance: 37.86, Start Time: 1.09s, End Time: 1.60s
# Loaded keyword MFCC: Bale_003.npy, Shape: (39, 50)
# Keyword: Bale_003.npy, DTW Distance: 41.88, Start Time: 0.93s, End Time: 1.60s
# Loaded keyword MFCC: Bale_004.npy, Shape: (39, 50)
# Keyword: Bale_004.npy, DTW Distance: 39.36, Start Time: 1.41s, End Time: 1.60s
# Loaded keyword MFCC: Bale_005.npy, Shape: (39, 50)
# Keyword: Bale_005.npy, DTW Distance: 37.65, Start Time: 1.25s, End Time: 1.60s
# Loaded keyword MFCC: Bale_01.npy, Shape: (39, 50)
# Keyword: Bale_01.npy, DTW Distance: 37.35, Start Time: 1.28s, End Time: 1.60s
# Loaded keyword MFCC: Bale_02.npy, Shape: (39, 50)
# Keyword: Bale_02.npy, DTW Distance: 48.46, Start Time: 0.93s, End Time: 1.60s
# Loaded keyword MFCC: Bale_03.npy, Shape: (39, 50)
# Keyword: Bale_03.npy, DTW Distance: 42.89, Start Time: 0.38s, End Time: 0.80s
# Loaded keyword MFCC: Bale_04.npy, Shape: (39, 50)
# Keyword: Bale_04.npy, DTW Distance: 40.61, Start Time: 0.90s, End Time: 1.60s
# Loaded keyword MFCC: Bale_05.npy, Shape: (39, 50)
# Keyword: Bale_05.npy, DTW Distance: 42.17, Start Time: 0.93s, End Time: 1.60s
# ✅ Saved detections to data/keyword_detections\fekhrkonam_bale.json
# Detections: [{'word': 'بله', 'start_time': np.float64(1.28), 'end_time': np.float64(1.6)}]
#
# 🔍 Processing speech file: felan_khodahafez.npy
# Loaded speech MFCC: felan_khodahafez.npy, Shape: (39, 50)
# Annotation loaded: فعلا خداحافظ, Duration: 2.4797708333333333
# Allowed keywords for felan_khodahafez.npy: ['Khodahafez']
# Loaded keyword MFCC: Khodahafez_000001.npy, Shape: (39, 50)
# Keyword: Khodahafez_000001.npy, DTW Distance: 30.66, Start Time: 0.58s, End Time: 1.57s
# Loaded keyword MFCC: Khodahafez_000002.npy, Shape: (39, 50)
# Keyword: Khodahafez_000002.npy, DTW Distance: 32.24, Start Time: 0.58s, End Time: 1.57s
# Loaded keyword MFCC: Khodahafez_000003.npy, Shape: (39, 50)
# Keyword: Khodahafez_000003.npy, DTW Distance: 36.87, Start Time: 0.99s, End Time: 1.57s
# Loaded keyword MFCC: Khodahafez_000004.npy, Shape: (39, 50)
# Keyword: Khodahafez_000004.npy, DTW Distance: 30.99, Start Time: 0.58s, End Time: 1.60s
# Loaded keyword MFCC: Khodahafez_000005.npy, Shape: (39, 50)
# Keyword: Khodahafez_000005.npy, DTW Distance: 35.37, Start Time: 0.58s, End Time: 1.57s
# Loaded keyword MFCC: Khodahafez_001.npy, Shape: (39, 50)
# Keyword: Khodahafez_001.npy, DTW Distance: 28.91, Start Time: 0.58s, End Time: 1.57s
# Loaded keyword MFCC: Khodahafez_002.npy, Shape: (39, 50)
# Keyword: Khodahafez_002.npy, DTW Distance: 29.35, Start Time: 0.58s, End Time: 1.57s
# Loaded keyword MFCC: Khodahafez_003.npy, Shape: (39, 50)
# Keyword: Khodahafez_003.npy, DTW Distance: 34.40, Start Time: 0.58s, End Time: 1.57s
# Loaded keyword MFCC: Khodahafez_004.npy, Shape: (39, 50)
# Keyword: Khodahafez_004.npy, DTW Distance: 26.62, Start Time: 0.58s, End Time: 1.54s
# Loaded keyword MFCC: Khodahafez_005.npy, Shape: (39, 50)
# Keyword: Khodahafez_005.npy, DTW Distance: 29.35, Start Time: 0.58s, End Time: 1.54s
# ✅ Saved detections to data/keyword_detections\felan_khodahafez.json
# Detections: [{'word': 'خداحافظ', 'start_time': np.float64(0.58), 'end_time': np.float64(1.54)}]
#
# 🔍 Processing speech file: kheili_moteshaker.npy
# Loaded speech MFCC: kheili_moteshaker.npy, Shape: (39, 50)
# Annotation loaded:  حیلی متشکرم از شما , Duration: 2.6397708333333334
# Allowed keywords for kheili_moteshaker.npy: ['Motshakeram']
# Loaded keyword MFCC: Motshakeram_000001.npy, Shape: (39, 50)
# Keyword: Motshakeram_000001.npy, DTW Distance: 44.63, Start Time: 0.48s, End Time: 1.25s
# Loaded keyword MFCC: Motshakeram_000002.npy, Shape: (39, 50)
# Keyword: Motshakeram_000002.npy, DTW Distance: 45.25, Start Time: 0.58s, End Time: 1.28s
# Loaded keyword MFCC: Motshakeram_000003.npy, Shape: (39, 50)
# Keyword: Motshakeram_000003.npy, DTW Distance: 47.96, Start Time: 0.48s, End Time: 1.25s
# Loaded keyword MFCC: Motshakeram_000004.npy, Shape: (39, 50)
# Keyword: Motshakeram_000004.npy, DTW Distance: 48.89, Start Time: 0.48s, End Time: 1.28s
# Loaded keyword MFCC: Motshakeram_000005.npy, Shape: (39, 50)
# Keyword: Motshakeram_000005.npy, DTW Distance: 49.76, Start Time: 0.48s, End Time: 1.25s
# Loaded keyword MFCC: Motshakeram_001.npy, Shape: (39, 50)
# Keyword: Motshakeram_001.npy, DTW Distance: 44.26, Start Time: 0.45s, End Time: 1.25s
# Loaded keyword MFCC: Motshakeram_002.npy, Shape: (39, 50)
# Keyword: Motshakeram_002.npy, DTW Distance: 46.78, Start Time: 0.26s, End Time: 1.25s
# Loaded keyword MFCC: Motshakeram_003.npy, Shape: (39, 50)
# Keyword: Motshakeram_003.npy, DTW Distance: 46.41, Start Time: 0.22s, End Time: 1.25s
# Loaded keyword MFCC: Motshakeram_004.npy, Shape: (39, 50)
# Keyword: Motshakeram_004.npy, DTW Distance: 43.95, Start Time: 0.48s, End Time: 1.25s
# Loaded keyword MFCC: Motshakeram_005.npy, Shape: (39, 50)
# Keyword: Motshakeram_005.npy, DTW Distance: 46.09, Start Time: 0.48s, End Time: 1.25s
# Loaded keyword MFCC: Motshakeram_01.npy, Shape: (39, 50)
# Keyword: Motshakeram_01.npy, DTW Distance: 40.11, Start Time: 0.32s, End Time: 1.25s
# Loaded keyword MFCC: Motshakeram_02.npy, Shape: (39, 50)
# Keyword: Motshakeram_02.npy, DTW Distance: 38.52, Start Time: 0.45s, End Time: 1.25s
# Loaded keyword MFCC: Motshakeram_03.npy, Shape: (39, 50)
# Keyword: Motshakeram_03.npy, DTW Distance: 40.95, Start Time: 0.26s, End Time: 1.25s
# Loaded keyword MFCC: Motshakeram_04.npy, Shape: (39, 50)
# Keyword: Motshakeram_04.npy, DTW Distance: 36.64, Start Time: 0.45s, End Time: 1.25s
# Loaded keyword MFCC: Motshakeram_05.npy, Shape: (39, 50)
# Keyword: Motshakeram_05.npy, DTW Distance: 33.73, Start Time: 0.45s, End Time: 1.25s
# ✅ Saved detections to data/keyword_detections\kheili_moteshaker.json
# Detections: [{'word': 'متشکرم', 'start_time': np.float64(0.45), 'end_time': np.float64(1.25)}]
#
# 🔍 Processing speech file: khir_intor_nist.npy
# Loaded speech MFCC: khir_intor_nist.npy, Shape: (39, 50)
# Annotation loaded: خیر اینطور نیست, Duration: 2.439770833333333
# Allowed keywords for khir_intor_nist.npy: ['Kheir']
# Loaded keyword MFCC: Kheir_000001.npy, Shape: (39, 50)
# Keyword: Kheir_000001.npy, DTW Distance: 47.61, Start Time: 0.10s, End Time: 0.61s
# Loaded keyword MFCC: Kheir_000002.npy, Shape: (39, 50)
# Keyword: Kheir_000002.npy, DTW Distance: 44.87, Start Time: 0.00s, End Time: 0.61s
# Loaded keyword MFCC: Kheir_000003.npy, Shape: (39, 50)
# Keyword: Kheir_000003.npy, DTW Distance: 48.45, Start Time: 0.00s, End Time: 0.61s
# Loaded keyword MFCC: Kheir_000004.npy, Shape: (39, 50)
# Keyword: Kheir_000004.npy, DTW Distance: 50.94, Start Time: 0.00s, End Time: 0.61s
# Loaded keyword MFCC: Kheir_000005.npy, Shape: (39, 50)
# Keyword: Kheir_000005.npy, DTW Distance: 51.80, Start Time: 0.00s, End Time: 0.61s
# Loaded keyword MFCC: Kheir_001.npy, Shape: (39, 50)
# Keyword: Kheir_001.npy, DTW Distance: 40.61, Start Time: 0.00s, End Time: 1.02s
# Loaded keyword MFCC: Kheir_002.npy, Shape: (39, 50)
# Keyword: Kheir_002.npy, DTW Distance: 42.97, Start Time: 0.00s, End Time: 1.02s
# Loaded keyword MFCC: Kheir_003.npy, Shape: (39, 50)
# Keyword: Kheir_003.npy, DTW Distance: 44.45, Start Time: 0.00s, End Time: 0.61s
# Loaded keyword MFCC: Kheir_004.npy, Shape: (39, 50)
# Keyword: Kheir_004.npy, DTW Distance: 46.45, Start Time: 0.00s, End Time: 0.61s
# Loaded keyword MFCC: Kheir_005.npy, Shape: (39, 50)
# Keyword: Kheir_005.npy, DTW Distance: 46.45, Start Time: 0.00s, End Time: 1.02s
# Loaded keyword MFCC: Kheir_01.npy, Shape: (39, 50)
# Keyword: Kheir_01.npy, DTW Distance: 35.56, Start Time: 0.10s, End Time: 0.61s
# Loaded keyword MFCC: Kheir_02.npy, Shape: (39, 50)
# Keyword: Kheir_02.npy, DTW Distance: 37.27, Start Time: 0.00s, End Time: 0.61s
# Loaded keyword MFCC: Kheir_03.npy, Shape: (39, 50)
# Keyword: Kheir_03.npy, DTW Distance: 30.59, Start Time: 0.00s, End Time: 0.61s
# Loaded keyword MFCC: Kheir_04.npy, Shape: (39, 50)
# Keyword: Kheir_04.npy, DTW Distance: 33.31, Start Time: 0.00s, End Time: 0.99s
# Loaded keyword MFCC: Kheir_05.npy, Shape: (39, 50)
# Keyword: Kheir_05.npy, DTW Distance: 32.33, Start Time: 0.00s, End Time: 0.61s
# ✅ Saved detections to data/keyword_detections\khir_intor_nist.json
# Detections: [{'word': 'خیر', 'start_time': np.float64(0.0), 'end_time': np.float64(0.61)}]
#
# 🔍 Processing speech file: khodahafez_ta_faeda.npy
# Loaded speech MFCC: khodahafez_ta_faeda.npy, Shape: (39, 50)
# Annotation loaded: خداحافظ تا فردا, Duration: 2.5597708333333333
# Allowed keywords for khodahafez_ta_faeda.npy: ['Khodahafez']
# Loaded keyword MFCC: Khodahafez_000001.npy, Shape: (39, 50)
# Keyword: Khodahafez_000001.npy, DTW Distance: 34.97, Start Time: 0.00s, End Time: 0.83s
# Loaded keyword MFCC: Khodahafez_000002.npy, Shape: (39, 50)
# Keyword: Khodahafez_000002.npy, DTW Distance: 34.40, Start Time: 0.00s, End Time: 0.86s
# Loaded keyword MFCC: Khodahafez_000003.npy, Shape: (39, 50)
# Keyword: Khodahafez_000003.npy, DTW Distance: 34.60, Start Time: 0.00s, End Time: 0.83s
# Loaded keyword MFCC: Khodahafez_000004.npy, Shape: (39, 50)
# Keyword: Khodahafez_000004.npy, DTW Distance: 33.19, Start Time: 0.00s, End Time: 0.83s
# Loaded keyword MFCC: Khodahafez_000005.npy, Shape: (39, 50)
# Keyword: Khodahafez_000005.npy, DTW Distance: 38.10, Start Time: 0.00s, End Time: 0.83s
# Loaded keyword MFCC: Khodahafez_001.npy, Shape: (39, 50)
# Keyword: Khodahafez_001.npy, DTW Distance: 32.36, Start Time: 0.00s, End Time: 0.83s
# Loaded keyword MFCC: Khodahafez_002.npy, Shape: (39, 50)
# Keyword: Khodahafez_002.npy, DTW Distance: 28.52, Start Time: 0.00s, End Time: 0.83s
# Loaded keyword MFCC: Khodahafez_003.npy, Shape: (39, 50)
# Keyword: Khodahafez_003.npy, DTW Distance: 26.03, Start Time: 0.00s, End Time: 0.83s
# Loaded keyword MFCC: Khodahafez_004.npy, Shape: (39, 50)
# Keyword: Khodahafez_004.npy, DTW Distance: 30.27, Start Time: 0.00s, End Time: 0.83s
# Loaded keyword MFCC: Khodahafez_005.npy, Shape: (39, 50)
# Keyword: Khodahafez_005.npy, DTW Distance: 28.79, Start Time: 0.00s, End Time: 0.83s
# ✅ Saved detections to data/keyword_detections\khodahafez_ta_faeda.json
# Detections: [{'word': 'خداحافظ', 'start_time': np.float64(0.0), 'end_time': np.float64(0.83)}]
#
# 🔍 Processing speech file: moteshakeram_lotf.npy
# Loaded speech MFCC: moteshakeram_lotf.npy, Shape: (39, 50)
# Annotation loaded: متشکرم لطف کردید, Duration: 2.6397708333333334
# Allowed keywords for moteshakeram_lotf.npy: ['Motshakeram']
# Loaded keyword MFCC: Motshakeram_000001.npy, Shape: (39, 50)
# Keyword: Motshakeram_000001.npy, DTW Distance: 40.38, Start Time: 0.00s, End Time: 0.86s
# Loaded keyword MFCC: Motshakeram_000002.npy, Shape: (39, 50)
# Keyword: Motshakeram_000002.npy, DTW Distance: 44.71, Start Time: 0.26s, End Time: 0.86s
# Loaded keyword MFCC: Motshakeram_000003.npy, Shape: (39, 50)
# Keyword: Motshakeram_000003.npy, DTW Distance: 45.55, Start Time: 0.00s, End Time: 0.86s
# Loaded keyword MFCC: Motshakeram_000004.npy, Shape: (39, 50)
# Keyword: Motshakeram_000004.npy, DTW Distance: 47.15, Start Time: 0.00s, End Time: 0.86s
# Loaded keyword MFCC: Motshakeram_000005.npy, Shape: (39, 50)
# Keyword: Motshakeram_000005.npy, DTW Distance: 47.51, Start Time: 0.00s, End Time: 0.86s
# Loaded keyword MFCC: Motshakeram_001.npy, Shape: (39, 50)
# Keyword: Motshakeram_001.npy, DTW Distance: 42.49, Start Time: 0.03s, End Time: 0.86s
# Loaded keyword MFCC: Motshakeram_002.npy, Shape: (39, 50)
# Keyword: Motshakeram_002.npy, DTW Distance: 41.91, Start Time: 0.00s, End Time: 0.86s
# Loaded keyword MFCC: Motshakeram_003.npy, Shape: (39, 50)
# Keyword: Motshakeram_003.npy, DTW Distance: 42.38, Start Time: 0.00s, End Time: 0.86s
# Loaded keyword MFCC: Motshakeram_004.npy, Shape: (39, 50)
# Keyword: Motshakeram_004.npy, DTW Distance: 42.80, Start Time: 0.00s, End Time: 0.86s
# Loaded keyword MFCC: Motshakeram_005.npy, Shape: (39, 50)
# Keyword: Motshakeram_005.npy, DTW Distance: 43.09, Start Time: 0.00s, End Time: 0.86s
# Loaded keyword MFCC: Motshakeram_01.npy, Shape: (39, 50)
# Keyword: Motshakeram_01.npy, DTW Distance: 40.57, Start Time: 0.00s, End Time: 0.86s
# Loaded keyword MFCC: Motshakeram_02.npy, Shape: (39, 50)
# Keyword: Motshakeram_02.npy, DTW Distance: 39.14, Start Time: 0.00s, End Time: 0.86s
# Loaded keyword MFCC: Motshakeram_03.npy, Shape: (39, 50)
# Keyword: Motshakeram_03.npy, DTW Distance: 42.96, Start Time: 0.00s, End Time: 0.86s
# Loaded keyword MFCC: Motshakeram_04.npy, Shape: (39, 50)
# Keyword: Motshakeram_04.npy, DTW Distance: 37.33, Start Time: 0.00s, End Time: 0.86s
# Loaded keyword MFCC: Motshakeram_05.npy, Shape: (39, 50)
# Keyword: Motshakeram_05.npy, DTW Distance: 34.39, Start Time: 0.03s, End Time: 0.86s
# ✅ Saved detections to data/keyword_detections\moteshakeram_lotf.json
# Detections: [{'word': 'متشکرم', 'start_time': np.float64(0.03), 'end_time': np.float64(0.86)}]
#
# 🔍 Processing speech file: na_khir_ashtebah_shode.npy
# Loaded speech MFCC: na_khir_ashtebah_shode.npy, Shape: (39, 50)
# Annotation loaded: نه خیر اشتباه شده, Duration: 2.6397708333333334
# Allowed keywords for na_khir_ashtebah_shode.npy: ['Kheir']
# Loaded keyword MFCC: Kheir_000001.npy, Shape: (39, 50)
# Keyword: Kheir_000001.npy, DTW Distance: 45.34, Start Time: 0.32s, End Time: 0.86s
# Loaded keyword MFCC: Kheir_000002.npy, Shape: (39, 50)
# Keyword: Kheir_000002.npy, DTW Distance: 43.70, Start Time: 1.25s, End Time: 1.44s
# Loaded keyword MFCC: Kheir_000003.npy, Shape: (39, 50)
# Keyword: Kheir_000003.npy, DTW Distance: 48.24, Start Time: 0.32s, End Time: 0.86s
# Loaded keyword MFCC: Kheir_000004.npy, Shape: (39, 50)
# Keyword: Kheir_000004.npy, DTW Distance: 50.19, Start Time: 0.70s, End Time: 0.86s
# Loaded keyword MFCC: Kheir_000005.npy, Shape: (39, 50)
# Keyword: Kheir_000005.npy, DTW Distance: 50.35, Start Time: 0.70s, End Time: 0.86s
# Loaded keyword MFCC: Kheir_001.npy, Shape: (39, 50)
# Keyword: Kheir_001.npy, DTW Distance: 44.34, Start Time: 0.32s, End Time: 0.86s
# Loaded keyword MFCC: Kheir_002.npy, Shape: (39, 50)
# Keyword: Kheir_002.npy, DTW Distance: 44.18, Start Time: 0.32s, End Time: 0.86s
# Loaded keyword MFCC: Kheir_003.npy, Shape: (39, 50)
# Keyword: Kheir_003.npy, DTW Distance: 43.52, Start Time: 0.32s, End Time: 0.90s
# Loaded keyword MFCC: Kheir_004.npy, Shape: (39, 50)
# Keyword: Kheir_004.npy, DTW Distance: 42.13, Start Time: 0.32s, End Time: 0.90s
# Loaded keyword MFCC: Kheir_005.npy, Shape: (39, 50)
# Keyword: Kheir_005.npy, DTW Distance: 47.50, Start Time: 0.32s, End Time: 0.86s
# Loaded keyword MFCC: Kheir_01.npy, Shape: (39, 50)
# Keyword: Kheir_01.npy, DTW Distance: 39.53, Start Time: 0.32s, End Time: 0.86s
# Loaded keyword MFCC: Kheir_02.npy, Shape: (39, 50)
# Keyword: Kheir_02.npy, DTW Distance: 42.09, Start Time: 0.32s, End Time: 0.64s
# Loaded keyword MFCC: Kheir_03.npy, Shape: (39, 50)
# Keyword: Kheir_03.npy, DTW Distance: 33.71, Start Time: 0.32s, End Time: 0.64s
# Loaded keyword MFCC: Kheir_04.npy, Shape: (39, 50)
# Keyword: Kheir_04.npy, DTW Distance: 33.94, Start Time: 0.32s, End Time: 0.64s
# Loaded keyword MFCC: Kheir_05.npy, Shape: (39, 50)
# Keyword: Kheir_05.npy, DTW Distance: 35.04, Start Time: 0.32s, End Time: 0.64s
# ✅ Saved detections to data/keyword_detections\na_khir_ashtebah_shode.json
# Detections: [{'word': 'خیر', 'start_time': np.float64(0.32), 'end_time': np.float64(0.64)}]
#
# 🔍 Processing speech file: no_key_01.npy
# Loaded speech MFCC: no_key_01.npy, Shape: (39, 50)
# Annotation loaded: متن فرضی جمله, Duration: 3.0397708333333333
# Allowed keywords for no_key_01.npy: []
# ✅ Saved detections to data/keyword_detections\no_key_01.json
# Detections: []
#
# 🔍 Processing speech file: no_key_02.npy
# Loaded speech MFCC: no_key_02.npy, Shape: (39, 50)
# Annotation loaded: متن فرضی جمله, Duration: 2.6797708333333334
# Allowed keywords for no_key_02.npy: []
# ✅ Saved detections to data/keyword_detections\no_key_02.json
# Detections: []
#
# 🔍 Processing speech file: no_key_03.npy
# Loaded speech MFCC: no_key_03.npy, Shape: (39, 50)
# Annotation loaded: متن فرضی جمله, Duration: 2.4797708333333333
# Allowed keywords for no_key_03.npy: []
# ✅ Saved detections to data/keyword_detections\no_key_03.json
# Detections: []
#
# 🔍 Processing speech file: no_key_04.npy
# Loaded speech MFCC: no_key_04.npy, Shape: (39, 50)
# Annotation loaded: متن فرضی جمله, Duration: 2.5197708333333333
# Allowed keywords for no_key_04.npy: []
# ✅ Saved detections to data/keyword_detections\no_key_04.json
# Detections: []
#
# 🔍 Processing speech file: no_key_05.npy
# Loaded speech MFCC: no_key_05.npy, Shape: (39, 50)
# Annotation loaded: متن فرضی جمله, Duration: 2.7997708333333335
# Allowed keywords for no_key_05.npy: []
# ✅ Saved detections to data/keyword_detections\no_key_05.json
# Detections: []
#
# 🔍 Processing speech file: no_key_06.npy
# Loaded speech MFCC: no_key_06.npy, Shape: (39, 50)
# Annotation loaded: متن فرضی جمله, Duration: 2.399770833333333
# Allowed keywords for no_key_06.npy: []
# ✅ Saved detections to data/keyword_detections\no_key_06.json
# Detections: []
#
# 🔍 Processing speech file: no_key_07.npy
# Loaded speech MFCC: no_key_07.npy, Shape: (39, 50)
# Annotation loaded: متن فرضی جمله, Duration: 2.4797708333333333
# Allowed keywords for no_key_07.npy: []
# ✅ Saved detections to data/keyword_detections\no_key_07.json
# Detections: []
#
# 🔍 Processing speech file: no_key_08.npy
# Loaded speech MFCC: no_key_08.npy, Shape: (39, 50)
# Annotation loaded: متن فرضی جمله, Duration: 2.2397708333333335
# Allowed keywords for no_key_08.npy: []
# ✅ Saved detections to data/keyword_detections\no_key_08.json
# Detections: []
#
# 🔍 Processing speech file: no_key_09.npy
# Loaded speech MFCC: no_key_09.npy, Shape: (39, 50)
# Annotation loaded: متن فرضی جمله, Duration: 2.2797708333333335
# Allowed keywords for no_key_09.npy: []
# ✅ Saved detections to data/keyword_detections\no_key_09.json
# Detections: []
#
# 🔍 Processing speech file: no_key_10.npy
# Loaded speech MFCC: no_key_10.npy, Shape: (39, 50)
# Annotation loaded: متن فرضی جمله, Duration: 2.399770833333333
# Allowed keywords for no_key_10.npy: []
# ✅ Saved detections to data/keyword_detections\no_key_10.json
# Detections: []
#
# 🔍 Processing speech file: salam_mo_kh.npy
# Loaded speech MFCC: salam_mo_kh.npy, Shape: (39, 50)
# Annotation loaded: سلام متشکرم خداحافظ, Duration: 3.319770833333333
# Allowed keywords for salam_mo_kh.npy: ['Salam', 'Motshakeram', 'Khodahafez']
# Loaded keyword MFCC: Salam_000001.npy, Shape: (39, 50)
# Keyword: Salam_000001.npy, DTW Distance: 35.84, Start Time: 0.74s, End Time: 1.06s
# Loaded keyword MFCC: Salam_000002.npy, Shape: (39, 50)
# Keyword: Salam_000002.npy, DTW Distance: 42.34, Start Time: 0.74s, End Time: 1.06s
# Loaded keyword MFCC: Salam_000003.npy, Shape: (39, 50)
# Keyword: Salam_000003.npy, DTW Distance: 32.31, Start Time: 0.74s, End Time: 1.06s
# Loaded keyword MFCC: Salam_000004.npy, Shape: (39, 50)
# Keyword: Salam_000004.npy, DTW Distance: 37.94, Start Time: 0.32s, End Time: 0.74s
# Loaded keyword MFCC: Salam_000005.npy, Shape: (39, 50)
# Keyword: Salam_000005.npy, DTW Distance: 38.15, Start Time: 0.74s, End Time: 1.06s
# Loaded keyword MFCC: Salam_001.npy, Shape: (39, 50)
# Keyword: Salam_001.npy, DTW Distance: 33.17, Start Time: 0.54s, End Time: 1.06s
# Loaded keyword MFCC: Salam_002.npy, Shape: (39, 50)
# Keyword: Salam_002.npy, DTW Distance: 38.87, Start Time: 0.54s, End Time: 1.06s
# Loaded keyword MFCC: Salam_003.npy, Shape: (39, 50)
# Keyword: Salam_003.npy, DTW Distance: 33.69, Start Time: 0.54s, End Time: 1.06s
# Loaded keyword MFCC: Salam_004.npy, Shape: (39, 50)
# Keyword: Salam_004.npy, DTW Distance: 36.22, Start Time: 0.54s, End Time: 1.06s
# Loaded keyword MFCC: Salam_005.npy, Shape: (39, 50)
# Keyword: Salam_005.npy, DTW Distance: 35.30, Start Time: 0.54s, End Time: 1.06s
# Loaded keyword MFCC: Salam_01.npy, Shape: (39, 50)
# Keyword: Salam_01.npy, DTW Distance: 32.54, Start Time: 0.70s, End Time: 1.06s
# Loaded keyword MFCC: Salam_02.npy, Shape: (39, 50)
# Keyword: Salam_02.npy, DTW Distance: 36.17, Start Time: 0.00s, End Time: 0.42s
# Loaded keyword MFCC: Salam_03.npy, Shape: (39, 50)
# Keyword: Salam_03.npy, DTW Distance: 28.04, Start Time: 0.00s, End Time: 0.38s
# Loaded keyword MFCC: Salam_04.npy, Shape: (39, 50)
# Keyword: Salam_04.npy, DTW Distance: 29.76, Start Time: 0.00s, End Time: 0.38s
# Loaded keyword MFCC: Salam_05.npy, Shape: (39, 50)
# Keyword: Salam_05.npy, DTW Distance: 33.65, Start Time: 0.00s, End Time: 0.38s
# Loaded keyword MFCC: Motshakeram_000001.npy, Shape: (39, 50)
# Keyword: Motshakeram_000001.npy, DTW Distance: 36.29, Start Time: 0.35s, End Time: 1.06s
# Loaded keyword MFCC: Motshakeram_000002.npy, Shape: (39, 50)
# Keyword: Motshakeram_000002.npy, DTW Distance: 36.09, Start Time: 0.54s, End Time: 1.06s
# Loaded keyword MFCC: Motshakeram_000003.npy, Shape: (39, 50)
# Keyword: Motshakeram_000003.npy, DTW Distance: 40.53, Start Time: 0.35s, End Time: 1.06s
# Loaded keyword MFCC: Motshakeram_000004.npy, Shape: (39, 50)
# Keyword: Motshakeram_000004.npy, DTW Distance: 40.64, Start Time: 0.35s, End Time: 1.06s
# Loaded keyword MFCC: Motshakeram_000005.npy, Shape: (39, 50)
# Keyword: Motshakeram_000005.npy, DTW Distance: 36.70, Start Time: 0.35s, End Time: 1.06s
# Loaded keyword MFCC: Motshakeram_001.npy, Shape: (39, 50)
# Keyword: Motshakeram_001.npy, DTW Distance: 34.94, Start Time: 0.38s, End Time: 1.06s
# Loaded keyword MFCC: Motshakeram_002.npy, Shape: (39, 50)
# Keyword: Motshakeram_002.npy, DTW Distance: 35.72, Start Time: 0.35s, End Time: 1.06s
# Loaded keyword MFCC: Motshakeram_003.npy, Shape: (39, 50)
# Keyword: Motshakeram_003.npy, DTW Distance: 39.24, Start Time: 0.35s, End Time: 1.06s
# Loaded keyword MFCC: Motshakeram_004.npy, Shape: (39, 50)
# Keyword: Motshakeram_004.npy, DTW Distance: 36.09, Start Time: 0.38s, End Time: 1.06s
# Loaded keyword MFCC: Motshakeram_005.npy, Shape: (39, 50)
# Keyword: Motshakeram_005.npy, DTW Distance: 36.42, Start Time: 0.38s, End Time: 1.06s
# Loaded keyword MFCC: Motshakeram_01.npy, Shape: (39, 50)
# Keyword: Motshakeram_01.npy, DTW Distance: 35.60, Start Time: 0.38s, End Time: 1.06s
# Loaded keyword MFCC: Motshakeram_02.npy, Shape: (39, 50)
# Keyword: Motshakeram_02.npy, DTW Distance: 34.63, Start Time: 0.38s, End Time: 1.06s
# Loaded keyword MFCC: Motshakeram_03.npy, Shape: (39, 50)
# Keyword: Motshakeram_03.npy, DTW Distance: 35.82, Start Time: 0.38s, End Time: 1.06s
# Loaded keyword MFCC: Motshakeram_04.npy, Shape: (39, 50)
# Keyword: Motshakeram_04.npy, DTW Distance: 32.41, Start Time: 0.38s, End Time: 1.06s
# Loaded keyword MFCC: Motshakeram_05.npy, Shape: (39, 50)
# Keyword: Motshakeram_05.npy, DTW Distance: 33.29, Start Time: 0.38s, End Time: 1.06s
# Loaded keyword MFCC: Khodahafez_000001.npy, Shape: (39, 50)
# Keyword: Khodahafez_000001.npy, DTW Distance: 27.59, Start Time: 1.09s, End Time: 1.60s
# Loaded keyword MFCC: Khodahafez_000002.npy, Shape: (39, 50)
# Keyword: Khodahafez_000002.npy, DTW Distance: 28.37, Start Time: 1.09s, End Time: 1.60s
# Loaded keyword MFCC: Khodahafez_000003.npy, Shape: (39, 50)
# Keyword: Khodahafez_000003.npy, DTW Distance: 32.48, Start Time: 1.02s, End Time: 1.60s
# Loaded keyword MFCC: Khodahafez_000004.npy, Shape: (39, 50)
# Keyword: Khodahafez_000004.npy, DTW Distance: 29.21, Start Time: 1.09s, End Time: 1.60s
# Loaded keyword MFCC: Khodahafez_000005.npy, Shape: (39, 50)
# Keyword: Khodahafez_000005.npy, DTW Distance: 33.87, Start Time: 1.06s, End Time: 1.60s
# Loaded keyword MFCC: Khodahafez_001.npy, Shape: (39, 50)
# Keyword: Khodahafez_001.npy, DTW Distance: 33.54, Start Time: 1.09s, End Time: 1.60s
# Loaded keyword MFCC: Khodahafez_002.npy, Shape: (39, 50)
# Keyword: Khodahafez_002.npy, DTW Distance: 32.80, Start Time: 1.09s, End Time: 1.60s
# Loaded keyword MFCC: Khodahafez_003.npy, Shape: (39, 50)
# Keyword: Khodahafez_003.npy, DTW Distance: 33.32, Start Time: 1.09s, End Time: 1.60s
# Loaded keyword MFCC: Khodahafez_004.npy, Shape: (39, 50)
# Keyword: Khodahafez_004.npy, DTW Distance: 30.34, Start Time: 1.09s, End Time: 1.57s
# Loaded keyword MFCC: Khodahafez_005.npy, Shape: (39, 50)
# Keyword: Khodahafez_005.npy, DTW Distance: 30.47, Start Time: 1.06s, End Time: 1.57s
# ✅ Saved detections to data/keyword_detections\salam_mo_kh.json
# Detections: [{'word': 'سلام', 'start_time': np.float64(0.0), 'end_time': np.float64(0.38)}, {'word': 'متشکرم', 'start_time': np.float64(0.38), 'end_time': np.float64(1.06)}, {'word': 'خداحافظ', 'start_time': np.float64(1.09), 'end_time': np.float64(1.6)}]
#
# 🔍 Processing speech file: salam_sob_be_kheir.npy
# Loaded speech MFCC: salam_sob_be_kheir.npy, Shape: (39, 50)
# Annotation loaded: سلام صبح به خیر, Duration: 2.919770833333333
# Allowed keywords for salam_sob_be_kheir.npy: ['Salam', 'Kheir']
# Loaded keyword MFCC: Salam_000001.npy, Shape: (39, 50)
# Keyword: Salam_000001.npy, DTW Distance: 49.01, Start Time: 0.00s, End Time: 0.61s
# Loaded keyword MFCC: Salam_000002.npy, Shape: (39, 50)
# Keyword: Salam_000002.npy, DTW Distance: 54.28, Start Time: 0.00s, End Time: 0.61s
# Loaded keyword MFCC: Salam_000003.npy, Shape: (39, 50)
# Keyword: Salam_000003.npy, DTW Distance: 43.06, Start Time: 0.70s, End Time: 1.06s
# Loaded keyword MFCC: Salam_000004.npy, Shape: (39, 50)
# Keyword: Salam_000004.npy, DTW Distance: 45.32, Start Time: 0.00s, End Time: 0.10s
# Loaded keyword MFCC: Salam_000005.npy, Shape: (39, 50)
# Keyword: Salam_000005.npy, DTW Distance: 47.14, Start Time: 0.00s, End Time: 0.61s
# Loaded keyword MFCC: Salam_001.npy, Shape: (39, 50)
# Keyword: Salam_001.npy, DTW Distance: 41.92, Start Time: 0.70s, End Time: 1.02s
# Loaded keyword MFCC: Salam_002.npy, Shape: (39, 50)
# Keyword: Salam_002.npy, DTW Distance: 48.74, Start Time: 0.70s, End Time: 1.02s
# Loaded keyword MFCC: Salam_003.npy, Shape: (39, 50)
# Keyword: Salam_003.npy, DTW Distance: 45.53, Start Time: 0.70s, End Time: 1.02s
# Loaded keyword MFCC: Salam_004.npy, Shape: (39, 50)
# Keyword: Salam_004.npy, DTW Distance: 47.67, Start Time: 0.70s, End Time: 1.02s
# Loaded keyword MFCC: Salam_005.npy, Shape: (39, 50)
# Keyword: Salam_005.npy, DTW Distance: 46.92, Start Time: 0.70s, End Time: 1.02s
# Loaded keyword MFCC: Salam_01.npy, Shape: (39, 50)
# Keyword: Salam_01.npy, DTW Distance: 37.38, Start Time: 0.00s, End Time: 0.58s
# Loaded keyword MFCC: Salam_02.npy, Shape: (39, 50)
# Keyword: Salam_02.npy, DTW Distance: 37.75, Start Time: 0.70s, End Time: 1.02s
# Loaded keyword MFCC: Salam_03.npy, Shape: (39, 50)
# Keyword: Salam_03.npy, DTW Distance: 29.67, Start Time: 0.00s, End Time: 0.58s
# Loaded keyword MFCC: Salam_04.npy, Shape: (39, 50)
# Keyword: Salam_04.npy, DTW Distance: 35.73, Start Time: 0.00s, End Time: 0.58s
# Loaded keyword MFCC: Salam_05.npy, Shape: (39, 50)
# Keyword: Salam_05.npy, DTW Distance: 42.42, Start Time: 0.00s, End Time: 0.58s
# Loaded keyword MFCC: Kheir_000001.npy, Shape: (39, 50)
# Keyword: Kheir_000001.npy, DTW Distance: 44.62, Start Time: 1.25s, End Time: 1.60s
# Loaded keyword MFCC: Kheir_000002.npy, Shape: (39, 50)
# Keyword: Kheir_000002.npy, DTW Distance: 40.61, Start Time: 1.25s, End Time: 1.60s
# Loaded keyword MFCC: Kheir_000003.npy, Shape: (39, 50)
# Keyword: Kheir_000003.npy, DTW Distance: 48.00, Start Time: 1.25s, End Time: 1.60s
# Loaded keyword MFCC: Kheir_000004.npy, Shape: (39, 50)
# Keyword: Kheir_000004.npy, DTW Distance: 49.31, Start Time: 1.25s, End Time: 1.60s
# Loaded keyword MFCC: Kheir_000005.npy, Shape: (39, 50)
# Keyword: Kheir_000005.npy, DTW Distance: 49.60, Start Time: 1.25s, End Time: 1.60s
# Loaded keyword MFCC: Kheir_001.npy, Shape: (39, 50)
# Keyword: Kheir_001.npy, DTW Distance: 43.43, Start Time: 1.25s, End Time: 1.60s
# Loaded keyword MFCC: Kheir_002.npy, Shape: (39, 50)
# Keyword: Kheir_002.npy, DTW Distance: 45.68, Start Time: 1.22s, End Time: 1.60s
# Loaded keyword MFCC: Kheir_003.npy, Shape: (39, 50)
# Keyword: Kheir_003.npy, DTW Distance: 42.81, Start Time: 1.22s, End Time: 1.60s
# Loaded keyword MFCC: Kheir_004.npy, Shape: (39, 50)
# Keyword: Kheir_004.npy, DTW Distance: 41.64, Start Time: 1.22s, End Time: 1.60s
# Loaded keyword MFCC: Kheir_005.npy, Shape: (39, 50)
# Keyword: Kheir_005.npy, DTW Distance: 45.95, Start Time: 1.22s, End Time: 1.60s
# Loaded keyword MFCC: Kheir_01.npy, Shape: (39, 50)
# Keyword: Kheir_01.npy, DTW Distance: 40.69, Start Time: 1.25s, End Time: 1.60s
# Loaded keyword MFCC: Kheir_02.npy, Shape: (39, 50)
# Keyword: Kheir_02.npy, DTW Distance: 43.58, Start Time: 1.25s, End Time: 1.60s
# Loaded keyword MFCC: Kheir_03.npy, Shape: (39, 50)
# Keyword: Kheir_03.npy, DTW Distance: 35.66, Start Time: 1.25s, End Time: 1.60s
# Loaded keyword MFCC: Kheir_04.npy, Shape: (39, 50)
# Keyword: Kheir_04.npy, DTW Distance: 31.33, Start Time: 1.25s, End Time: 1.60s
# Loaded keyword MFCC: Kheir_05.npy, Shape: (39, 50)
# Keyword: Kheir_05.npy, DTW Distance: 34.27, Start Time: 1.22s, End Time: 1.60s
# ✅ Saved detections to data/keyword_detections\salam_sob_be_kheir.json
# Detections: [{'word': 'سلام', 'start_time': np.float64(0.0), 'end_time': np.float64(0.58)}, {'word': 'خیر', 'start_time': np.float64(1.25), 'end_time': np.float64(1.6)}]
#
# 🔍 Processing speech file: ye_salam_garm_be_hame.npy
# Loaded speech MFCC: ye_salam_garm_be_hame.npy, Shape: (39, 50)
# Annotation loaded: یه سلام گرم به همه, Duration: 2.5997708333333334
# Allowed keywords for ye_salam_garm_be_hame.npy: ['Salam']
# Loaded keyword MFCC: Salam_000001.npy, Shape: (39, 50)
# Keyword: Salam_000001.npy, DTW Distance: 43.90, Start Time: 0.80s, End Time: 1.44s
# Loaded keyword MFCC: Salam_000002.npy, Shape: (39, 50)
# Keyword: Salam_000002.npy, DTW Distance: 48.72, Start Time: 0.32s, End Time: 0.83s
# Loaded keyword MFCC: Salam_000003.npy, Shape: (39, 50)
# Keyword: Salam_000003.npy, DTW Distance: 45.32, Start Time: 1.09s, End Time: 1.60s
# Loaded keyword MFCC: Salam_000004.npy, Shape: (39, 50)
# Keyword: Salam_000004.npy, DTW Distance: 51.81, Start Time: 0.77s, End Time: 1.09s
# Loaded keyword MFCC: Salam_000005.npy, Shape: (39, 50)
# Keyword: Salam_000005.npy, DTW Distance: 42.71, Start Time: 0.80s, End Time: 1.60s
# Loaded keyword MFCC: Salam_001.npy, Shape: (39, 50)
# Keyword: Salam_001.npy, DTW Distance: 42.59, Start Time: 0.32s, End Time: 0.83s
# Loaded keyword MFCC: Salam_002.npy, Shape: (39, 50)
# Keyword: Salam_002.npy, DTW Distance: 47.53, Start Time: 0.32s, End Time: 0.83s
# Loaded keyword MFCC: Salam_003.npy, Shape: (39, 50)
# Keyword: Salam_003.npy, DTW Distance: 46.23, Start Time: 0.32s, End Time: 0.83s
# Loaded keyword MFCC: Salam_004.npy, Shape: (39, 50)
# Keyword: Salam_004.npy, DTW Distance: 46.34, Start Time: 0.32s, End Time: 0.83s
# Loaded keyword MFCC: Salam_005.npy, Shape: (39, 50)
# Keyword: Salam_005.npy, DTW Distance: 44.07, Start Time: 0.32s, End Time: 1.09s
# Loaded keyword MFCC: Salam_01.npy, Shape: (39, 50)
# Keyword: Salam_01.npy, DTW Distance: 40.10, Start Time: 0.35s, End Time: 0.67s
# Loaded keyword MFCC: Salam_02.npy, Shape: (39, 50)
# Keyword: Salam_02.npy, DTW Distance: 35.84, Start Time: 0.35s, End Time: 0.67s
# Loaded keyword MFCC: Salam_03.npy, Shape: (39, 50)
# Keyword: Salam_03.npy, DTW Distance: 35.81, Start Time: 1.22s, End Time: 1.60s
# Loaded keyword MFCC: Salam_04.npy, Shape: (39, 50)
# Keyword: Salam_04.npy, DTW Distance: 36.95, Start Time: 0.35s, End Time: 0.67s
# Loaded keyword MFCC: Salam_05.npy, Shape: (39, 50)
# Keyword: Salam_05.npy, DTW Distance: 43.78, Start Time: 0.35s, End Time: 0.67s
# ✅ Saved detections to data/keyword_detections\ye_salam_garm_be_hame.json
# Detections: [{'word': 'سلام', 'start_time': np.float64(1.22), 'end_time': np.float64(1.6)}]

# %% [markdown]
# ### GUI
